# %%
import numpy as np

def load_embeddings(path):
    mapping = dict()
    
    with open(path, 'r', encoding='utf8') as f:
        for line in f:
            line = line.strip()
            if len(line) == 0:
                continue
            splitted = line.split(" ")
            if len(splitted) <= 2:
                continue
            mapping[splitted[0]] = np.array(splitted[1:], dtype=float) # stwórz słownik słowo -> wektor 
    return mapping

glove_mapping = load_embeddings('glove/glove.6B.300d.txt') 
my_mapping = load_embeddings('Embedding-Models/size300-window10.txt')

# %%
glove_keys = np.array(list(glove_mapping.keys()))
glove_vals = np.array(list(glove_mapping.values()))

glove_avg, glove_std = np.average(glove_vals), np.std(glove_vals)

my_keys = np.array(list(my_mapping.keys()))
my_vals = np.array(list(my_mapping.values()))

my_avg, my_std = np.average(my_vals), np.std(my_vals)

glove_keys_count = glove_keys.shape[0]
my_keys_count = my_keys.shape[0]
all_words_count = np.unique(np.concatenate((glove_keys, my_keys))).shape[0]

overhead = all_words_count - glove_keys_count

new_mapping_values = np.zeros(shape = (all_words_count, glove_vals.shape[1] + my_vals.shape[1]), dtype=np.float64)
new_mapping_keys = np.empty(all_words_count, dtype="<U30")

# put glove mapping at the beginning of new super-mapping
# indices 0 : 4 000 000, 0 : 300
new_mapping_values[:glove_vals.shape[0], :glove_vals.shape[1]] = glove_vals
new_mapping_keys[:glove_keys.shape[0]] = glove_keys

vec_size = glove_vals.shape[1]

# join glove mapping with own mapping 
# or if it's missing, fill with random normal
for idx, key in enumerate(glove_keys):
    if key in my_mapping.keys():
        new_mapping_values[idx, glove_vals.shape[1]:] = my_mapping[key]
    else:
        new_mapping_values[idx, glove_vals.shape[1]:] = np.random.normal(loc=glove_avg, scale=glove_std, size=vec_size)
        
counter = 0
for idx, key in enumerate(my_keys):
    if key not in glove_mapping.keys():
        new_mapping_values[glove_vals.shape[0] + counter, :glove_vals.shape[1]] = np.random.normal(loc=my_avg, scale=my_std, size=vec_size)
        new_mapping_values[glove_vals.shape[0] + counter, glove_vals.shape[1]:] = my_mapping[key]
        new_mapping_keys[glove_vals.shape[0] + counter] = key
        counter += 1            

super_mapping = dict(zip(new_mapping_keys, new_mapping))
print(new_mapping_keys.shape, new_mapping_values.shape)
# Out:
# 300

# %%
str(super_mapping['the'][0])
# Out:
# '0.04656'

# %%
with open("Embedding-Models/super-model.txt", "w") as file:
    for key, value in super_mapping.items():
        file.write(key)
        file.write(" ")
        for v in value:
            file.write(str(v) + " ")
        file.write("\n")

# %%
import copy

# my_mapping_weight = 0.0

# for key in my_mapping.keys():
#     if key in super_mapping.keys():
#         new_vector = super_mapping[key] * (1-my_mapping_weight) + my_mapping[key] * my_mapping_weight
#         super_mapping[key] = new_vector
#     else:
#         super_mapping[key] = my_mapping[key]
# Out:
# 21055  - not in glove, random.normal!
# the  - concat!
# to  - concat!
# of  - concat!
# and  - concat!
# in  - concat!
# is  - concat!
# that  - concat!
# this  - concat!
# as  - concat!
# for  - concat!
# with  - concat!
# on  - concat!
# it  - concat!
# by  - concat!
# system-path  - not in glove, random.normal!
# we  - concat!
# are  - concat!
# from  - concat!
# malware  - concat!
# an  - concat!
# be  - concat!
# was  - concat!
# used  - concat!
# have  - concat!
# which  - concat!
# or  - concat!
# file  - concat!
# not  - concat!
# these  - concat!
# also  - concat!
# has  - concat!
# at  - concat!
# data  - concat!
# can  - concat!
# information  - concat!
# were  - concat!
# attacks  - concat!
# their  - concat!
# code  - concat!
# server  - concat!
# com-file  - not in glove, random.normal!
# they  - concat!
# been  - concat!
# following  - concat!
# system  - concat!
# one  - concat!
# using  - concat!
# attackers  - concat!
# its  - concat!
# other  - concat!
# attack  - concat!
# exe-file  - not in glove, random.normal!
# files  - concat!
# all  - concat!
# network  - concat!
# some  - concat!
# will  - concat!
# if  - concat!
# use  - concat!
# security  - concat!
# same  - concat!
# group  - concat!
# malicious  - concat!
# but  - concat!
# more  - concat!
# such  - concat!
# our  - concat!
# command  - concat!
# samples  - concat!
# time  - concat!
# ip  - concat!
# into  - concat!
# may  - concat!
# cyber  - concat!
# first  - concat!
# targeted  - concat!
# control  - concat!
# threat  - concat!
# then  - concat!
# when  - concat!
# two  - concat!
# found  - concat!
# servers  - concat!
# name  - concat!
# any  - concat!
# sample  - concat!
# domain  - concat!
# hash  - concat!
# victim  - concat!
# only  - concat!
# after  - concat!
# windows  - concat!
# key  - concat!
# there  - concat!
# analysis  - concat!
# most  - concat!
# address  - concat!
# observed  - concat!
# new  - concat!
# different  - concat!
# campaign  - concat!
# figure  - concat!
# within  - concat!
# known  - concat!
# number  - concat!
# version  - concat!
# both  - concat!
# access  - concat!
# user  - concat!
# dll  - concat!
# between  - concat!
# would  - concat!
# korea  - concat!
# systems  - concat!
# targets  - concat!
# however  - concat!
# dll-file  - not in glove, random.normal!
# while  - concat!
# target  - concat!
# about  - concat!
# activity  - concat!
# based  - concat!
# over  - concat!
# several  - concat!
# through  - concat!
# email  - concat!
# them  - concat!
# no  - concat!
# north  - concat!
# another  - concat!
# service  - concat!
# function  - concat!
# module  - concat!
# tools  - concat!
# backdoor  - concat!
# china  - concat!
# process  - concat!
# could  - concat!
# c2  - concat!
# against  - concat!
# had  - concat!
# infrastructure  - concat!
# value  - concat!
# victims  - concat!
# infected  - concat!
# during  - concat!
# uses  - concat!
# domains  - concat!
# driver  - concat!
# exploit  - concat!
# many  - concat!
# compromised  - concat!
# likely  - concat!
# string  - concat!
# ip-address  - not in glove, random.normal!
# com  - concat!
# rat  - concat!
# example  - concat!
# like  - concat!
# each  - concat!
# government  - concat!
# groups  - concat!
# some-variable  - not in glove, random.normal!
# well  - concat!
# including  - concat!
# computer  - concat!
# encrypted  - concat!
# being  - concat!
# attacker  - concat!
# via  - concat!
# remote  - concat!
# payload  - concat!
# actors  - concat!
# campaigns  - concat!
# see  - concat!
# executable  - concat!
# report  - concat!
# document  - concat!
# commands  - concat!
# below  - concat!
# tool  - concat!
# research  - concat!
# contains  - concat!
# internet  - concat!
# than  - concat!
# configuration  - concat!
# chinese  - concat!
# set  - concat!
# web  - concat!
# so  - concat!
# specific  - concat!
# software  - concat!
# us  - concat!
# list  - concat!
# http  - concat!
# traffic  - concat!
# organizations  - concat!
# company  - concat!
# where  - concat!
# stage  - concat!
# out  - concat!
# addresses  - concat!
# operation  - concat!
# case  - concat!
# team  - concat!
# order  - concat!
# seen  - concat!
# available  - concat!
# who  - concat!
# named  - concat!
# identified  - concat!
# intelligence  - concat!
# names  - concat!
# appears  - concat!
# content  - concat!
# registry  - concat!
# what  - concat!
# apt  - concat!
# similar  - concat!
# sent  - concat!
# part  - concat!
# operations  - concat!
# since  - concat!
# password  - concat!
# very  - concat!
# legitimate  - concat!
# apt1  - not in glove, random.normal!
# functionality  - concat!
# does  - concat!
# main  - concat!
# microsoft  - concat!
# additional  - concat!
# org-file  - not in glove, random.normal!
# companies  - concat!
# created  - concat!
# related  - concat!
# possible  - concat!
# called  - concat!
# south  - concat!
# how  - concat!
# three  - concat!
# multiple  - concat!
# second  - concat!
# back  - concat!
# above  - concat!
# request  - concat!
# post  - concat!
# bytes  - concat!
# binary  - concat!
# networks  - concat!
# do  - concat!
# targeting  - concat!
# able  - concat!
# users  - concat!
# interesting  - concat!
# documents  - concat!
# once  - concat!
# get  - concat!
# running  - concat!
# shell  - concat!
# registered  - concat!
# services  - concat!
# website  - concat!
# korean  - concat!
# communications  - concat!
# even  - concat!
# itself  - concat!
# least  - concat!
# component  - concat!
# technical  - concat!
# 2013  - concat!
# dropper  - concat!
# work  - concat!
# variant  - concat!
# up  - concat!
# include  - concat!
# techniques  - concat!
# memory  - concat!
# you  - concat!
# net  - concat!
# associated  - concat!
# date  - concat!
# further  - concat!
# client  - concat!
# common  - concat!
# versions  - concat!
# response  - concat!
# md5  - concat!
# connection  - concat!
# machine  - concat!
# size  - concat!
# directory  - concat!
# host  - concat!
# communication  - concat!
# details  - concat!
# current  - concat!
# oil  - concat!
# here  - concat!
# should  - concat!
# proxy  - concat!
# those  - concat!
# application  - concat!
# military  - concat!
# trojan  - concat!
# components  - concat!
# port  - concat!
# table  - concat!
# type  - concat!
# shown  - concat!
# countries  - concat!
# method  - concat!
# section  - concat!
# variants  - concat!
# often  - concat!
# compromise  - concat!
# before  - concat!
# strings  - concat!
# various  - concat!
# appear  - concat!
# source  - concat!
# run  - concat!
# identify  - concat!
# advanced  - concat!
# vulnerability  - concat!
# way  - concat!
# addition  - concat!
# message  - concat!
# detection  - concat!
# public  - concat!
# next  - concat!
# phishing  - concat!
# download  - concat!
# contained  - concat!
# previously  - concat!
# shows  - concat!
# made  - concat!
# active  - concat!
# capabilities  - concat!
# compiled  - concat!
# execution  - concat!
# exploits  - concat!
# because  - concat!
# encryption  - concat!
# executed  - concat!
# organization  - concat!
# initial  - concat!
# account  - concat!
# program  - concat!
# state  - concat!
# websites  - concat!
# path  - concat!
# gen  - concat!
# years  - concat!
# local  - concat!
# infection  - concat!
# fireeye  - not in glove, random.normal!
# --  - concat!
# original  - concat!
# processes  - concat!
# directly  - concat!
# log  - concat!
# provides  - concat!
# execute  - concat!
# last  - concat!
# social  - concat!
# net-file  - not in glove, random.normal!
# xor  - concat!
# contain  - concat!
# stored  - concat!
# digital  - concat!
# id  - concat!
# api  - concat!
# cases  - concat!
# resources  - concat!
# actor  - concat!
# espionage  - concat!
# computers  - concat!
# dropped  - concat!
# make  - concat!
# later  - concat!
# 10  - concat!
# link  - concat!
# detected  - concat!
# evidence  - concat!
# located  - concat!
# particular  - concat!
# installed  - concat!
# his  - concat!
# believe  - concat!
# unique  - concat!
# 2014  - concat!
# described  - concat!
# defense  - concat!
# unit  - concat!
# point  - concat!
# development  - concat!
# custom  - concat!
# discovered  - concat!
# although  - concat!
# block  - concat!
# emails  - concat!
# call  - concat!
# did  - concat!
# instead  - concat!
# under  - concat!
# blog  - concat!
# connections  - concat!
# 2012  - concat!
# own  - concat!
# engineering  - concat!
# world  - concat!
# embedded  - concat!
# allows  - concat!
# full  - concat!
# now  - concat!
# credentials  - concat!
# word  - concat!
# provide  - concat!
# disk  - concat!
# much  - concat!
# threats  - concat!
# level  - concat!
# e-mail  - concat!
# large  - concat!
# iran  - concat!
# google  - concat!
# without  - concat!
# format  - concat!
# note  - concat!
# technology  - concat!
# internal  - concat!
# modules  - concat!
# shared  - concat!
# designed  - concat!
# update  - concat!
# just  - concat!
# either  - concat!
# behind  - concat!
# russian  - concat!
# written  - concat!
# industry  - concat!
# includes  - concat!
# connect  - concat!
# given  - concat!
# regime  - concat!
# still  - concat!
# recent  - concat!
# language  - concat!
# simple  - concat!
# creates  - concat!
# functions  - concat!
# java  - concat!
# means  - concat!
# url  - concat!
# ad  - concat!
# detect  - concat!
# text  - concat!
# connected  - concat!
# pe  - concat!
# decoy  - concat!
# activities  - concat!
# received  - concat!
# incident  - concat!
# provided  - concat!
# filename  - concat!
# real  - concat!
# image  - concat!
# page  - concat!
# find  - concat!
# fact  - concat!
# according  - concat!
# accounts  - concat!
# included  - concat!
# attempts  - concat!
# stuxnet  - concat!
# few  - concat!
# header  - concat!
# dns  - concat!
# analyzed  - concat!
# present  - concat!
# values  - concat!
# folder  - concat!
# appendix  - concat!
# encoded  - concat!
# result  - concat!
# location  - concat!
# family  - concat!
# requests  - concat!
# cnc  - concat!
# open  - concat!
# stolen  - concat!
# previous  - concat!
# bot  - concat!
# shellcode  - concat!
# makes  - concat!
# states  - concat!
# every  - concat!
# july  - concat!
# instance  - concat!
# across  - concat!
# around  - concat!
# high  - concat!
# indicators  - concat!
# protocol  - concat!
# must  - concat!
# resource  - concat!
# attempt  - concat!
# features  - concat!
# follows  - concat!
# march  - concat!
# php-file  - not in glove, random.normal!
# backdoors  - concat!
# look  - concat!
# he  - concat!
# though  - concat!
# responsible  - concat!
# important  - concat!
# registrant  - concat!
# kaspersky  - concat!
# developed  - concat!
# support  - concat!
# inside  - concat!
# create  - concat!
# thread  - concat!
# signed  - concat!
# downloaded  - concat!
# operating  - concat!
# help  - concat!
# start  - concat!
# hosted  - concat!
# sector  - concat!
# end  - concat!
# containing  - concat!
# links  - concat!
# library  - concat!
# 20  - concat!
# regin  - concat!
# framework  - concat!
# whether  - concat!
# technique  - concat!
# day  - concat!
# indicate  - concat!
# byte  - concat!
# might  - concat!
# 11  - concat!
# united  - concat!
# major  - concat!
# platform  - concat!
# indicates  - concat!
# national  - concat!
# range  - concat!
# people  - concat!
# typically  - concat!
# purpose  - concat!
# country  - concat!
# structure  - concat!
# online  - concat!
# methods  - concat!
# messages  - concat!
# researchers  - concat!
# year  - concat!
# site  - concat!
# 2011  - concat!
# media  - concat!
# private  - concat!
# global  - concat!
# form  - concat!
# linked  - concat!
# sophisticated  - concat!
# upon  - concat!
# october  - concat!
# russia  - concat!
# already  - concat!
# environment  - concat!
# significant  - concat!
# generated  - concat!
# due  - concat!
# reports  - concat!
# products  - concat!
# twitter  - concat!
# binaries  - concat!
# past  - concat!
# pivy  - not in glove, random.normal!
# investigation  - concat!
# collected  - concat!
# involved  - concat!
# checks  - concat!
# times  - concat!
# line  - concat!
# function-name  - not in glove, random.normal!
# algorithm  - concat!
# early  - concat!
# single  - concat!
# direct  - concat!
# simply  - concat!
# load  - concat!
# started  - concat!
# your  - concat!
# certificate  - concat!
# send  - concat!
# crew  - concat!
# listed  - concat!
# highly  - concat!
# device  - concat!
# compile  - concat!
# loaded  - concat!
# results  - concat!
# pdf  - concat!
# search  - concat!
# entry  - concat!
# vulnerabilities  - concat!
# hosting  - concat!
# operators  - concat!
# perform  - concat!
# critical  - concat!
# starts  - concat!
# base64  - concat!
# passwords  - concat!
# variety  - concat!
# gas  - concat!
# probably  - concat!
# seems  - concat!
# tranchulas  - not in glove, random.normal!
# reported  - concat!
# copy  - concat!
# output  - concat!
# interest  - concat!
# duqu  - not in glove, random.normal!
# publicly  - concat!
# small  - concat!
# script  - concat!
# change  - concat!
# event  - concat!
# political  - concat!
# energy  - concat!
# sites  - concat!
# poison  - concat!
# spear  - concat!
# author  - concat!
# four  - concat!
# hardcoded  - not in glove, random.normal!
# doc-file  - not in glove, random.normal!
# modified  - concat!
# university  - concat!
# ability  - concat!
# machines  - concat!
# install  - concat!
# others  - concat!
# registration  - concat!
# logs  - concat!
# certain  - concat!
# decrypted  - concat!
# keys  - concat!
# mentioned  - concat!
# loader  - concat!
# sophistication  - concat!
# ivy  - concat!
# continue  - concat!
# along  - concat!
# hacking  - concat!
# rather  - concat!
# working  - concat!
# potential  - concat!
# field  - concat!
# actual  - concat!
# recently  - concat!
# incidents  - concat!
# strategic  - concat!
# take  - concat!
# check  - concat!
# kernel  - concat!
# tcp  - concat!
# protection  - concat!
# syrian  - concat!
# certificates  - concat!
# apt28  - not in glove, random.normal!
# usually  - concat!
# currently  - concat!
# additionally  - concat!
# types  - concat!
# published  - concat!
# yet  - concat!
# difficult  - concat!
# hidden  - concat!
# individuals  - concat!
# resolved  - concat!
# symantec  - concat!
# long  - concat!
# share  - concat!
# 12  - concat!
# events  - concat!
# error  - concat!
# rights  - concat!
# specifically  - concat!
# red  - concat!
# persistent  - concat!
# dynamic  - concat!
# earlier  - concat!
# utc  - concat!
# object  - concat!
# devices  - concat!
# community  - concat!
# standard  - concat!
# unknown  - concat!
# project  - concat!
# among  - concat!
# monitoring  - concat!
# contact  - concat!
# appeared  - concat!
# lab  - concat!
# screenshot  - concat!
# need  - concat!
# default  - concat!
# explorer  - concat!
# profile  - concat!
# contents  - concat!
# popular  - concat!
# suggests  - concat!
# finspy  - not in glove, random.normal!
# international  - concat!
# implant  - concat!
# tactics  - concat!
# primary  - concat!
# office  - concat!
# asp-file  - not in glove, random.normal!
# drive  - concat!
# individual  - concat!
# developers  - concat!
# delivered  - concat!
# signature  - concat!
# noted  - concat!
# configured  - concat!
# calls  - concat!
# successful  - concat!
# 16  - concat!
# easily  - concat!
# down  - concat!
# drops  - concat!
# until  - concat!
# human  - concat!
# news  - concat!
# august  - concat!
# mail  - concat!
# plugins  - concat!
# cleaver  - concat!
# detailed  - concat!
# third  - concat!
# interface  - concat!
# attribution  - concat!
# allow  - concat!
# upload  - concat!
# finally  - concat!
# prior  - concat!
# know  - concat!
# steal  - concat!
# rats  - concat!
# decoded  - concat!
# paper  - concat!
# buffer  - concat!
# settings  - concat!
# less  - concat!
# separate  - concat!
# vector  - concat!
# taken  - concat!
# cozyduke  - not in glove, random.normal!
# space  - concat!
# far  - concat!
# done  - concat!
# 2010  - concat!
# sends  - concat!
# nature  - concat!
# established  - concat!
# future  - concat!
# dat-file  - not in glove, random.normal!
# series  - concat!
# industries  - concat!
# gain  - concat!
# creating  - concat!
# virtual  - concat!
# maintain  - concat!
# left  - concat!
# 14  - concat!
# power  - concat!
# financial  - concat!
# looks  - concat!
# instances  - concat!
# show  - concat!
# antivirus  - concat!
# making  - concat!
# hide  - concat!
# 64-bit  - concat!
# callback  - concat!
# saved  - concat!
# almost  - concat!
# specified  - concat!
# presence  - concat!
# successfully  - concat!
# archive  - concat!
# revealed  - concat!
# fake  - concat!
# product  - concat!
# followed  - concat!
# management  - concat!
# mode  - concat!
# members  - concat!
# limited  - concat!
# looking  - concat!
# june  - concat!
# together  - concat!
# families  - concat!
# examples  - concat!
# therefore  - concat!
# parameters  - concat!
# protect  - concat!
# org  - concat!
# again  - concat!
# exploitation  - concat!
# required  - concat!
# attachment  - concat!
# trojans  - concat!
# place  - concat!
# flash  - concat!
# entities  - concat!
# e-mails  - concat!
# hard  - concat!
# executing  - concat!
# sending  - concat!
# intended  - concat!
# traditional  - concat!
# effort  - concat!
# authors  - concat!
# random  - concat!
# basic  - concat!
# log-file  - not in glove, random.normal!
# little  - concat!
# clear  - concat!
# implemented  - concat!
# existing  - concat!
# whois  - concat!
# browser  - concat!
# intrusion  - concat!
# potentially  - concat!
# uploaded  - concat!
# changes  - concat!
# warfare  - concat!
# build  - concat!
# decrypt  - concat!
# context  - concat!
# prevent  - concat!
# behavior  - concat!
# attachments  - concat!
# 00  - concat!
# suggest  - concat!
# ips  - concat!
# routine  - concat!
# android  - concat!
# iranian  - concat!
# allowed  - concat!
# packet  - concat!
# business  - concat!
# governments  - concat!
# study  - concat!
# programs  - concat!
# conflict  - concat!
# older  - concat!
# rsa  - concat!
# dword  - not in glove, random.normal!
# zero-day  - concat!
# downloader  - concat!
# persistence  - concat!
# months  - concat!
# special  - concat!
# body  - concat!
# distributed  - concat!
# hosts  - concat!
# obtained  - concat!
# issues  - concat!
# visual  - concat!
# desktop  - concat!
# zxshell  - not in glove, random.normal!
# beginning  - concat!
# view  - concat!
# outside  - concat!
# builder  - concat!
# policy  - concat!
# applications  - concat!
# mobile  - concat!
# 17  - concat!
# hashes  - concat!
# characters  - concat!
# export  - concat!
# spear-phishing  - not in glove, random.normal!
# blackenergy  - not in glove, random.normal!
# why  - concat!
# avoid  - concat!
# htm-file  - not in glove, random.normal!
# themselves  - concat!
# distribution  - concat!
# pages  - concat!
# connects  - concat!
# commonly  - concat!
# startup  - concat!
# documented  - concat!
# updated  - concat!
# middle  - concat!
# 000  - concat!
# february  - concat!
# signatures  - concat!
# five  - concat!
# 21  - concat!
# industrial  - concat!
# beacon  - concat!
# 19  - concat!
# shanghai  - concat!
# monitor  - concat!
# always  - concat!
# focused  - concat!
# rc4  - concat!
# communicate  - concat!
# changed  - concat!
# txt-file  - not in glove, random.normal!
# clearly  - concat!
# september  - concat!
# january  - concat!
# thus  - concat!
# locations  - concat!
# enough  - concat!
# seem  - concat!
# mechanism  - concat!
# quite  - concat!
# task  - concat!
# european  - concat!
# cloud  - concat!
# base  - concat!
# total  - concat!
# top  - concat!
# parameter  - concat!
# free  - concat!
# 15  - concat!
# 25  - concat!
# affected  - concat!
# sensitive  - concat!
# launched  - concat!
# handle  - concat!
# discussed  - concat!
# depending  - concat!
# identical  - concat!
# hook  - concat!
# obtain  - concat!
# phone  - concat!
# hackers  - concat!
# step  - concat!
# april  - concat!
# opened  - concat!
# os  - concat!
# executes  - concat!
# general  - concat!
# english  - concat!
# debug  - concat!
# possibly  - concat!
# executables  - concat!
# plugin  - concat!
# compressed  - concat!
# period  - concat!
# ms  - concat!
# immediately  - concat!
# interestingly  - concat!
# efforts  - concat!
# snake  - concat!
# rootkit  - concat!
# pattern  - concat!
# tasks  - concat!
# department  - concat!
# focus  - concat!
# exe  - concat!
# babar  - concat!
# miniduke  - not in glove, random.normal!
# comes  - concat!
# low  - concat!
# purposes  - concat!
# foreign  - concat!
# channel  - concat!
# read  - concat!
# ensure  - concat!
# 2009  - concat!
# relevant  - concat!
# referred  - concat!
# added  - concat!
# installation  - concat!
# indian  - concat!
# actually  - concat!
# tcirt  - not in glove, random.normal!
# solutions  - concat!
# party  - concat!
# old  - concat!
# days  - concat!
# offset  - concat!
# runs  - concat!
# class  - concat!
# particularly  - concat!
# obfuscation  - concat!
# pcc  - concat!
# nuclear  - concat!
# sectors  - concat!
# please  - concat!
# especially  - concat!
# login  - concat!
# determine  - concat!
# strong  - concat!
# effective  - concat!
# bit  - concat!
# collection  - concat!
# corresponding  - concat!
# drives  - concat!
# said  - concat!
# perhaps  - concat!
# japan  - concat!
# longer  - concat!
# infect  - concat!
# loop  - concat!
# stealing  - concat!
# updates  - concat!
# distinct  - concat!
# official  - concat!
# reason  - concat!
# input  - concat!
# began  - concat!
# apparently  - concat!
# 22  - concat!
# quickly  - concat!
# points  - concat!
# uri  - concat!
# compilation  - concat!
# plugx  - not in glove, random.normal!
# widely  - concat!
# knowledge  - concat!
# attributed  - concat!
# creation  - concat!
# confirmed  - concat!
# 13  - concat!
# ini-file  - not in glove, random.normal!
# area  - concat!
# home  - concat!
# ports  - concat!
# calling  - concat!
# capable  - concat!
# army  - concat!
# stages  - concat!
# installer  - concat!
# javascript  - concat!
# corporate  - concat!
# managed  - concat!
# represents  - concat!
# commercial  - concat!
# external  - concat!
# war  - concat!
# consistent  - concat!
# shares  - concat!
# wiper  - concat!
# throughout  - concat!
# inc  - concat!
# 61398  - not in glove, random.normal!
# conducted  - concat!
# operate  - concat!
# lists  - concat!
# per  - concat!
# loads  - concat!
# libraries  - concat!
# december  - concat!
# majority  - concat!
# frequently  - concat!
# terms  - concat!
# posted  - concat!
# writing  - concat!
# center  - concat!
# adversary  - concat!
# having  - concat!
# 26  - concat!
# connecting  - concat!
# dino  - concat!
# le  - concat!
# isis  - concat!
# right  - concat!
# theft  - concat!
# anti-virus  - concat!
# detail  - concat!
# initially  - concat!
# injected  - concat!
# identifier  - concat!
# ongoing  - concat!
# launch  - concat!
# released  - concat!
# reveals  - concat!
# core  - concat!
# taking  - concat!
# latest  - concat!
# spread  - concat!
# suspicious  - concat!
# aes  - concat!
# av  - concat!
# 30  - concat!
# info  - concat!
# html  - concat!
# extension  - concat!
# 24  - concat!
# believed  - concat!
# ddos  - concat!
# panda  - concat!
# icefog  - not in glove, random.normal!
# become  - concat!
# amount  - concat!
# exfiltration  - concat!
# agent  - concat!
# scripts  - concat!
# conduct  - concat!
# impact  - concat!
# submitted  - concat!
# supported  - concat!
# feature  - concat!
# india  - concat!
# reference  - concat!
# damage  - concat!
# pla  - concat!
# sources  - concat!
# etc  - concat!
# tmp-file  - not in glove, random.normal!
# provider  - concat!
# write  - concat!
# go  - concat!
# deployed  - concat!
# 32-bit  - concat!
# supports  - concat!
# exist  - concat!
# east  - concat!
# adobe  - concat!
# identifying  - concat!
# drop  - concat!
# numbers  - concat!
# comfoo  - not in glove, random.normal!
# php  - concat!
# never  - concat!
# track  - concat!
# collect  - concat!
# valid  - concat!
# performed  - concat!
# providing  - concat!
# region  - concat!
# apis  - concat!
# delivery  - concat!
# copies  - concat!
# approach  - concat!
# ing  - concat!
# screen  - concat!
# piece  - concat!
# continues  - concat!
# presented  - concat!
# description  - concat!
# capability  - concat!
# risk  - concat!
# tinyzbot  - not in glove, random.normal!
# chain  - concat!
# reconnaissance  - concat!
# opposition  - concat!
# register  - concat!
# command-and-control  - concat!
# decrypts  - concat!
# filenames  - concat!
# off  - concat!
# requires  - concat!
# master  - concat!
# character  - concat!
# numerous  - concat!
# 23  - concat!
# bitterbug  - not in glove, random.normal!
# troy  - concat!
# ftp  - concat!
# admin  - concat!
# consists  - concat!
# parts  - concat!
# increase  - concat!
# course  - concat!
# come  - concat!
# issue  - concat!
# 100  - concat!
# late  - concat!
# firewall  - concat!
# static  - concat!
# entity  - concat!
# month  - concat!
# obfuscated  - concat!
# listing  - concat!
# 01  - concat!
# window  - concat!
# comment  - concat!
# largest  - concat!
# generally  - concat!
# effectively  - concat!
# property  - concat!
# refer  - concat!
# attention  - concat!
# exists  - concat!
# cve-2012-0158  - not in glove, random.normal!
# test  - concat!
# extracted  - concat!
# operational  - concat!
# personal  - concat!
# technologies  - concat!
# complex  - concat!
# headers  - concat!
# something  - concat!
# codes  - concat!
# understanding  - concat!
# decryption  - concat!
# japanese  - concat!
# seconds  - concat!
# payloads  - concat!
# primarily  - concat!
# agencies  - concat!
# trend  - concat!
# economic  - concat!
# breach  - concat!
# real-time  - concat!
# enterprise  - concat!
# 18  - concat!
# vpsnoc  - not in glove, random.normal!
# pakistan  - concat!
# tti  - concat!
# cloudduke  - not in glove, random.normal!
# follow  - concat!
# built  - concat!
# logging  - concat!
# variable  - concat!
# characteristics  - concat!
# remains  - concat!
# larger  - concat!
# overall  - concat!
# interests  - concat!
# hacker  - concat!
# despite  - concat!
# handshake  - concat!
# typical  - concat!
# keylogger  - concat!
# virus  - concat!
# tiger  - concat!
# ranges  - concat!
# record  - concat!
# sys-file  - not in glove, random.normal!
# similarities  - concat!
# username  - concat!
# give  - concat!
# automatically  - concat!
# package  - concat!
# normal  - concat!
# storage  - concat!
# aware  - concat!
# activists  - concat!
# database  - concat!
# urls  - concat!
# occurred  - concat!
# resulting  - concat!
# better  - concat!
# protected  - concat!
# length  - concat!
# actively  - concat!
# unclear  - concat!
# reportedly  - concat!
# scanbox  - not in glove, random.normal!
# khan  - concat!
# pitty  - concat!
# lack  - concat!
# understand  - concat!
# gathering  - concat!
# discovery  - concat!
# communicates  - concat!
# useful  - concat!
# suspect  - concat!
# relationship  - concat!
# indicating  - concat!
# gets  - concat!
# hundreds  - concat!
# user-agent  - not in glove, random.normal!
# institutions  - concat!
# wide  - concat!
# hours  - concat!
# exploited  - concat!
# difference  - concat!
# ministry  - concat!
# infections  - concat!
# true  - concat!
# history  - concat!
# turla  - not in glove, random.normal!
# remain  - concat!
# cluster  - concat!
# jar-file  - not in glove, random.normal!
# customers  - concat!
# saw  - concat!
# downloads  - concat!
# administration  - concat!
# keep  - concat!
# scanning  - concat!
# person  - concat!
# developer  - concat!
# authentication  - concat!
# entries  - concat!
# leveraged  - concat!
# sharing  - concat!
# fully  - concat!
# writes  - concat!
# import  - concat!
# deliver  - concat!
# zip  - concat!
# needed  - concat!
# begins  - concat!
# procedures  - concat!
# question  - concat!
# attributes  - concat!
# intruders  - concat!
# employees  - concat!
# intellectual  - concat!
# generic  - concat!
# model  - concat!
# locate  - concat!
# sets  - concat!
# deleted  - concat!
# well-known  - concat!
# vulnerable  - concat!
# bahrain  - concat!
# syria  - concat!
# cybercriminals  - concat!
# scan  - concat!
# surveillance  - concat!
# displayed  - concat!
# dates  - concat!
# encoding  - concat!
# personnel  - concat!
# session  - concat!
# best  - concat!
# otherwise  - concat!
# obvious  - concat!
# going  - concat!
# beijing  - concat!
# crowdstrike  - not in glove, random.normal!
# etso  - not in glove, random.normal!
# complete  - concat!
# usage  - concat!
# compared  - concat!
# phase  - concat!
# rely  - concat!
# trick  - concat!
# receive  - concat!
# turn  - concat!
# easy  - concat!
# hong  - concat!
# kong  - concat!
# showed  - concat!
# professional  - concat!
# safe  - concat!
# analyze  - concat!
# video  - concat!
# records  - concat!
# whose  - concat!
# apparent  - concat!
# belonging  - concat!
# vectors  - concat!
# serve  - concat!
# close  - concat!
# timestamp  - concat!
# paths  - concat!
# properly  - concat!
# heavily  - concat!
# ie  - concat!
# config  - concat!
# percent  - concat!
# lynx  - concat!
# release  - concat!
# actions  - concat!
# attached  - concat!
# watering  - concat!
# visitors  - concat!
# rtf  - concat!
# copied  - concat!
# sign  - concat!
# rar  - concat!
# operator  - concat!
# references  - concat!
# modification  - concat!
# starting  - concat!
# represent  - concat!
# interested  - concat!
# steps  - concat!
# installs  - concat!
# implements  - concat!
# nt  - concat!
# building  - concat!
# toolset  - concat!
# consider  - concat!
# virustotal  - not in glove, random.normal!
# issued  - concat!
# findings  - concat!
# droppers  - concat!
# taiwan  - concat!
# relatively  - concat!
# endpoint  - concat!
# market  - concat!
# darkhotel  - not in glove, random.normal!
# customized  - concat!
# hikit  - not in glove, random.normal!
# score  - concat!
# transfer  - concat!
# patterns  - concat!
# testing  - concat!
# downloading  - concat!
# generate  - concat!
# necessary  - concat!
# great  - concat!
# loading  - concat!
# cause  - concat!
# sometimes  - concat!
# subject  - concat!
# good  - concat!
# action  - concat!
# option  - concat!
# replaced  - concat!
# nation  - concat!
# htran  - not in glove, random.normal!
# asia  - concat!
# www  - concat!
# generation  - concat!
# procedure  - concat!
# goal  - concat!
# unusual  - concat!
# visit  - concat!
# movement  - concat!
# gives  - concat!
# noticed  - concat!
# extract  - concat!
# mcafee  - concat!
# agency  - concat!
# continued  - concat!
# enable  - concat!
# week  - concat!
# analysts  - concat!
# performs  - concat!
# bypass  - concat!
# pointed  - concat!
# problem  - concat!
# visibility  - concat!
# employed  - concat!
# design  - concat!
# clusters  - concat!
# evade  - concat!
# strategy  - concat!
# final  - concat!
# controls  - concat!
# quick  - concat!
# minutes  - concat!
# require  - concat!
# recovered  - concat!
# utilized  - concat!
# offensive  - concat!
# cmd-param  - not in glove, random.normal!
# 06  - concat!
# pdb-file  - not in glove, random.normal!
# worldwide  - concat!
# bp  - concat!
# terminator  - concat!
# apt1s  - not in glove, random.normal!
# considered  - concat!
# telecommunications  - concat!
# hole  - concat!
# administrator  - concat!
# temporary  - concat!
# communicating  - concat!
# wild  - concat!
# allowing  - concat!
# hooks  - concat!
# store  - concat!
# works  - concat!
# removed  - concat!
# volume  - concat!
# uncovered  - concat!
# defenses  - concat!
# tracking  - concat!
# suspected  - concat!
# tibetan  - concat!
# capture  - concat!
# beyond  - concat!
# secondary  - concat!
# ssl  - concat!
# 80  - concat!
# 2007  - concat!
# randomly  - concat!
# labs  - concat!
# production  - concat!
# joint  - concat!
# iocs  - concat!
# implementation  - concat!
# etumbot  - not in glove, random.normal!
# showing  - concat!
# mutex  - not in glove, random.normal!
# runtime  - concat!
# member  - concat!
# develop  - concat!
# mandiant  - not in glove, random.normal!
# article  - concat!
# platforms  - concat!
# clients  - concat!
# flow  - concat!
# arbitrary  - concat!
# metasploit  - concat!
# anonymous  - concat!
# took  - concat!
# facebook  - concat!
# attempted  - concat!
# forensic  - concat!
# query  - concat!
# zone  - concat!
# lure  - concat!
# move  - concat!
# directories  - concat!
# 40  - concat!
# determined  - concat!
# 3rd  - concat!
# scale  - concat!
# threatconnect  - not in glove, random.normal!
# sha1  - not in glove, random.normal!
# dark  - concat!
# sunshop  - not in glove, random.normal!
# kim  - concat!
# winnti  - not in glove, random.normal!
# cosmu  - not in glove, random.normal!
# fin4  - not in glove, random.normal!
# today  - concat!
# experience  - concat!
# ways  - concat!
# privileges  - concat!
# aspects  - concat!
# decoding  - concat!
# unlike  - concat!
# kind  - concat!
# city  - concat!
# compromises  - concat!
# blocks  - concat!
# physical  - concat!
# controlled  - concat!
# opening  - concat!
# artifacts  - concat!
# notable  - concat!
# legal  - concat!
# served  - concat!
# pdf-file  - not in glove, random.normal!
# electronic  - concat!
# november  - concat!
# 50  - concat!
# tries  - concat!
# providers  - concat!
# diplomatic  - concat!
# training  - concat!
# collects  - concat!
# achieve  - concat!
# my  - concat!
# keyboard  - concat!
# 09  - concat!
# checking  - concat!
# game  - concat!
# unfortunately  - concat!
# originally  - concat!
# malwares  - not in glove, random.normal!
# temp  - concat!
# putter  - concat!
# cpyy  - not in glove, random.normal!
# bit9  - not in glove, random.normal!
# yy  - concat!
# scheme  - concat!
# employee  - concat!
# origin  - concat!
# injection  - concat!
# vendors  - concat!
# familiar  - concat!
# analyzing  - concat!
# xp  - concat!
# largely  - concat!
# projects  - concat!
# derived  - concat!
# carried  - concat!
# hard-coded  - concat!
# receives  - concat!
# uploads  - concat!
# pipe  - concat!
# encrypt  - concat!
# msie  - not in glove, random.normal!
# involvement  - concat!
# njrat  - not in glove, random.normal!
# offers  - concat!
# 443  - concat!
# nations  - concat!
# instructions  - concat!
# metadata  - concat!
# europe  - concat!
# co  - concat!
# ve  - concat!
# searches  - concat!
# ads  - concat!
# extremely  - concat!
# secure  - concat!
# properties  - concat!
# lead  - concat!
# reasons  - concat!
# botnet  - concat!
# enables  - concat!
# app  - concat!
# installing  - concat!
# micro  - concat!
# nettraveler  - not in glove, random.normal!
# white  - concat!
# exclusively  - concat!
# gh0st  - not in glove, random.normal!
# insight  - concat!
# automated  - concat!
# controller  - concat!
# ones  - concat!
# six  - concat!
# options  - concat!
# unable  - concat!
# came  - concat!
# goes  - concat!
# conducting  - concat!
# act  - concat!
# trigger  - concat!
# timeline  - concat!
# reverse  - concat!
# drivers  - concat!
# timestamps  - concat!
# applied  - concat!
# reads  - concat!
# incoming  - concat!
# engine  - concat!
# manner  - concat!
# increasingly  - concat!
# presumably  - concat!
# usb  - concat!
# bureau  - concat!
# 02  - concat!
# sleep  - concat!
# criminal  - concat!
# gather  - concat!
# pakistani  - concat!
# checked  - concat!
# return  - concat!
# advantage  - concat!
# privacy  - concat!
# linux  - concat!
# differences  - concat!
# education  - concat!
# pdb  - concat!
# constant  - concat!
# apt-file  - not in glove, random.normal!
# reveal  - concat!
# takes  - concat!
# lateral  - concat!
# compatible  - concat!
# furthermore  - concat!
# try  - concat!
# mainly  - concat!
# former  - concat!
# describe  - concat!
# toolkit  - concat!
# defined  - concat!
# root  - concat!
# expected  - concat!
# stores  - concat!
# keystrokes  - concat!
# central  - concat!
# match  - concat!
# suggesting  - concat!
# delete  - concat!
# matches  - concat!
# background  - concat!
# objective  - concat!
# entire  - concat!
# exact  - concat!
# success  - concat!
# fields  - concat!
# mac  - concat!
# chosen  - concat!
# 2nd  - concat!
# binder  - concat!
# weapons  - concat!
# led  - concat!
# establish  - concat!
# aka  - concat!
# newly  - concat!
# regarding  - concat!
# retrieve  - concat!
# lot  - concat!
# subdomains  - concat!
# someone  - concat!
# elements  - concat!
# dedicated  - concat!
# too  - concat!
# dlls  - concat!
# extensive  - concat!
# anyone  - concat!
# jpg-file  - not in glove, random.normal!
# vary  - concat!
# newer  - concat!
# returned  - concat!
# half  - concat!
# portion  - concat!
# stated  - concat!
# tags  - concat!
# manually  - concat!
# cookie  - concat!
# awareness  - concat!
# visible  - concat!
# let  - concat!
# magic  - concat!
# denial  - concat!
# initialization  - concat!
# side  - concat!
# batch  - concat!
# cylance  - not in glove, random.normal!
# havex  - not in glove, random.normal!
# fqdns  - not in glove, random.normal!
# parties  - concat!
# mission  - concat!
# dump  - concat!
# protocols  - concat!
# identity  - concat!
# exception  - concat!
# exposed  - concat!
# exactly  - concat!
# words  - concat!
# assigned  - concat!
# similarly  - concat!
# highlighted  - concat!
# serves  - concat!
# opens  - concat!
# mbr  - concat!
# channels  - concat!
# rcs  - concat!
# tor  - concat!
# overlap  - concat!
# begin  - concat!
# onto  - concat!
# consistently  - concat!
# chopstick  - concat!
# ids  - concat!
# appended  - concat!
# pieces  - concat!
# malvertising  - not in glove, random.normal!
# display  - concat!
# stop  - concat!
# doc  - concat!
# 27  - concat!
# status  - concat!
# teams  - concat!
# irc  - concat!
# destructive  - concat!
# maintains  - concat!
# redacted  - concat!
# sabotage  - concat!
# put  - concat!
# apt12  - not in glove, random.normal!
# cmstar  - not in glove, random.normal!
# decided  - concat!
# relies  - concat!
# apart  - concat!
# pass  - concat!
# images  - concat!
# map  - concat!
# firm  - concat!
# receiving  - concat!
# themes  - concat!
# regional  - concat!
# relationships  - concat!
# proprietary  - concat!
# 42  - concat!
# approximately  - concat!
# 60  - concat!
# clr  - concat!
# reporting  - concat!
# categories  - concat!
# false  - concat!
# ics  - concat!
# israel  - concat!
# tlp  - concat!
# hop  - concat!
# defenders  - concat!
# corporation  - concat!
# xls-file  - not in glove, random.normal!
# telenor  - concat!
# sayad  - concat!
# leverage  - concat!
# fairly  - concat!
# click  - concat!
# objectives  - concat!
# hope  - concat!
# exploiting  - concat!
# confirm  - concat!
# attacking  - concat!
# btz-file  - not in glove, random.normal!
# meaning  - concat!
# architecture  - concat!
# modern  - concat!
# 28  - concat!
# socket  - concat!
# accessible  - concat!
# stack  - concat!
# setting  - concat!
# passed  - concat!
# processing  - concat!
# 2008  - concat!
# cycle  - concat!
# intercept  - concat!
# 32  - concat!
# communicated  - concat!
# re-  - not in glove, random.normal!
# modify  - concat!
# relative  - concat!
# performing  - concat!
# areas  - concat!
# referenced  - concat!
# implement  - concat!
# methodology  - concat!
# 04  - concat!
# rest  - concat!
# decode  - concat!
# rate  - concat!
# notice  - concat!
# mechanisms  - concat!
# proxies  - concat!
# firms  - concat!
# 45  - concat!
# distribute  - concat!
# utilize  - concat!
# extensions  - concat!
# live  - concat!
# correct  - concat!
# inf-file  - not in glove, random.normal!
# removable  - concat!
# higher  - concat!
# assets  - concat!
# owned  - concat!
# derusbi  - not in glove, random.normal!
# experts  - concat!
# short  - concat!
# picture  - concat!
# attacked  - concat!
# python  - concat!
# goals  - concat!
# hammertoss  - not in glove, random.normal!
# evilgrab  - not in glove, random.normal!
# db  - concat!
# csos  - concat!
# menupass  - not in glove, random.normal!
# dubbed  - concat!
# crafted  - concat!
# doing  - concat!
# evolution  - concat!
# subsequent  - concat!
# researcher  - concat!
# belong  - concat!
# traces  - concat!
# choice  - concat!
# organisations  - concat!
# respond  - concat!
# exports  - concat!
# reach  - concat!
# boot  - concat!
# needs  - concat!
# patched  - concat!
# certainly  - concat!
# adversaries  - concat!
# redirected  - concat!
# role  - concat!
# spy  - concat!
# adds  - concat!
# forces  - concat!
# combination  - concat!
# examined  - concat!
# observe  - concat!
# wait  - concat!
# tied  - concat!
# seven  - concat!
# placed  - concat!
# possibility  - concat!
# orcarat  - not in glove, random.normal!
# valuable  - concat!
# nearly  - concat!
# earliest  - concat!
# packets  - concat!
# flag  - concat!
# american  - concat!
# canada  - concat!
# outlook  - concat!
# operated  - concat!
# involving  - concat!
# valves  - concat!
# chopper  - concat!
# searching  - concat!
# mostly  - concat!
# exfiltrate  - not in glove, random.normal!
# sandbox  - concat!
# transmitted  - concat!
# screenshots  - concat!
# folders  - concat!
# carry  - concat!
# advertising  - concat!
# deep  - concat!
# powerful  - concat!
# measures  - concat!
# passive  - concat!
# claim  - concat!
# ties  - concat!
# cybercrime  - concat!
# ever  - concat!
# life  - concat!
# increasing  - concat!
# tion  - concat!
# trusted  - concat!
# tactic  - concat!
# kit  - concat!
# fixed  - concat!
# germany  - concat!
# rules  - concat!
# eastern  - concat!
# combined  - concat!
# implants  - concat!
# credential  - concat!
# modifications  - concat!
# organized  - concat!
# sid  - concat!
# uploading  - concat!
# pointer  - concat!
# ttps  - not in glove, random.normal!
# failed  - concat!
# player  - concat!
# redirect  - concat!
# zero  - concat!
# nothing  - concat!
# automatic  - concat!
# native  - concat!
# https  - concat!
# unlikely  - concat!
# utility  - concat!
# penetration  - concat!
# cmd  - concat!
# detections  - concat!
# hijacking  - concat!
# ajax  - concat!
# icon  - concat!
# prevention  - concat!
# completely  - concat!
# sea  - concat!
# duke  - concat!
# hwp  - concat!
# poisonivy  - not in glove, random.normal!
# smoaler  - not in glove, random.normal!
# professionals  - concat!
# coming  - concat!
# things  - concat!
# mean  - concat!
# transferred  - concat!
# rdp  - concat!
# province  - concat!
# usa  - concat!
# firewalls  - concat!
# routines  - concat!
# levels  - concat!
# patch  - concat!
# cyber-espionage  - not in glove, random.normal!
# claims  - concat!
# appropriate  - concat!
# com-  - not in glove, random.normal!
# webpage  - concat!
# extended  - concat!
# supplied  - concat!
# subsequently  - concat!
# uk  - concat!
# remaining  - concat!
# environments  - concat!
# tailored  - concat!
# hostname  - concat!
# index  - concat!
# cover  - concat!
# bidding  - concat!
# 0-day  - not in glove, random.normal!
# highest  - concat!
# yahoo  - concat!
# recipient  - concat!
# hold  - concat!
# configurations  - concat!
# units  - concat!
# add  - concat!
# 64  - concat!
# summary  - concat!
# compression  - concat!
# gif  - concat!
# attribute  - concat!
# door  - concat!
# operates  - concat!
# staff  - concat!
# selected  - concat!
# law  - concat!
# seoul  - concat!
# xshell  - not in glove, random.normal!
# stay  - concat!
# describes  - concat!
# everything  - concat!
# gained  - concat!
# want  - concat!
# indicated  - concat!
# sections  - concat!
# cs  - concat!
# thousands  - concat!
# internally  - concat!
# exchange  - concat!
# leveraging  - concat!
# fingerprint  - concat!
# weeks  - concat!
# scope  - concat!
# comprehensive  - concat!
# refers  - concat!
# except  - concat!
# fails  - concat!
# bits  - concat!
# force  - concat!
# posts  - concat!
# job  - concat!
# packaged  - concat!
# play  - concat!
# gui  - concat!
# self-extracting  - not in glove, random.normal!
# relay  - concat!
# 35  - concat!
# yara  - concat!
# 31  - concat!
# serious  - concat!
# citizen  - concat!
# citizens  - concat!
# nato  - concat!
# light  - concat!
# letter  - concat!
# originating  - concat!
# exported  - concat!
# remove  - concat!
# ixeshe  - not in glove, random.normal!
# tag  - concat!
# generates  - concat!
# epic  - concat!
# select  - concat!
# blue  - concat!
# towards  - concat!
# 05  - concat!
# face  - concat!
# programming  - concat!
# administrators  - concat!
# hacked  - concat!
# forum  - concat!
# launcher  - concat!
# resolution  - concat!
# pressure  - concat!
# sql  - concat!
# republic  - concat!
# be2  - concat!
# doesnt  - concat!
# ke3chang  - not in glove, random.normal!
# expect  - concat!
# attempting  - concat!
# finding  - concat!
# break  - concat!
# infecting  - concat!
# sure  - concat!
# regular  - concat!
# empty  - concat!
# belongs  - concat!
# indeed  - concat!
# position  - concat!
# manager  - concat!
# offer  - concat!
# overview  - concat!
# networking  - concat!
# detects  - concat!
# save  - concat!
# places  - concat!
# vista  - concat!
# serving  - concat!
# sequence  - concat!
# enabled  - concat!
# disable  - concat!
# demonstrated  - concat!
# spyware  - concat!
# in-  - not in glove, random.normal!
# hand  - concat!
# civil  - concat!
# whereas  - concat!
# deletes  - concat!
# captured  - concat!
# logged  - concat!
# firefox  - concat!
# discover  - concat!
# forums  - concat!
# resulted  - concat!
# me  - concat!
# latter  - concat!
# finfisher  - not in glove, random.normal!
# independent  - concat!
# western  - concat!
# identifies  - concat!
# motivated  - concat!
# assume  - concat!
# alert  - concat!
# trust  - concat!
# considering  - concat!
# globe  - concat!
# launches  - concat!
# comparison  - concat!
# enterprises  - concat!
# hooking  - concat!
# 07  - concat!
# economy  - concat!
# xored  - not in glove, random.normal!
# shamoon  - concat!
# aerospace  - concat!
# messenger  - concat!
# archives  - concat!
# officials  - concat!
# apt29  - not in glove, random.normal!
# 121  - concat!
# inc-file  - not in glove, random.normal!
# deepwater  - concat!
# horizon  - concat!
# kill  - concat!
# press  - concat!
# publication  - concat!
# whole  - concat!
# say  - concat!
# naming  - concat!
# connectivity  - concat!
# cipher  - concat!
# bots  - concat!
# think  - concat!
# comments  - concat!
# simplified  - concat!
# affairs  - concat!
# story  - concat!
# respectively  - concat!
# doesn  - concat!
# returns  - concat!
# demonstrates  - concat!
# identification  - concat!
# inspection  - concat!
# basis  - concat!
# indication  - concat!
# 200  - concat!
# accessing  - concat!
# signing  - concat!
# worth  - concat!
# secrets  - concat!
# uae  - concat!
# underground  - concat!
# contrast  - concat!
# term  - concat!
# contacted  - concat!
# became  - concat!
# union  - concat!
# interaction  - concat!
# saudi  - concat!
# accept  - concat!
# lures  - concat!
# sourface  - not in glove, random.normal!
# closely  - concat!
# cooperation  - concat!
# demonstrate  - concat!
# headquarters  - concat!
# ru  - concat!
# observations  - concat!
# threads  - concat!
# sense  - concat!
# becomes  - concat!
# win  - concat!
# reader  - concat!
# blocking  - concat!
# greater  - concat!
# webdav  - concat!
# classes  - concat!
# indications  - concat!
# stub  - concat!
# 08  - concat!
# hex  - concat!
# idea  - concat!
# statistics  - concat!
# conjunction  - concat!
# ir  - concat!
# mitm  - not in glove, random.normal!
# dangerous  - concat!
# scada  - concat!
# supply  - concat!
# topsec  - not in glove, random.normal!
# rss  - concat!
# zip-file  - not in glove, random.normal!
# fidelis  - concat!
# specic  - not in glove, random.normal!
# teamviewer  - not in glove, random.normal!
# dragonok  - not in glove, random.normal!
# bs2005  - not in glove, random.normal!
# non-state  - concat!
# destory  - not in glove, random.normal!
# moudoor  - not in glove, random.normal!
# visited  - concat!
# thanks  - concat!
# inject  - concat!
# manage  - concat!
# interact  - concat!
# retrieved  - concat!
# big  - concat!
# logistics  - concat!
# customer  - concat!
# couple  - concat!
# ago  - concat!
# conclusion  - concat!
# handler  - concat!
# normally  - concat!
# forward  - concat!
# identifiers  - concat!
# perspective  - concat!
# evolved  - concat!
# third-party  - concat!
# large-scale  - concat!
# engaged  - concat!
# house  - concat!
# telecom  - concat!
# growing  - concat!
# somewhat  - concat!
# modular  - concat!
# presents  - concat!
# indicative  - concat!
# 29  - concat!
# collecting  - concat!
# don  - concat!
# topics  - concat!
# alone  - concat!
# minor  - concat!
# detecting  - concat!
# studio  - concat!
# 43  - concat!
# packages  - concat!
# strategies  - concat!
# router  - concat!
# regardless  - concat!
# confidence  - concat!
# listening  - concat!
# wiping  - concat!
# 4-byte  - concat!
# xml  - concat!
# sinkhole  - concat!
# apps  - concat!
# marker  - concat!
# safety  - concat!
# significantly  - concat!
# assumed  - concat!
# hack  - concat!
# games  - concat!
# gaming  - concat!
# steals  - concat!
# voho  - not in glove, random.normal!
# gang  - concat!
# travnet  - not in glove, random.normal!
# developing  - concat!
# state-sponsored  - concat!
# involves  - concat!
# acquisition  - concat!
# lines  - concat!
# soon  - concat!
# anything  - concat!
# ct  - concat!
# translated  - concat!
# adding  - concat!
# serial  - concat!
# remotely  - concat!
# gathered  - concat!
# indicator  - concat!
# questions  - concat!
# classified  - concat!
# uroburos  - not in glove, random.normal!
# establishing  - concat!
# notification  - concat!
# passes  - concat!
# introduced  - concat!
# opportunity  - concat!
# dir  - concat!
# gamma  - concat!
# circumstantial  - concat!
# importance  - concat!
# con-  - not in glove, random.normal!
# journalists  - concat!
# necessarily  - concat!
# fall  - concat!
# de-  - not in glove, random.normal!
# smaller  - concat!
# pc  - concat!
# reading  - concat!
# leaving  - concat!
# clean  - concat!
# hit  - concat!
# nor  - concat!
# communities  - concat!
# videos  - concat!
# increased  - concat!
# packed  - concat!
# employ  - concat!
# coding  - concat!
# trying  - concat!
# satellite  - concat!
# cpu  - concat!
# went  - concat!
# spying  - concat!
# thing  - concat!
# ultimately  - concat!
# deploy  - concat!
# rule  - concat!
# ll  - concat!
# carbon  - concat!
# invincea  - not in glove, random.normal!
# manufacturing  - concat!
# directed  - concat!
# highlight  - concat!
# decodes  - concat!
# ascii  - concat!
# situation  - concat!
# linx  - concat!
# loss  - concat!
# raw  - concat!
# animal  - concat!
# farm  - concat!
# exit  - concat!
# 2001  - concat!
# maintained  - concat!
# aspect  - concat!
# clipboard  - concat!
# night  - concat!
# onedrive  - not in glove, random.normal!
# 46  - concat!
# volexity  - not in glove, random.normal!
# defend  - concat!
# seaduke  - not in glove, random.normal!
# cosmicduke  - not in glove, random.normal!
# les  - concat!
# freegate  - not in glove, random.normal!
# investigations  - concat!
# arsenal  - concat!
# excel  - concat!
# delivering  - concat!
# scanned  - concat!
# triggered  - concat!
# achieved  - concat!
# acquire  - concat!
# console  - concat!
# pack  - concat!
# governmental  - concat!
# turned  - concat!
# chunk  - concat!
# pipes  - concat!
# illustrates  - concat!
# outbound  - concat!
# existence  - concat!
# blocked  - concat!
# stream  - concat!
# logic  - concat!
# decrypting  - concat!
# observing  - concat!
# 500  - concat!
# worm  - concat!
# at-  - not in glove, random.normal!
# investigating  - concat!
# trade  - concat!
# solely  - concat!
# practices  - concat!
# encrypts  - concat!
# scr-file  - not in glove, random.normal!
# science  - concat!
# georgia  - concat!
# geopolitical  - concat!
# disguise  - concat!
# association  - concat!
# influence  - concat!
# utilities  - concat!
# slightly  - concat!
# moved  - concat!
# focuses  - concat!
# plain  - concat!
# intent  - concat!
# lets  - concat!
# panel  - concat!
# vendor  - concat!
# cleartext  - not in glove, random.normal!
# vpn  - concat!
# disruption  - concat!
# argument  - concat!
# browsers  - concat!
# risks  - concat!
# hurricane  - concat!
# digitally  - concat!
# ltd  - concat!
# watering-hole  - not in glove, random.normal!
# 44  - concat!
# win32  - concat!
# node  - concat!
# sinkholed  - not in glove, random.normal!
# mind  - concat!
# school  - concat!
# illustrated  - concat!
# carefully  - concat!
# permissions  - concat!
# street  - concat!
# coded  - concat!
# smart  - concat!
# equipment  - concat!
# natural  - concat!
# ...
# tickets  - too short
# indiana  - too short
# hero  - too short
# inspectors  - too short
# survivors  - too short
# aides  - too short
# barcelona  - too short
# gunmen  - too short
# athletic  - too short
# mortgage  - too short
# l.  - too short
# pan  - too short
# liverpool  - too short
# victoria  - too short
# quarterback  - too short
# baltimore  - too short
# winds  - too short
# traveling  - too short
# 1960  - too short
# churches  - too short
# f.  - too short
# simpson  - too short
# reception  - too short
# congo  - too short
# pilots  - too short
# flew  - too short
# genus  - too short
# sweet  - too short
# condemned  - too short
# railroad  - too short
# roger  - too short
# harris  - too short
# desert  - too short
# coaches  - too short
# jason  - too short
# beaten  - too short
# cape  - too short
# editorial  - too short
# kurdish  - too short
# nepal  - too short
# robinson  - too short
# andy  - too short
# 1965  - too short
# prosecution  - too short
# boss  - too short
# moore  - too short
# margin  - too short
# tampa  - too short
# lieutenant  - too short
# ¥  - too short
# editors  - too short
# tigers  - too short
# kabul  - too short
# 1966  - too short
# funeral  - too short
# couples  - too short
# connecticut  - too short
# meat  - too short
# firing  - too short
# midfielder  - too short
# charter  - too short
# ranks  - too short
# n  - too short
# refugee  - too short
# indians  - too short
# musharraf  - too short
# guitar  - too short
# skin  - too short
# withdraw  - too short
# documentary  - too short
# p.  - too short
# 1-0  - too short
# haiti  - too short
# collapsed  - too short
# louisiana  - too short
# financing  - too short
# earn  - too short
# gray  - too short
# jakarta  - too short
# killings  - too short
# feels  - too short
# 2.5  - too short
# trials  - too short
# arthur  - too short
# soil  - too short
# brussels  - too short
# f  - too short
# oregon  - too short
# 1962  - too short
# centuries  - too short
# guerrillas  - too short
# edwards  - too short
# philip  - too short
# customs  - too short
# ___  - too short
# atmosphere  - too short
# rockets  - too short
# metropolitan  - too short
# gallery  - too short
# senators  - too short
# mosque  - too short
# badly  - too short
# kentucky  - too short
# walker  - too short
# semi  - too short
# chirac  - too short
# nazi  - too short
# journey  - too short
# calif.  - too short
# starring  - too short
# competed  - too short
# somalia  - too short
# anger  - too short
# kings  - too short
# shops  - too short
# shoulder  - too short
# walter  - too short
# rio  - too short
# yugoslav  - too short
# hamilton  - too short
# counties  - too short
# swimming  - too short
# bruce  - too short
# danish  - too short
# tribal  - too short
# enjoyed  - too short
# settlements  - too short
# rush  - too short
# jesus  - too short
# albanian  - too short
# boats  - too short
# hostages  - too short
# parks  - too short
# moral  - too short
# longtime  - too short
# montreal  - too short
# francs  - too short
# standings  - too short
# 20,000  - too short
# triple  - too short
# alcohol  - too short
# medals  - too short
# 2-1  - too short
# burned  - too short
# puerto  - too short
# cemetery  - too short
# mississippi  - too short
# appointment  - too short
# uganda  - too short
# rivers  - too short
# roof  - too short
# jerry  - too short
# orchestra  - too short
# bloc  - too short
# gene  - too short
# suspension  - too short
# struggled  - too short
# 1944  - too short
# utah  - too short
# vienna  - too short
# traveled  - too short
# singing  - too short
# lincoln  - too short
# 2-0  - too short
# sparked  - too short
# campbell  - too short
# trophy  - too short
# argue  - too short
# murray  - too short
# adams  - too short
# consensus  - too short
# bright  - too short
# graham  - too short
# divisions  - too short
# broadway  - too short
# explosives  - too short
# tape  - too short
# drinking  - too short
# von  - too short
# aide  - too short
# hampshire  - too short
# shock  - too short
# lunch  - too short
# wisconsin  - too short
# literary  - too short
# dick  - too short
# climbed  - too short
# 50,000  - too short
# cairo  - too short
# mouth  - too short
# ontario  - too short
# feared  - too short
# beer  - too short
# melbourne  - too short
# dvd  - too short
# prix  - too short
# conservatives  - too short
# 1947  - too short
# defended  - too short
# peacekeeping  - too short
# barry  - too short
# eve  - too short
# n.y.  - too short
# geneva  - too short
# mines  - too short
# geography  - too short
# lane  - too short
# residential  - too short
# rookie  - too short
# lots  - too short
# kilometres  - too short
# luis  - too short
# barely  - too short
# morris  - too short
# lands  - too short
# 1961  - too short
# princess  - too short
# conservation  - too short
# emissions  - too short
# prospect  - too short
# darfur  - too short
# disappointed  - too short
# colonial  - too short
# afford  - too short
# 1949  - too short
# franchise  - too short
# 1959  - too short
# illness  - too short
# fifa  - too short
# celebrated  - too short
# wright  - too short
# depression  - too short
# foster  - too short
# bands  - too short
# beauty  - too short
# 6-1  - too short
# surge  - too short
# proud  - too short
# tackle  - too short
# spiritual  - too short
# athletics  - too short
# chicken  - too short
# croatian  - too short
# russell  - too short
# mitchell  - too short
# francis  - too short
# colonel  - too short
# acres  - too short
# hispanic  - too short
# blues  - too short
# kid  - too short
# priest  - too short
# wedding  - too short
# daughters  - too short
# exploded  - too short
# nhl  - too short
# carl  - too short
# vegas  - too short
# vatican  - too short
# peacekeepers  - too short
# brigade  - too short
# negotiate  - too short
# verdict  - too short
# 1950  - too short
# cent  - too short
# diseases  - too short
# taste  - too short
# legs  - too short
# somebody  - too short
# flowers  - too short
# tonight  - too short
# lakers  - too short
# bars  - too short
# nigerian  - too short
# riding  - too short
# wells  - too short
# 1.2  - too short
# accusations  - too short
# temperatures  - too short
# aired  - too short
# crossed  - too short
# shuttle  - too short
# 1956  - too short
# ncaa  - too short
# organizers  - too short
# businessman  - too short
# brooklyn  - too short
# vessel  - too short
# punishment  - too short
# worldsources  - too short
# blacks  - too short
# baker  - too short
# imperial  - too short
# tall  - too short
# wildlife  - too short
# twenty  - too short
# lawrence  - too short
# settlers  - too short
# wayne  - too short
# v.  - too short
# rwanda  - too short
# jimmy  - too short
# rodriguez  - too short
# marines  - too short
# 700  - too short
# roberts  - too short
# demonstrators  - too short
# bomber  - too short
# sick  - too short
# graf  - too short
# perry  - too short
# goalkeeper  - too short
# nobel  - too short
# 1958  - too short
# stance  - too short
# 1946  - too short
# bitter  - too short
# eliminated  - too short
# insurgency  - too short
# ousted  - too short
# lights  - too short
# jiang  - too short
# elderly  - too short
# critic  - too short
# rick  - too short
# bench  - too short
# ballots  - too short
# sarajevo  - too short
# hillary  - too short
# 1942  - too short
# ‘  - too short
# etc.  - too short
# £  - too short
# wealthy  - too short
# paintings  - too short
# argentine  - too short
# throwing  - too short
# roy  - too short
# 1957  - too short
# appealed  - too short
# cruise  - too short
# ski  - too short
# pollution  - too short
# kidnapped  - too short
# buses  - too short
# lasted  - too short
# resign  - too short
# surplus  - too short
# friendship  - too short
# anne  - too short
# exile  - too short
# terry  - too short
# neck  - too short
# slam  - too short
# stroke  - too short
# 1941  - too short
# alaska  - too short
# painted  - too short
# costa  - too short
# 1940  - too short
# grass  - too short
# celebration  - too short
# warren  - too short
# da  - too short
# 30,000  - too short
# swept  - too short
# chrysler  - too short
# 7-6  - too short
# dodgers  - too short
# attorneys  - too short
# lt.  - too short
# barbara  - too short
# conspiracy  - too short
# midnight  - too short
# bloody  - too short
# craig  - too short
# k  - too short
# scholars  - too short
# angels  - too short
# sierra  - too short
# 200,000  - too short
# childhood  - too short
# lineup  - too short
# approve  - too short
# pat  - too short
# g.  - too short
# pleaded  - too short
# elect  - too short
# fred  - too short
# discrimination  - too short
# bass  - too short
# opec  - too short
# medicare  - too short
# guinea  - too short
# garcia  - too short
# rape  - too short
# vessels  - too short
# rebounds  - too short
# wings  - too short
# canceled  - too short
# touchdown  - too short
# hip  - too short
# boom  - too short
# solar  - too short
# pitcher  - too short
# colin  - too short
# colony  - too short
# 1943  - too short
# corn  - too short
# cheney  - too short
# musicians  - too short
# commanders  - too short
# reagan  - too short
# uh  - too short
# sisters  - too short
# impose  - too short
# 1,500  - too short
# worries  - too short
# trips  - too short
# 1954  - too short
# legend  - too short
# yard  - too short
# 10-year  - too short
# nationalist  - too short
# amnesty  - too short
# fernando  - too short
# karzai  - too short
# sarkozy  - too short
# bag  - too short
# matthew  - too short
# lending  - too short
# fatah  - too short
# readers  - too short
# pleased  - too short
# strait  - too short
# 1952  - too short
# jay  - too short
# arkansas  - too short
# buffalo  - too short
# sporting  - too short
# cathedral  - too short
# trapped  - too short
# cambridge  - too short
# parade  - too short
# genocide  - too short
# elementary  - too short
# piano  - too short
# bobby  - too short
# mets  - too short
# protein  - too short
# northeastern  - too short
# poet  - too short
# horses  - too short
# mugabe  - too short
# chips  - too short
# cincinnati  - too short
# mainstream  - too short
# oppose  - too short
# germans  - too short
# northwestern  - too short
# wimbledon  - too short
# thirds  - too short
# wooden  - too short
# rushed  - too short
# ira  - too short
# footballer  - too short
# susan  - too short
# cattle  - too short
# |  - too short
# boxing  - too short
# samuel  - too short
# vancouver  - too short
# dominant  - too short
# mubarak  - too short
# colombian  - too short
# uefa  - too short
# o  - too short
# du  - too short
# inhabitants  - too short
# carriers  - too short
# mediterranean  - too short
# torn  - too short
# ceasefire  - too short
# yasser  - too short
# mall  - too short
# killer  - too short
# withdrew  - too short
# christ  - too short
# truce  - too short
# kitchen  - too short
# homer  - too short
# tours  - too short
# jane  - too short
# progressive  - too short
# wrestling  - too short
# clay  - too short
# swing  - too short
# turner  - too short
# challenged  - too short
# oakland  - too short
# pitched  - too short
# continent  - too short
# 4,000  - too short
# 500,000  - too short
# thick  - too short
# fierce  - too short
# shah  - too short
# southeastern  - too short
# lyrics  - too short
# dressed  - too short
# composer  - too short
# 1.3  - too short
# continental  - too short
# robin  - too short
# mill  - too short
# defendants  - too short
# fm  - too short
# policemen  - too short
# erupted  - too short
# wickets  - too short
# arguing  - too short
# christians  - too short
# marathon  - too short
# convoy  - too short
# folk  - too short
# foods  - too short
# derby  - too short
# 1951  - too short
# achievement  - too short
# armstrong  - too short
# semifinals  - too short
# invitation  - too short
# hindu  - too short
# l  - too short
# pierre  - too short
# mood  - too short
# prisoner  - too short
# franklin  - too short
# dynasty  - too short
# maine  - too short
# karl  - too short
# feelings  - too short
# todd  - too short
# grace  - too short
# bombers  - too short
# wore  - too short
# anna  - too short
# indies  - too short
# knocked  - too short
# historian  - too short
# judgment  - too short
# sudanese  - too short
# donors  - too short
# prayer  - too short
# quebec  - too short
# tribute  - too short
# straits  - too short
# asylum  - too short
# earl  - too short
# plunged  - too short
# pirates  - too short
# pga  - too short
# dublin  - too short
# wages  - too short
# shirt  - too short
# collins  - too short
# factions  - too short
# dubai  - too short
# lynch  - too short
# legislators  - too short
# cowboys  - too short
# parker  - too short
# flooding  - too short
# ivory  - too short
# mohamed  - too short
# tribe  - too short
# mad  - too short
# guerrilla  - too short
# eggs  - too short
# sars  - too short
# mph  - too short
# portland  - too short
# gonzalez  - too short
# copper  - too short
# w  - too short
# ann  - too short
# veto  - too short
# currencies  - too short
# bags  - too short
# suburban  - too short
# billboard  - too short
# surrender  - too short
# marc  - too short
# cream  - too short
# stones  - too short
# boris  - too short
# evans  - too short
# sand  - too short
# explosive  - too short
# makeup  - too short
# celebrity  - too short
# nights  - too short
# siege  - too short
# virgin  - too short
# frozen  - too short
# airways  - too short
# universe  - too short
# retailers  - too short
# donations  - too short
# gingrich  - too short
# ibm  - too short
# martinez  - too short
# omar  - too short
# nominee  - too short
# patriots  - too short
# rico  - too short
# smooth  - too short
# cotton  - too short
# rocks  - too short
# bone  - too short
# displaced  - too short
# donated  - too short
# enron  - too short
# 3.5  - too short
# reiterated  - too short
# productions  - too short
# denies  - too short
# dying  - too short
# turmoil  - too short
# restoration  - too short
# tired  - too short
# boycott  - too short
# birmingham  - too short
# inmates  - too short
# orlando  - too short
# closest  - too short
# batting  - too short
# ]  - too short
# hate  - too short
# johnny  - too short
# t.  - too short
# mills  - too short
# artistic  - too short
# teach  - too short
# 1930s  - too short
# warnings  - too short
# magazines  - too short
# milwaukee  - too short
# subsidies  - too short
# evacuated  - too short
# gardens  - too short
# goldman  - too short
# referee  - too short
# frankfurt  - too short
# portfolio  - too short
# vacation  - too short
# bail  - too short
# habitat  - too short
# mideast  - too short
# crops  - too short
# advisers  - too short
# angola  - too short
# tale  - too short
# charlotte  - too short
# breast  - too short
# southwestern  - too short
# 3-0  - too short
# voter  - too short
# nancy  - too short
# dancing  - too short
# retained  - too short
# ridge  - too short
# extremists  - too short
# 1936  - too short
# freeze  - too short
# pete  - too short
# blew  - too short
# sheriff  - too short
# casino  - too short
# fla.  - too short
# postponed  - too short
# teammates  - too short
# deutsche  - too short
# memories  - too short
# 1938  - too short
# e.g.  - too short
# marie  - too short
# giuliani  - too short
# disappointing  - too short
# charts  - too short
# mahmoud  - too short
# harsh  - too short
# crop  - too short
# attendance  - too short
# 1918  - too short
# lopez  - too short
# tanzania  - too short
# riot  - too short
# berlusconi  - too short
# rev.  - too short
# pesos  - too short
# rallied  - too short
# villagers  - too short
# rebound  - too short
# therapy  - too short
# margaret  - too short
# cohen  - too short
# lap  - too short
# rumsfeld  - too short
# cocaine  - too short
# burden  - too short
# manuel  - too short
# stanford  - too short
# governors  - too short
# chapel  - too short
# homeless  - too short
# constituency  - too short
# revenge  - too short
# hah  - too short
# rebellion  - too short
# reign  - too short
# lakes  - too short
# bible  - too short
# pink  - too short
# deputies  - too short
# expedition  - too short
# reluctant  - too short
# 7-5  - too short
# aftermath  - too short
# cardinals  - too short
# pregnant  - too short
# opener  - too short
# sean  - too short
# sprint  - too short
# 1.6  - too short
# novels  - too short
# divorce  - too short
# bryant  - too short
# holocaust  - too short
# col.  - too short
# teammate  - too short
# guantanamo  - too short
# nevada  - too short
# unveiled  - too short
# lions  - too short
# tommy  - too short
# phillips  - too short
# bridges  - too short
# i.e.  - too short
# hughes  - too short
# crowds  - too short
# turnout  - too short
# fatal  - too short
# steam  - too short
# chemicals  - too short
# rubber  - too short
# lifting  - too short
# kidnapping  - too short
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-226-d0ef5444e496> in <module>
#      36 print("hey")
#      37 for key in glove_mapping.keys():
# ---> 38     if len(super_mapping[key]) == len(list(glove_mapping.values())[0]):
#      39         print(key, " - too short")
#      40         dummy = np.random.normal(loc=my_avg, scale=my_std, size=len(super_mapping[key]))
#
# KeyboardInterrupt:

# %%
dataframes = {}

# %%
'''
Data loader.
'''

import data_helpers
import os
import pandas as pd

load_main = False

main_cats = ['ActionName', 'Capability']
# dataframes = {cat : {} for cat in main_cats} if load_main else {}

for cat in main_cats:
    path = os.getcwd() + "/Dataframes/" + cat + "/Processed/"
    ls = os.listdir(path)
    for file in ls:
        if (load_main and cat in file) or (not load_main and cat not in file):
            print(file)
            df = pd.read_csv(path + file, encoding='utf-8')

            df.rename({"Unnamed: 0":"a"}, axis="columns", inplace=True)
            df.drop(["a"], axis=1, inplace=True)

            df.rename({"Unnamed: 0.1":"a"}, axis="columns", inplace=True)
            df.drop(["a"], axis=1, inplace=True)

            df_type = file.split('-')[1]
            if load_main:
                try:
                    dataframes[cat][df_type] = df
                except KeyError:
                    print("\t? KeyError exception, did you mean it ?")
                    dataframes[cat] = {}
                    dataframes[cat][df_type] = df
            else:
                sub_cat = file.split('-')[0]
                if sub_cat not in dataframes.keys():
                    dataframes[sub_cat] = {}
                dataframes[sub_cat][df_type] = df

if not load_main:
    main_cats = list(dataframes.keys())
main_cats
# Out:
# File-Train-P.csv
# Other-Test-P.csv
# Network-Test-P.csv
# Other-Train-P.csv
# Network-Train-P.csv
# File-Test-P.csv
# other-Test-P.csv
# infection_propagation-Train-P.csv
# command_and_control-Train-P.csv
# command_and_control-Test-P.csv
# infection_propagation-Test-P.csv
# other-Train-P.csv
# ['ActionName',
#  'Capability',
#  'File',
#  'Other',
#  'Network',
#  'other',
#  'infection_propagation',
#  'command_and_control']

# %%
'''
Calculate simple average embeddings for given sentences,
based on file loaded (for example vectors of length 50).

Skips words, that don't exist in mapping!
Therefore some possibly meaningful words (in security context) are skipped.
'''

from sklearn.svm import SVC
from nltk import word_tokenize

from data_helpers import clean_sentence

import re
word_pattern = re.compile(r'[^a-zA-Z0-9-]')

from nltk.corpus import stopwords
stopwords = set(stopwords.words('english'))

def documents_to_ave_embeddings(docs, embeddings):
    result = []
    for idx, doc in enumerate(docs):
        vectors = []
        
        new_doc = clean_sentence(doc)
        new_doc = re.sub(word_pattern, " ", new_doc)
        
        words = word_tokenize(new_doc)
        words = [word.lower() for word in words if len(word) > 1 and len(word) <= 25]
        
        for word in words:
#         for word in (doc.lower()).split():
            
            global tokens_count
            tokens_count += 1
            if word in embeddings.keys():
                vectors.append(embeddings[word])
            else:
                global missing_tokens
                missing_tokens += 1
          
        if vectors:
            result.append(np.average(vectors, axis=0))
        else:
            result.append(np.zeros(shape=result[0].shape))
    
    return result

# %%
from sklearn.metrics import confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, classification_report

# %%
models = {}

# %%
tokens_count = 0
missing_tokens = 0

cat = 'infection_propagation'
column = 'text-rel'
mapping = super_mapping

print(">>> {}\n".format(cat))

train = dataframes[cat]['Train']
test = dataframes[cat]['Test']

train[column] = train[column].apply(lambda x : re.sub(r'[^\x00-\x7F]+',' ', x))
test[column] = test[column].apply(lambda x : re.sub(r'[^\x00-\x7F]+',' ', x))

train_transformed = documents_to_ave_embeddings(train[column], mapping)
test_transformed = documents_to_ave_embeddings(test[column], mapping)

print("There are {} tokens.".format(tokens_count))
print(" - {:2g} are missing :(".format(missing_tokens/tokens_count))
print()

clf = LogisticRegression(
    solver='newton-cg',
#     class_weight='balanced'
)
clf.fit(train_transformed, train['label_num']) # zwektoryzujmy dane i wytrenujmy klasyfikator na zbiorze treningowym

train_acc = clf.score(train_transformed, train['label_num'])
models[cat] = clf

accuracy = clf.score(test_transformed, test['label_num'])
y_pred = clf.predict(test_transformed)

print("Train Acc: {}".format(train_acc))
print("Test Acc: {}".format(accuracy))
print(classification_report(test['label_num'], y_pred))
c_m = confusion_matrix(test['label_num'], y_pred)
tn, fp, fn, tp = c_m.ravel()
print("TN: {}, FP: {}, FN: {}, TP: {}".format(tn, fp, fn, tp))
# Out:
# >>> infection_propagation
#
# There are 29436 tokens.
#  - 0.00129094 are missing :(
#
# Train Acc: 0.8679446219382322
# Test Acc: 0.7842105263157895
#               precision    recall  f1-score   support
#
#            0       0.98      0.78      0.87       173
#            1       0.27      0.82      0.41        17
#
#    micro avg       0.78      0.78      0.78       190
#    macro avg       0.62      0.80      0.64       190
# weighted avg       0.91      0.78      0.83       190
#
# TN: 135, FP: 38, FN: 3, TP: 14

# %%
models
# Out:
# {'ActionName': LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#            intercept_scaling=1, max_iter=100, multi_class='warn',
#            n_jobs=None, penalty='l2', random_state=None, solver='newton-cg',
#            tol=0.0001, verbose=0, warm_start=False),
#  'Capability': LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#            intercept_scaling=1, max_iter=100, multi_class='warn',
#            n_jobs=None, penalty='l2', random_state=None, solver='newton-cg',
#            tol=0.0001, verbose=0, warm_start=False),
#  'File': LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#            intercept_scaling=1, max_iter=100, multi_class='warn',
#            n_jobs=None, penalty='l2', random_state=None, solver='newton-cg',
#            tol=0.0001, verbose=0, warm_start=False),
#  'Network': LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#            intercept_scaling=1, max_iter=100, multi_class='warn',
#            n_jobs=None, penalty='l2', random_state=None, solver='newton-cg',
#            tol=0.0001, verbose=0, warm_start=False),
#  'Other': LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#            intercept_scaling=1, max_iter=100, multi_class='warn',
#            n_jobs=None, penalty='l2', random_state=None, solver='newton-cg',
#            tol=0.0001, verbose=0, warm_start=False),
#  'other': LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#            intercept_scaling=1, max_iter=100, multi_class='warn',
#            n_jobs=None, penalty='l2', random_state=None, solver='newton-cg',
#            tol=0.0001, verbose=0, warm_start=False),
#  'infection_propagation': LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#            intercept_scaling=1, max_iter=100, multi_class='warn',
#            n_jobs=None, penalty='l2', random_state=None, solver='newton-cg',
#            tol=0.0001, verbose=0, warm_start=False),
#  'command_and_control': LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#            intercept_scaling=1, max_iter=100, multi_class='warn',
#            n_jobs=None, penalty='l2', random_state=None, solver='newton-cg',
#            tol=0.0001, verbose=0, warm_start=False)}

# %%
test_transformed = documents_to_ave_embeddings(dataframes['ActionName']['Test']['text-rel'], mapping)

predictions = {}
for model_name in models.keys():
    predictions[model_name] = models[model_name].predict_proba(test_transformed)

# %%
'''
Gets actual tokens-list from data.
Some tokens annotated as 'Action Token' are not a single word.

Words' pos tags are checked and we add word to a token list 
if it's a VERB, or eventually a NOUN 
(it's usually NNS - noun plural - which was actually a VERB)

Skipping stopwords, because of such phrases as 'were installed' etc.
'''

from nltk.corpus import stopwords
from nltk import word_tokenize, pos_tag       

stopwords = set(stopwords.words('english'))
tokens_lists = {
    0 : [],
    1 : []
}

train = dataframes['ActionName']['Train']
test = dataframes['ActionName']['Test']

import re
pattern = re.compile('\W')

for i in range(train.shape[0]):
    token = train.at[i, 'token']
    label = train.at[i, 'label_num']
    tokens_lists[label] += get_verb_token(token)

print(len(tokens_lists[0]), len(tokens_lists[1]), train.shape)
# Out:
# 2144 1147 (3348, 10)

# %%
def get_verb_token(token):
    result = []
    token = token.lower().split()
    
    token = [t for t in token if t not in stopwords]
    token = [re.sub(pattern, '', t) for t in token]
        
    if len(token) > 1:
        tagged_tokens = [pos_tag([t]) for t in token]
        verb_tokens = [t for t in tagged_tokens if t[0][1].startswith("V")]
        if len(verb_tokens) == 1:
            token = verb_tokens[0][0][0]
            result += [token]
        elif len(verb_tokens) > 1:
            for tt in verb_tokens:
                 result += [tt[0][0]]
        else:
            noun_tokens = [t for t in tagged_tokens if t[0][1].startswith("N")]
            for tt in noun_tokens:
                result += [tt[0][0]]
    else:
        result += token
        
    return result

# %%
map_vectors = {}
for cat in tokens_lists.keys():
    vectors = [mapping[word] for word in tokens_lists[cat] if word in mapping.keys()]
    map_vectors[cat] = np.average(vectors, axis=0)

# %%
def cosine(vec1, vec2):
    vec1, vec2 = np.asarray(vec1), np.asarray(vec2)
    v1_sqrt = np.sqrt(np.sum(vec1 ** 2))
    v2_sqrt = np.sqrt(np.sum(vec2 ** 2))
    return np.sum((np.multiply(vec1, vec2))) / ( v1_sqrt * v2_sqrt )

# %%
all_count = 0
correct_count = 0

ds = train

train_data = []
train_labels = []

for i in range(ds.shape[0]):
    token = get_verb_token(ds.at[i, 'token'])
    label = ds.at[i, 'label_num']
    if token:
        token = token[0]
        
        if token in mapping.keys():
            
            all_count += 1
            vector = mapping[token]
            scores = [cosine(vector, map_vectors[0]), cosine(vector, map_vectors[1])]
#             print("Predicted: {}, real: {}".format(np.argmax(scores), label))
            choice = np.argmax(scores)
        
            if label == choice:
                correct_count += 1
               
            train_data.append(scores)
            train_labels.append(label)

print(correct_count/all_count)
# Out:
# 0.5078922934076138

# %%
clf = SVC()

clf.fit(train_data, train_labels) # zwektoryzujmy dane i wytrenujmy klasyfikator na zbiorze treningowym
accuracy = clf.score(train_data, train_labels)

accuracy
# Out:
# /home/jells123/anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# 0.6511915815536985
