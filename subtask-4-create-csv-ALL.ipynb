# %%
'''
This file gathers all previously selected categories:
1. ActionName
    File
    Network
    Other
2. Capability
    infection_propagation
    ...something
    other
into one DataFrame, instead of gathering binary data into files 
(for example ActionName - NoActionName)
'''
# Out:
# '\nThis file gathers all previously selected categories:\n1. ActionName\n    File\n    Network\n    Other\n2. Capability\n    infection_propagation\n    ...something\n    other\ninto one DataFrame, instead of gathering binary data into files \n(for example ActionName - NoActionName)\n'

# %%
import re
import os

# %%
root = '/home/jells123/Documents/ENGINEER/DATA/1-Raw data/data/'
ann = '/annotations'

sets = {
    'Train' : 'train',
    'Dev' : 'dev',
    'Test' : 'test_3'
}
set_type = 'Test'
path = root + sets[set_type] + ann

rel_pattern = r'(?P<r_id>R[0-9]+)\s+[A-Za-z]+\s+(?P<r_first>[A-Za-z]+:T[0-9]+)\s+(?P<r_second>[A-Za-z]+:T[0-9]+)'
ann_pattern = r'(?P<a_id>A[0-9]+)\s+(?P<cat>[A-Za-z]+)\s+(?P<t_id>T[0-9]+)\s+(?P<text>[^\n]+)'
token_pattern = r'(?P<t_id>T[0-9]+)\s+(?P<t_type>[A-Z][a-z]+) (?P<indices>[0-9]+ [0-9]+[^\t]+)\t(?P<t_text>.+)\n'

# %%
def init_data():
    data = {
        'Text' : [],
        'ActionName' : [],
        'Capability' : []
    }
    undefined = None
    return data, undefined

# %%
def process_annotation(anns, words, token):
    
    data['Text'].append(words)
    
    current_annotations = {}
    for ann in anns:
        m = re.search(r'(?P<id>[0-9]{3}):(?P<type>[A-Za-z]+)-(?P<name>.+)\s*', ann[3])
        typ, name = m.group('type'), m.group('name')
        typ, name = re.sub(r'\/', '_', typ), re.sub(r'\/', '_', name)
        main_cat = ann[1]
        if main_cat == 'Capability':
            # special treatment for Capability because there are no sub-categories
            current_annotations[main_cat] = name
        else:
            current_annotations[main_cat] = typ
    
    for c in [
        ['ActionName', ['File', 'Network']], 
        ['Capability', ['infection_propagation', 'command_and_control']]
    ]:
        category = c[0]
        sub_cats = c[1]
        if category in current_annotations.keys():
            sub_cat = current_annotations[category]
            if sub_cat in sub_cats:
                data[category].append(sub_cat)
            else:
                data[category].append("Other")
        else:
            data[category].append("-")

# %%
def get_token_words_relation(t, tokens, rels, anns):
    
    global tokens_count
    tokens_count += 1
    
    relations = list(filter(lambda x : x[1] == 'Action:'+t[0] , rels))
    if relations:
        mod_relations = list(filter(lambda x : 'Modifier' in x[2], relations))
        if mod_relations:
            for mr in mod_relations:
                relations += list(filter(lambda x : x[1] == mr[2], rels))
    
    if include_subject:
        subject = list(filter(lambda x : 'Subject' in x[1] and x[2] == 'Action:'+t[0], rels))
        if subject:
            subject = subject[0]
            relations.append(subject)

    if not relations:
        print("Token {} has no relation.".format(t))
        global relation_missing
        relation_missing += 1
    
    words = []
    words.append(t[3])
    
    for r in relations:
        
        if include_subject and 'Subject' in r[1]: 
            # subject -> action
            token_id = r[1].split(':')[1]
            token_word = list(filter(lambda x : x[0] == token_id, tokens))
            if token_word and token_word[0][3] not in words:
                words.insert(0, token_word[0][3])
            
        else:
            # action -> object, action -> mod -> object
            token_id = r[2].split(':')[1]
            token_word = list(filter(lambda x : x[0] == token_id, tokens))
            if token_word and token_word[0][3] not in words:
                if token_word[0][3][0].isupper():
                    words.insert(0, token_word[0][3])
                else:
                    words.append(token_word[0][3])
    
    # relation gathered and here we create the dataset
    # id prefer it in anotehr function but whatever
    annotations = list(filter(lambda x : x[2] == t[0], anns))
    process_annotation(annotations, words, t)
    
    if not annotations:
        print("Token {} has no annotation.".format(t))
        global annotation_missing
        annotation_missing += 1

# %%
def get_token_words_coords(t, text, off=0):
    indices = t[2]
    indices = indices.split(';') if ';' in indices else [indices]
    real_token = ''
    indices = [[int(idx) for idx in i.split()] for i in indices]
    for i in indices:
        real_token += text[i[0]+off : i[1]+off] + ' '
        
    while '- ' in real_token:
        real_token = real_token.replace('- ', '')
    return real_token.strip(), (indices[0][0]+off, indices[-1][1]+off)

def get_token_neighbors(token, coords, text, neighbors):
    
    left = (neighbors-1)/2
    right = left
    
    l_idx = coords[0] - 1
    r_idx = coords[1] + 1
    
    words = []
    while left:
        while text[l_idx].isspace():
            l_idx -= 1
        word = ''
        while not text[l_idx].isspace():
            word += text[l_idx]
            l_idx -= 1
        
        word = word[::-1]
        if word[0] == '<' or word[-1] == '>': #html tag
            l_idx -=1
            word = ''
        else:
            words.insert(0, word)
            left -= 1
    
    words.append(token)
    while right:
        while text[r_idx].isspace():
            r_idx += 1
        word = ''
        while not text[r_idx].isspace():
            word += text[r_idx]
            r_idx += 1
            
        if word[0] == '<' or word[-1] == '>':
            r_idx += 1
            word = ''
        else:
            words.append(word)
            right -= 1
            
    return words
        
def gather_data(words, anns, t):
    annotations = list(filter(lambda x : x[2] == t[0], anns))
    process_annotation(annotations, words, t)
    
    if not annotations:
        print("Token {} has no annotation.".format(t))
        global annotation_missing
        annotation_missing += 1

# %%
data, undefined = init_data()
print(data)

relation_mode = True

relation_missing = 0
annotation_missing = 0
tokens_count = 0

include_subject = True
action_tokens = []

for filename in os.listdir(path):
    
    if filename.endswith('.ann'):
        print("\n>>> {}".format(filename))
        with open(path + '/' + filename) as ann_file:
            content = ann_file.read()
            
            # match lines with a token            
            tokens = re.findall(token_pattern, content)
            relations = re.findall(rel_pattern, content)
            annotations = re.findall(ann_pattern, content)
            
            if not relation_mode:
            # read both .ann and .txt file
                with open(path + "/" + filename.replace(".ann", ".txt")) as txt_file:
                    text = txt_file.read()
                    text = re.sub(r'[^\x00-\x7F]+',' ', text)
                    offset = 0
                    for t in tokens:
                        if t[1] == 'Action':
                            # get token from annotations + text and compare them, are they equal?
                            ann_token = t[3]
                            tokens_count += 1
                            while '- ' in ann_token:
                                ann_token = ann_token.replace('- ', '')

                            idx_token, coords = get_token_words_coords(t, text, offset)
                            # oops, we got a mismatch!
                            if ann_token != idx_token:
                                # probably something went wrong! - we need to deal with it as always :)
                                where_is = text.find(ann_token)
                                offset = where_is - int(t[2].split()[0])
                                idx_token, coords = get_token_words_coords(t, text, offset)

                            words = get_token_neighbors(ann_token, coords, text, 9)
                            gather_data(words, annotations, t)
                            
            else:
            # older version -> finds token groups by relation
                for t in tokens:
                    if t[1] == 'Action':
                        get_token_words_relation(t, tokens, relations, annotations)         
                        action_tokens.append(t[3])
# Out:
# {'Text': [], 'ActionName': [], 'Capability': []}
#
# >>> butterfly-corporate-spies-out-for-financial-gain.ann
#
# >>> Equation_group_questions_and_answers.ann
#
# >>> Dissecting-LinuxMoose.ann
# Token ('T136', 'Action', '52031 52036', 'reach') has no annotation.
#
# >>> Dissecting-the-Kraken.ann
# Token ('T16', 'Action', '10699 10705', 'update') has no relation.
# Token ('T17', 'Action', '10710 10719', 'uninstall') has no relation.
#
# >>> DEEP_PANDA_Sakula.ann

# %%
data['Text']
# Out:
# [['Carbanak', 'designed', 'for', 'espionage'],
#  ['Carbanak', 'designed', 'for', 'data exfiltration'],
#  ['Carbanak', 'designed', 'to', 'provide remote access to infected machines'],
#  ['They',
#   'install',
#   'additional software such as the Ammyy Remote Administration Tool'],
#  ['They', 'SSH servers', 'compromise'],
#  ['The videos', 'sent', 'to', 'the C2 server'],
#  ['made', 'video recordings of the activities of bank employees'],
#  ['Carbanak', 'copies', 'itself', 'into', '“%system32%\\com”'],
#  ['the malware', 'creates', 'a new service'],
#  ['Carbanak',
#   'determines',
#   'if',
#   'either the avp.exe or avpui.exe processes (components of Kaspersky Internet Security) is running'],
#  ['Carbanak',
#   'creates',
#   'a file with a random name and a .bin extension',
#   'in',
#   '%COMMON_APPDATA%\\Mozilla'],
#  ['the malware',
#   'gets',
#   'the proxy configuration',
#   'from',
#   'the registry entry'],
#  ['The malware', 'saves', 'files', 'in'],
#  ['The malware', 'sent', 'to', 'files', 'the C2 server'],
#  ['Carbanak',
#   'obtain',
#   'proxy configuration information',
#   'from',
#   'headers sent through an application via SOCKS or HTTP'],
#  ['Carbanak', 'injects', 'its code', 'into', 'svchost.exe'],
#  ['Carbanak', 'downloads', 'the file kldconfig.plug', 'from', 'its C2 server'],
#  ['Carbanak', 'logs', 'keystrokes'],
#  ['Carbanak', 'takes', 'screenshots', 'every', '20 seconds'],
#  ['Carbanak', 'Auto', 'Termservice service execution mode', 'sets', 'to'],
#  ['Carbanak',
#   'enable',
#   'connections to the infected computer using the Remote Desktop Protocol (RDP)'],
#  ['it', 'sends', 'a special notification', 'to', 'its C2 server'],
#  ['Carbanak',
#   'detects',
#   'the banking application BLIZKO (funds transfer software)',
#   'in',
#   'the infected computer'],
#  ['It', 'receives', 'commands'],
#  ['Carbanak', 'sends', 'its collected monitoring data', 'to', 'its C2 server'],
#  ['the attackers',
#   'recompiled',
#   'the machine’s SSH daemon',
#   'with',
#   'so',
#   'a backdoor',
#   'they could gain direct access'],
#  ['used',
#   'to',
#   'a Secure Shell (SSH) backdoor',
#   'communicate with the C2 server'],
#  ['the program “MBR Eraser”', 'remove', 'traces'],
#  ['the program “MBR Eraser”', 'to crack', 'servers'],
#  ['the program “MBR Eraser”', 'Windows computers', 'to crack'],
#  ['hackers', 'got', 'access', 'to', 'e-mail servers'],
#  ['hackers', 'control', 'all internal communications'],
#  ['download', 'arbitrary exe- cutable files from the management server'],
#  ['the attacker', 'gets', 'remote access', 'to', 'the user computer'],
#  ['the attackers', 'SSH backdoor', 'use'],
#  ['SSH backdoor',
#   'transmits',
#   'the login/password data used to access the servers',
#   'to',
#   'the malicious server'],
#  ['SSH backdoor', 'provides', 'attackers', 'remote access to the servers'],
#  ['the at- tackers',
#   'modify',
#   'rules for firewalls Microsoft TMG, CISCO, etc'],
#  ['the attackers',
#   'downloaded',
#   'mali- cious scripts and changed denominations of issued banknotes in the ATM operating system registry'],
#  ['this file',
#   'changed',
#   'registry keys in the registry branch ““HKEY_LOCAL_MACHINE\\ SOFTWARE\\Wincor Nixdorf\\ProTopas\\Current- Version\\LYNXPAR\\CASH_DISPENSER”” that are responsible for cassette denominations in an ATM'],
#  ['The Gozi/ISFB based malware',
#   'drop',
#   'additional components on interesting systems'],
#  ['run', 'them'],
#  ['the malware', 'execute', 'commands', 'as', 'administrator'],
#  ['the dropper', 'add', 'persistence', 'in', 'the registry'],
#  ['the dropper', 'drop', 'a second file'],
#  ['the attackers',
#   'compromising',
#   'the update site for several industrial control system (ICS) software producers'],
#  ['They',
#   'Backdoor.Oldrea',
#   'bundle',
#   'with',
#   'a legitimate update of the affected software'],
#  ['The Dragonfly attackers',
#   'used',
#   'hacked websites',
#   'to',
#   'host command-and-control (C&C) software'],
#  ['Remote Access Tool (RAT) type malware',
#   'provide',
#   'the attackers',
#   'with',
#   'access and control of compromised computers'],
#  ['extract', 'data'],
#  ['install', 'further malware'],
#  ['selected executives and senior employees in target companies',
#   'receive',
#   'emails containing a malicious PDF attachment'],
#  ['Oldrea or Karagany', 'drop', 'on', 'the victim’s computer'],
#  ['a persistent component', 'C&C servers', 'interacts', 'with'],
#  ['download', 'payloads'],
#  ['execute', 'payloads'],
#  ['performing', 'a GET request'],
#  ['reaching out', 'to', 'the C&C server'],
#  ['The components', 'are downloaded'],
#  ['Backdoor.Oldrea',
#   'OS, user name, computer name, country, language, nation, Internet adapter configuration information, available drives, default browser, running processes, desktop file list, My Documents, Internet history, program files, and root of available drives',
#   'collect',
#   'system information',
#   'such as'],
#  ['This data', 'collected'],
#  ['This data', 'written', 'to', 'in', 'a temporary file', 'an encrypted form'],
#  ['POST’ed', 'it', 'to', 'a remote C&C server'],
#  ['It', 'download', 'additional files'],
#  ['It', 'install', 'additional files'],
#  ['It', 'exfiltrate', 'data'],
#  ['Trojan.Karagany',
#   'copies',
#   'itself',
#   'with',
#   'hidden and system attributes where it was first executed'],
#  ['Trojan.Karagany',
#   'checks',
#   'for',
#   'by',
#   'a live Internet connection',
#   'visiting Microsoft or Adobe websites'],
#  ['It', 'reach out', 'to', 'its C&C server'],
#  ['These campaigns',
#   'relied',
#   'on',
#   'spear phishing with malicious documents that dropped malware (mostly PlugX) along with Vietnamese- language decoy documents'],
#  ['Dyreza',
#   'intercept',
#   'logins',
#   'by',
#   'acquiring the HTTP POST data from under banking SSL sessions'],
#  ['These macros', 'download', 'first-stage loaders'],
#  ['first-stage loaders',
#   'install',
#   'the Dridex payload',
#   'onto',
#   'the victim machine'],
#  ['This copy of Kaptoxa',
#   'scanned',
#   'volatile memory of infected systems',
#   'for',
#   'patterns that looked like credit card numbers'],
#  ['This copy of Kaptoxa', 'logged', 'them', 'to', 'a file'],
#  ['This copy of Kaptoxa',
#   'transferred',
#   'a file',
#   'to',
#   'an internal network share'],
#  ['transferred', 'the data', 'to', 'external FTP servers'],
#  ['The malware',
#   'scans',
#   'memory',
#   'for',
#   'both Track 1 and Track 2 credit card data'],
#  ['The malware',
#   'HTTP requests',
#   'exfiltrates',
#   'its findings',
#   'to',
#   'over',
#   'control servers'],
#  ['This campaign',
#   'leveraged',
#   'fake websites',
#   'to',
#   'serve malware that poses as software updates for legitimate applications',
#   'trick users into entering credentials'],
#  ['This tool', 'log', 'keystrokes', 'on', 'infected systems'],
#  ['This tool', 'log', 'screenshots', 'on', 'infected systems'],
#  ['This tool', 'log', 'other user activity', 'on', 'infected systems'],
#  ['This tool',
#   'exfiltrates',
#   'this data',
#   'to',
#   'an attacker-controlled server'],
#  ['it',
#   'extracts',
#   'a backdoor Trojan',
#   'a configuration file',
#   'optionally a decoy (an image or a legitimate executable)'],
#  ['it', 'deploys', 'a backdoor Trojan'],
#  ['conducting', 'reconnaissance', 'of', 'victim machines'],
#  ['deleting', 'files'],
#  ['downloading', 'files'],
#  ['exfiltrating', 'data'],
#  ['It', 'log', 'keystrokes'],
#  ['It', 'copy', 'files'],
#  ['It', 'modify', 'files'],
#  ['capture', 'screenshots', 'video of user activity'],
#  ['It', 'perform', 'administrative tasks'],
#  ['terminating', 'processes'],
#  ['rebooting', 'victim machines'],
#  ['logging off', 'users'],
#  ['A full command shell', 'provided'],
#  ['sends',
#   'output',
#   'to',
#   'over',
#   'for',
#   'the PlugX instance',
#   'named pipes',
#   'onward relay to the attacker’s Command-and-Control (C2) servers'],
#  ['PlugX',
#   'delivered',
#   'to',
#   'via',
#   'targets',
#   'a spear phishing attack containing a malicious RTF or Word document leveraging exploit code for the popular CVE-2012-0158 vulnerability'],
#  ['dropped', 'three files'],
#  ['ZxShell', 'connected', 'to', 'a C2 at newss.effers.com'],
#  ['Win64.exe', 'invoke', 'other programs', 'with', 'elevated privileges'],
#  ['Win64.exe', 'elevate', 'its privileges', 'to', 'those of the SYSTEM user'],
#  ['Win64.exe',
#   'create',
#   'a new process',
#   'with',
#   'to',
#   'these access rights',
#   'run the command that was passed as an argument'],
#  ['deleted', 'it'],
#  ['executed',
#   'any command passed to the executable',
#   'with',
#   'elevated privileges'],
#  ['combined',
#   'malicious executable',
#   'a decoy document',
#   'with',
#   'a malicious CVE-2014-1761 document'],
#  ['malware',
#   'connecting',
#   'to',
#   'a known TEMPER PANDA C2 address, www. verizon.proxydns.com'],
#  ['this adversary', 'gain', 'legitimate credentials', 'to', 'move laterally'],
#  ['this adversary',
#   'RDP sessions',
#   'establish',
#   'to',
#   'achieve their objectives'],
#  ['this',
#   'provides',
#   'the equivalent functionality of a RAT',
#   'for',
#   'adversary control of webservers'],
#  ['they', 'deploy', 'privilege-escalation tools'],
#  ['PlugX C2 servers', 'used', 'the following IP addresses', 'as'],
#  ['they',
#   'seek',
#   'legitimate credentials',
#   'via',
#   'tools such as Windows Credential Viewer, Windows Credential Editor, or Mimikatz'],
#  ['HURRICANE PANDA', 'RDP', 'rely on'],
#  ['presented', 'with', 'an administrative command shell'],
#  ['RAR', 'compressed', 'using', 'files of interest'],
#  ['RAR', 'password protected', 'using', 'files of interest'],
#  ['they', 'stage', 'the files', 'at', 'a convenient location'],
#  ['they', 'FTP', 'exfiltrate', 'the files', 'from', 'via', 'the network'],
#  ['Pirpi',
#   'provides',
#   'the adversary',
#   'with',
#   'a traditional set of RAT features'],
#  ['the adversary', 'exfiltrate', 'files'],
#  ['the adversary', 'deploy', 'files'],
#  ['sophisticated Windows-based rootkit',
#   'leverage',
#   'an encrypted Virtual File System (VFS)',
#   'as',
#   'a staging area for tools to deploy and data prepared for exfiltration'],
#  ['Their main implant',
#   'is',
#   'a sophisticated RAT that exhibits a modular architecture and a multi-year development history']]

# %%
import pandas as pd

dataset = pd.DataFrame({
    'text-rel' : data['Text'],
    'token' : action_tokens,
    'ActionName' : data['ActionName'],
    'Capability' : data['Capability']
})
    
dataset.head()
# Out:
#                                             text-rel         token ActionName  \
# 0  [The attackers, obtaining, access, to, specifi...     obtaining          -
# 1      [they, eavesdropped, on, email conversations]  eavesdropped          -
# 2                  [they, insert, fraudulent emails]        insert          -
# 3  [used, a command-and-control (C&C) server, in,...          used          -
# 4                               [Bda9.tmp, executed]      executed       File
#
#             Capability
# 0                Other
# 1                Other
# 2                Other
# 3  command_and_control
# 4                    -

# %%
dataset['text-rel'] = dataset['text-rel'].apply(' '.join)
dataset['text-rel'] = dataset['text-rel'].apply(lambda x : re.sub(r"[“”\[\]]", "", x))
dataset.head()
# Out:
#                                             text-rel         token ActionName  \
# 0  The attackers obtaining access to specific sys...     obtaining          -
# 1           they eavesdropped on email conversations  eavesdropped          -
# 2                      they insert fraudulent emails        insert          -
# 3  used a command-and-control (C&C) server in an ...          used          -
# 4                                  Bda9.tmp executed      executed       File
#
#             Capability
# 0                Other
# 1                Other
# 2                Other
# 3  command_and_control
# 4                    -

# %%
# dataset.to_csv('neighbours/{}-{}.csv'.format(main_cat, set_type))
dataset.to_csv('All-{}.csv'.format(set_type))
print(dataset.ActionName.value_counts(), "\n")
print(dataset.Capability.value_counts(), "\n")
# Out:
# -          76
# File       15
# Other      12
# Network     7
# Name: ActionName, dtype: int64
#
# Other                    63
# -                        22
# command_and_control      15
# infection_propagation    10
# Name: Capability, dtype: int64
