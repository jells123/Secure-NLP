# %%
import data_helpers
import os
import pandas as pd

dataframes = {}
main_cats = ['ActionName', 'Capability']
for cat in main_cats:
    ls = os.listdir(os.getcwd() + "/" + cat)
    for file in ls:
        if cat not in file and '.csv' in file:
            df = pd.read_csv(os.getcwd() + "/" + cat + "/" + file, encoding='utf-8', engine='python')
            print(">>> {}:".format(file))
            print(df.label.value_counts(), df.columns.tolist(), '\n')
            dataframes[file.replace(".csv", "")] = df
# Out:
# >>> Other-Train.csv:
# NoOther    698
# Other      456
# Name: label, dtype: int64 ['Unnamed: 0', 'label', 'text-rel', 'label_num', 'text-neigh']
#
# >>> File-Test.csv:
# no-File    19
# File       15
# Name: label, dtype: int64 ['Unnamed: 0', 'label', 'text-rel', 'label_num', 'text-neigh']
#
# >>> Network-Train.csv:
# NoNetwork    781
# Network      373
# Name: label, dtype: int64 ['Unnamed: 0', 'label', 'text-rel', 'label_num', 'text-neigh']
#
# >>> Network-Test.csv:
# no-Network    27
# Network        7
# Name: label, dtype: int64 ['Unnamed: 0', 'label', 'text-rel', 'label_num', 'text-neigh']
#
# >>> Network-Dev.csv:
# NoNetwork    30
# Network      16
# Name: label, dtype: int64 ['Unnamed: 0', 'label', 'text-neigh', 'label_num', 'text-rel']
#
# >>> Other-Test.csv:
# no-Other    22
# Other       12
# Name: label, dtype: int64 ['Unnamed: 0', 'label', 'text-rel', 'label_num', 'text-neigh']
#
# >>> Other-Dev.csv:
# NoOther    33
# Other      13
# Name: label, dtype: int64 ['Unnamed: 0', 'label', 'text-neigh', 'label_num', 'text-rel']
#
# >>> File-Train.csv:
# NoFile    829
# File      325
# Name: label, dtype: int64 ['Unnamed: 0', 'label', 'text-rel', 'label_num', 'text-neigh']
#
# >>> File-Dev.csv:
# NoFile    29
# File      17
# Name: label, dtype: int64 ['Unnamed: 0', 'label', 'text-neigh', 'label_num', 'text-rel']
#
# >>> command_and_control-Dev.csv:
# no-command_and_control    86
# command_and_control       16
# Name: label, dtype: int64 ['Unnamed: 0', 'label', 'text-rel', 'label_num', 'text-neigh']
#
# >>> infection_propagation-Dev.csv:
# no-infection/propagation    95
# infection/propagation        7
# Name: label, dtype: int64 ['Unnamed: 0', 'label', 'text-rel', 'label_num', 'text-neigh']
#
# >>> other-Dev.csv:
# other       79
# no-other    23
# Name: label, dtype: int64 ['Unnamed: 0', 'label', 'text-rel', 'label_num', 'text-neigh']
#
# >>> command_and_control-Test.csv:
# no-command_and_control    73
# command_and_control       15
# Name: label, dtype: int64 ['Unnamed: 0', 'label', 'text-neigh', 'label_num', 'text-rel']
#
# >>> infection_propagation-Train.csv:
# no-infection/propagation    2292
# infection/propagation        525
# Name: label, dtype: int64 ['Unnamed: 0', 'label', 'text-neigh', 'label_num', 'text-rel']
#
# >>> infection_propagation-Test.csv:
# no-infection/propagation    78
# infection/propagation       10
# Name: label, dtype: int64 ['Unnamed: 0', 'label', 'text-neigh', 'label_num', 'text-rel']
#
# >>> other-Train.csv:
# other       1712
# no-other    1105
# Name: label, dtype: int64 ['Unnamed: 0', 'label', 'text-neigh', 'label_num', 'text-rel']
#
# >>> command_and_control-Train.csv:
# no-command_and_control    2237
# command_and_control        580
# Name: label, dtype: int64 ['Unnamed: 0', 'label', 'text-neigh', 'label_num', 'text-rel']
#
# >>> other-Test.csv:
# other       63
# no-other    25
# Name: label, dtype: int64 ['Unnamed: 0', 'label', 'text-neigh', 'label_num', 'text-rel']

# %%
dataframes['File-Train'].head()
# Out:
#    Unnamed: 0 label                                           text-rel  \
# 0           0  File  the driver creates device named \Device\vstor3...
# 1           1  File                           it cleans out those logs
# 2           2  File           rootkit store configuration and log data
# 3           3  File   rootkit The files within that directory are used
# 4           4  File  the pipe server saving data into a temporary file
#
#    label_num                                         text-neigh
# 0          1  first executed, the driver creates device name...
# 1          1  the server, and then cleans out those logs: 03...
# 2          1  by the rootkit to store configuration and log ...
# 3          1  files within that directory are used by the ro...
# 4          1  their behalf, such as saving data into a tempo...

# %%
'''
Join Dev with Test, because why bother?
'''

for cat in dataframes.keys():
    if 'Test' in cat:
        new_df = dataframes[cat]
        for ccat in dataframes.keys():
            if 'Dev' in ccat and ccat.replace("Dev", "Test") == cat:
#                 new_df = pd.concat([new_df, dataframes[ccat]], sort=False)
                new_df = new_df.append(dataframes[ccat], ignore_index=True)
                dataframes[cat] = new_df
                
dataframes = {cat : dataframes[cat] for cat in dataframes if 'Dev' not in cat}
# Out:
# /home/jells123/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/frame.py:6211: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)

# %%
from tokenizer import TheTokenizer
my_tokenizer = TheTokenizer(stem=False, lem=False, stopword=False)

# %%
'''
Process data from sentences to list of words:
- remove punctuation
- convert to lowercase
- split by whitespace to get list
- stem or lemmatize
- remove stopwords
- remove one-char words?
- remove words longer than 30 (probably some hashes)
'''

import re
from nltk import word_tokenize, pos_tag     
from nltk.corpus import stopwords

stopwords = set(stopwords.words('english'))

for cat in dataframes.keys():
    df = dataframes[cat]
    print(">>> {}".format(cat))
    cols = df.columns.tolist()
    for c in cols:
        if 'text' in c and 'token' not in c and 'processed' not in c:
            
            data = df[c]
#             print(data[0:1]) 
#(BEFORE)
            
            data = data.apply(lambda x : re.sub(r'[,\[\]\(\)"’]', '', x))
            data = data.apply(lambda x : x.lower())
            data = data.apply(lambda x : x.split())
            
            data = data.apply(lambda tokens : [my_tokenizer.stem_token(t) for t in tokens])
#             data = data.apply(lambda tokens : [my_tokenizer.lemmatize_token(t, pos) for t, pos in pos_tag(tokens)])
            
            data = data.apply(lambda tokens : [t for t in tokens if t not in stopwords])
        
            data = data.apply(lambda tokens : ['hash-code' if len(t) >= 31 else t for t in tokens])
            data = data.apply(lambda tokens : [t for t in tokens if len(t) > 1 and len(t) <= 20])
            
            df['{}-processed'.format(c)] = data.apply(lambda x : ' '.join(x))

#             print(data[0:1])
#(AFTER)
# Out:
# >>> Other-Train
# >>> File-Test
# >>> Network-Train
# >>> Network-Test
# >>> Other-Test
# >>> File-Train
# >>> command_and_control-Test
# >>> infection_propagation-Train
# >>> infection_propagation-Test
# >>> other-Train
# >>> command_and_control-Train
# >>> other-Test

# %% [markdown]
# Komentarz NLP Stanford to Stemming vs Lemmatization:
#     https://nlp.stanford.edu/IR-book/html/htmledition/stemming-and-lemmatization-1.html

# %%
'''
Attempt to replace some of very-unique words, such as file name, URL... 
(unfortunately not all are replaced, example: some long hashes and codes),
as well as remove YEAR (four digits)
'''

from data_helpers import clean_dataframe

print("Data cleaning examples:")
for cat in dataframes.keys():
    df = dataframes[cat]
    print('\n', df.at[0, 'text-rel-processed'])
    df = clean_dataframe(df)
    dataframes[cat] = df
    print(df.at[0, 'text-rel-processed'])
# Out:
# Data cleaning examples:
#
#  driver creat devic name \device\vstor32 symbol link \dosdevices\vstor32
# driver creat devic name system-path  symbol link system-path
#
#  bda9.tmp execut
#  tmp-file execut
#
#  driver creat devic name \device\vstor32 symbol link \dosdevices\vstor32
# driver creat devic name system-path  symbol link system-path
#
#  bda9.tmp execut
#  tmp-file execut
#
#  bda9.tmp execut
#  tmp-file execut
#
#  driver creat devic name \device\vstor32 symbol link \dosdevices\vstor32
# driver creat devic name system-path  symbol link system-path
#
#  use command-and-control c&c server attack
# use command-and-control c&c server attack
#
#  command control destin malwar
# command control destin malwar
#
#  use command-and-control c&c server attack
# use command-and-control c&c server attack
#
#  command control destin malwar
# command control destin malwar
#
#  command control destin malwar
# command control destin malwar
#
#  use command-and-control c&c server attack
# use command-and-control c&c server attack

# %%
'''
Create -tokens columns (list of words)
'''

for cat in dataframes.keys():
    df = dataframes[cat]
    cols = df.columns.tolist()
    for c in cols:
        if 'processed' in c:
            data = df[c]
            data = data.apply(lambda x : x.split())
            label = c.replace('processed', 'tokens')
            df[label] = data

# %%
def dummy(doc):
    return doc

from sklearn.feature_extraction.text import CountVectorizer
vectorizer = CountVectorizer(
    tokenizer=dummy,
    preprocessor=dummy
)

'''
Count unique words in all datasets after we processed them into tokens.
Compare -relations and -neighbours features.
What is the size of BOW?
'''

for cat in dataframes.keys():
    print("\n>>> {}".format(cat))
    df = dataframes[cat]
    
    print("\nModel z relacjami:")
    X_counts = vectorizer.fit_transform(df['text-rel-tokens']) # stwórz macierz liczbową z danych. W wierszach mamy kolejne dokumenty, w kolumnach kolejne pola wektora cech odpowiadające unikalnym słowom (bag of words)
    print("Liczba dokumentów: {x}".format(x=X_counts.shape[0]))
    print("Rozmiar wektora bag-of-words {x}".format(x=X_counts.shape[1]))
    
    print("\nModel 'sąsiedzi':")
    X_counts = vectorizer.fit_transform(df['text-neigh-tokens']) # stwórz macierz liczbową z danych. W wierszach mamy kolejne dokumenty, w kolumnach kolejne pola wektora cech odpowiadające unikalnym słowom (bag of words)
    print("Liczba dokumentów: {x}".format(x=X_counts.shape[0]))
    print("Rozmiar wektora bag-of-words {x}".format(x=X_counts.shape[1]))
    
    if 'Test' in cat:
        df_joined = df
        for ccat in dataframes.keys():
            if ccat.replace('Train', 'Test') == cat:
                df_joined = df_joined.append(dataframes[ccat], ignore_index=True)
                
                # Łączymy dataframe'y treningowe i testowe aby pokazać, że reprezentacja BOW
                # nie przyniesie 100% rezultatów - występują słowa które są w Train i nie ma ich w Test lub na odwrót
                print("\n>>> Połączenie {} + {}:".format(cat, ccat))
                X_counts = vectorizer.fit_transform(df_joined['text-rel-tokens'])
                print("Relacyjnie: {x}".format(x=X_counts.shape[1]))
                
                X_counts = vectorizer.fit_transform(df_joined['text-neigh-tokens'])
                print("Sąsiedzi: {x}".format(x=X_counts.shape[1]))
                
                break
# Out:
# >>> Other-Train
#
# Model z relacjami:
# Liczba dokumentów: 1154
# Rozmiar wektora bag-of-words 1327
#
# Model 'sąsiedzi':
# Liczba dokumentów: 1154
# Rozmiar wektora bag-of-words 1443
#
# >>> File-Test
#
# Model z relacjami:
# Liczba dokumentów: 80
# Rozmiar wektora bag-of-words 236
#
# Model 'sąsiedzi':
# Liczba dokumentów: 80
# Rozmiar wektora bag-of-words 246
#
# >>> Połączenie File-Test + File-Test:
# Relacyjnie: 236
# Sąsiedzi: 246
#
# >>> Network-Train
#
# Model z relacjami:
# Liczba dokumentów: 1154
# Rozmiar wektora bag-of-words 1327
#
# Model 'sąsiedzi':
# Liczba dokumentów: 1154
# Rozmiar wektora bag-of-words 1443
#
# >>> Network-Test
#
# Model z relacjami:
# Liczba dokumentów: 80
# Rozmiar wektora bag-of-words 236
#
# Model 'sąsiedzi':
# Liczba dokumentów: 80
# Rozmiar wektora bag-of-words 246
#
# >>> Połączenie Network-Test + Network-Train:
# Relacyjnie: 1374
# Sąsiedzi: 1509
#
# >>> Other-Test
#
# Model z relacjami:
# Liczba dokumentów: 80
# Rozmiar wektora bag-of-words 236
#
# Model 'sąsiedzi':
# Liczba dokumentów: 80
# Rozmiar wektora bag-of-words 246
#
# >>> Połączenie Other-Test + Other-Train:
# Relacyjnie: 1374
# Sąsiedzi: 1509
#
# >>> File-Train
#
# Model z relacjami:
# Liczba dokumentów: 1154
# Rozmiar wektora bag-of-words 1327
#
# Model 'sąsiedzi':
# Liczba dokumentów: 1154
# Rozmiar wektora bag-of-words 1443
#
# >>> command_and_control-Test
#
# Model z relacjami:
# Liczba dokumentów: 190
# Rozmiar wektora bag-of-words 505
#
# Model 'sąsiedzi':
# Liczba dokumentów: 190
# Rozmiar wektora bag-of-words 500
#
# >>> Połączenie command_and_control-Test + command_and_control-Test:
# Relacyjnie: 505
# Sąsiedzi: 500
#
# >>> infection_propagation-Train
#
# Model z relacjami:
# Liczba dokumentów: 2817
# Rozmiar wektora bag-of-words 2755
#
# Model 'sąsiedzi':
# Liczba dokumentów: 2817
# Rozmiar wektora bag-of-words 2798
#
# >>> infection_propagation-Test
#
# Model z relacjami:
# Liczba dokumentów: 190
# Rozmiar wektora bag-of-words 505
#
# Model 'sąsiedzi':
# Liczba dokumentów: 190
# Rozmiar wektora bag-of-words 500
#
# >>> Połączenie infection_propagation-Test + infection_propagation-Train:
# Relacyjnie: 2835
# Sąsiedzi: 2900
#
# >>> other-Train
#
# Model z relacjami:
# Liczba dokumentów: 2817
# Rozmiar wektora bag-of-words 2755
#
# Model 'sąsiedzi':
# Liczba dokumentów: 2817
# Rozmiar wektora bag-of-words 2798
#
# >>> command_and_control-Train
#
# Model z relacjami:
# Liczba dokumentów: 2817
# Rozmiar wektora bag-of-words 2755
#
# Model 'sąsiedzi':
# Liczba dokumentów: 2817
# Rozmiar wektora bag-of-words 2798
#
# >>> other-Test
#
# Model z relacjami:
# Liczba dokumentów: 190
# Rozmiar wektora bag-of-words 505
#
# Model 'sąsiedzi':
# Liczba dokumentów: 190
# Rozmiar wektora bag-of-words 500
#
# >>> Połączenie other-Test + other-Train:
# Relacyjnie: 2835
# Sąsiedzi: 2900

# %% [markdown]
# W arkuszu kalkulacyjnym możemy zobaczyć jak redukował się rozmiar BOW po przetworzeniu tekstu.
# https://docs.google.com/spreadsheets/d/1KUDvUCe77z-SJ9EKlfW-axWSYfTmHRG9v59b3BqvKmY/edit?usp=sharing

# %%
from data_helpers import get_top_occuring_words

'''
Show top occuring words found by our vectorizer.
We get words such as 'malwar' because we applied stemming to our datasets.
'''

how_many_words = 20
for cat in dataframes.keys():
    print("\n>>> {}".format(cat))
    df = dataframes[cat]
    
    print("\nModel z relacjami:")
    X_counts = vectorizer.fit_transform(df['text-rel-tokens']) # stwórz macierz liczbową z danych. W wierszach mamy kolejne dokumenty, w kolumnach kolejne pola wektora cech odpowiadające unikalnym słowom (bag of words)
    print("\tbag-of-words: {x}".format(x=X_counts.shape[1]))
    
    vocab = list(map(lambda x : [len(x), x], sorted(vectorizer.vocabulary_.keys(), key=lambda x : -1*len(x))))
    print("\t- longest words:")
    print(vocab[:how_many_words])
    print("\t- shortest words:")
    print(vocab[-how_many_words:])
    
    print("\t TOP:")
    result = get_top_occuring_words(X_counts, 10, vectorizer, df)
    for entry in result:
        print(entry[0])
        print(entry[1])
    
    print("\nModel 'sąsiedzi':")
    X_counts = vectorizer.fit_transform(df['text-neigh-tokens']) # stwórz macierz liczbową z danych. W wierszach mamy kolejne dokumenty, w kolumnach kolejne pola wektora cech odpowiadające unikalnym słowom (bag of words)
    print("\tbag-of-words: {x}".format(x=X_counts.shape[1]))
    
    vocab = list(map(lambda x : [len(x), x], sorted(vectorizer.vocabulary_.keys(), key=lambda x : -1*len(x))))
    print("\t- longest words:")
    print(vocab[:how_many_words])
    print("\t- shortest words:")
    print(vocab[-how_many_words:])
    
    print("\t TOP:")
    result = get_top_occuring_words(X_counts, 10, vectorizer, df)
    for entry in result:
        print(entry[0])
        print(entry[1])
# Out:
# >>> Other-Train
#
# Model z relacjami:
# 	bag-of-words: 1327
# 	- longest words:
# [[20, 'shared$=%systemroot%'], [19, 'command-and-control'], [19, 'name>&&mux=<encrypt'], [18, 'zwterminateprocess'], [18, '‘collectw3perfdata'], [18, 'savadminservice.ex'], [17, 'apptransferwiz.dl'], [17, 'nato_smtp@mail.ru'], [17, 'sharedtaskschedul'], [16, 'loadembeddedimag'], [16, 'nato_pop@mail.ru'], [16, 'internetopenurla'], [16, '3443-4344-c4ffff'], [16, 'attacker-control'], [16, 'hyf54&%9&jkmcxui'], [16, 'winlogonuserinit'], [15, 'internetreadfil'], [15, 'ccprojectmgr.ex'], [15, 'deviceiocontrol'], [15, 'dbt_devicearriv']]
# 	- shortest words:
# [[2, 'c0'], [2, 'b8'], [2, '3c'], [2, 'e5'], [2, '51'], [2, '64'], [2, '80'], [2, 'io'], [2, 'us'], [2, '10'], [2, 'xp'], [2, 'rc'], [2, 'os'], [2, 'hi'], [2, 'vb'], [2, 'vm'], [2, 'dn'], [2, '14'], [2, 'av'], [2, 'er']]
# 	 TOP:
# NoOther
# [('file', 198.0), ('execut', 99.0), ('malwar', 91.0), ('download', 86.0), ('thi', 71.0), ('command', 67.0), ('server', 66.0), ('connect', 55.0), ('data', 54.0), ('attack', 48.0)]
# Other
# [('driver', 61.0), ('dll', 56.0), ('process', 54.0), ('load', 53.0), ('use', 51.0), ('hook', 48.0), ('request', 43.0), ('servic', 39.0), ('registri', 39.0), ('name', 32.0)]
#
# Model 'sąsiedzi':
# 	bag-of-words: 1443
# 	- longest words:
# [[20, 'sharedtaskscheduler.'], [19, 'command-and-control'], [18, 'cipher-block-chain'], [18, 'zwterminateprocess'], [18, '‘collectw3perfdata'], [18, 'dllregisterserver.'], [17, 'apptransferwiz.dl'], [17, 'nato_smtp@mail.ru'], [17, 'digitalsignature.'], [17, 'ndismpausecomplet'], [16, 'loadembeddedimag'], [16, 'attacker-control'], [16, 'straightforward.'], [16, 'zwshutdownsystem'], [16, 'inj_snake_x64.dl'], [15, 'internetreadfil'], [15, 'communications.'], [15, 'ccprojectmgr.ex'], [15, 'configurations.'], [15, 'deviceiocontrol']]
# 	- shortest words:
# [[2, '20'], [2, '8.'], [2, 'd.'], [2, 'c:'], [2, 'e.'], [2, '64'], [2, 'ae'], [2, 'vp'], [2, 'ok'], [2, 'gp'], [2, 'er'], [2, '7.'], [2, 'go'], [2, 'os'], [2, 'hi'], [2, 'vb'], [2, '4.'], [2, 'dn'], [2, '14'], [2, 'c#']]
# 	 TOP:
# NoOther
# [('file', 150.0), ('execut', 122.0), ('download', 103.0), ('upload', 59.0), ('malwar', 57.0), ('connect', 54.0), ('command', 49.0), ('data', 46.0), ('thi', 44.0), ('send', 41.0)]
# Other
# [('load', 54.0), ('dll', 53.0), ('driver', 50.0), ('use', 49.0), ('hook', 45.0), ('process', 33.0), ('servic', 31.0), ('registri', 30.0), ('call', 29.0), ('file', 28.0)]
#
# >>> File-Test
#
# Model z relacjami:
# 	bag-of-words: 236
# 	- longest words:
# [[19, 'command-and-control'], [13, 'doublefantasi'], [13, 'some-variable'], [11, 'system-path'], [11, 'malware-rel'], [10, 'self-delet'], [10, 'svchost.ex'], [10, 'first-stag'], [10, 'termservic'], [9, 'compromis'], [9, 'side-load'], [9, 'hash-code'], [9, 'blacklist'], [9, 'temporari'], [9, 'adversari'], [9, 'arbitrari'], [9, 'kasperski'], [9, 'administr'], [8, 'tmp-file'], [8, 'jir-file']]
# 	- shortest words:
# [[3, 'ani'], [3, 'run'], [3, 'tcp'], [3, 'vpn'], [3, 'end'], [3, 'use'], [3, 'set'], [3, 'raw'], [3, 'bot'], [3, 'key'], [3, 'mbr'], [3, 'thi'], [3, 'ssh'], [3, 'atm'], [3, 'ftp'], [3, 'new'], [3, 'get'], [3, 'c&c'], [2, 'wa'], [2, 'c2']]
# 	 TOP:
# File
# [('file', 13.0), ('execut', 5.0), ('copi', 5.0), ('log', 4.0), ('event', 3.0), ('delet', 3.0), ('eve-file', 3.0), ('carbanak', 3.0), ('creat', 2.0), ('dump', 2.0)]
# no-File
# [('process', 5.0), ('page', 4.0), ('login', 4.0), ('victim', 4.0), ('tcp', 3.0), ('dropper', 3.0), ('malwar', 3.0), ('registri', 3.0), ('use', 3.0), ('connect', 2.0)]
# NoFile
# [('server', 11.0), ('download', 8.0), ('file', 7.0), ('c2', 5.0), ('malwar', 5.0), ('carbanak', 4.0), ('system-path', 4.0), ('data', 3.0), ('registri', 3.0), ('compon', 3.0)]
#
# Model 'sąsiedzi':
# 	bag-of-words: 246
# 	- longest words:
# [[14, 'administrator.'], [13, 'doublefantasi'], [13, 'capabilities.'], [13, 'some-variable'], [12, 'self-delete.'], [11, 'system-path'], [11, 'executable.'], [11, 'keystrokes;'], [10, 'reconnaiss'], [10, 'screenshot'], [10, 'first-stag'], [10, 'termservic'], [9, 'explorer.'], [9, 'similarli'], [9, 'microsoft'], [9, 'software.'], [9, 'side-load'], [9, 'defenses.'], [9, 'payloads.'], [9, 'temporari']]
# 	- shortest words:
# [[3, 'run'], [3, 'bot'], [3, 'doe'], [3, 'tcp'], [3, 'set'], [3, 'see'], [3, 'raw'], [3, 'thi'], [3, 'key'], [3, 'mbr'], [3, 'ssh'], [3, 'c&c'], [3, 'ftp'], [3, 'new'], [3, 'rdp'], [3, 'get'], [2, 'wa'], [2, 'os'], [2, 'c2'], [2, '22']]
# 	 TOP:
# File
# [('file', 14.0), ('log', 9.0), ('copi', 5.0), ('dump', 5.0), ('event', 5.0), ('execut', 4.0), ('delet', 4.0), ('carbanak', 4.0), ('password', 3.0), ('secur', 3.0)]
# no-File
# [('use', 4.0), ('login', 4.0), ('victim', 4.0), ('port', 3.0), ('tcp', 3.0), ('process', 3.0), ('10073', 2.0), ('page', 2.0), ('direct', 2.0), ('one', 2.0)]
# NoFile
# [('download', 8.0), ('file', 7.0), ('carbanak', 5.0), ('execut', 5.0), ('server', 4.0), ('user', 4.0), ('thi', 3.0), ('data', 3.0), ('wa', 3.0), ('c&c', 3.0)]
#
# >>> Network-Train
#
# Model z relacjami:
# 	bag-of-words: 1327
# 	- longest words:
# [[20, 'shared$=%systemroot%'], [19, 'command-and-control'], [19, 'name>&&mux=<encrypt'], [18, 'zwterminateprocess'], [18, '‘collectw3perfdata'], [18, 'savadminservice.ex'], [17, 'apptransferwiz.dl'], [17, 'nato_smtp@mail.ru'], [17, 'sharedtaskschedul'], [16, 'loadembeddedimag'], [16, 'nato_pop@mail.ru'], [16, 'internetopenurla'], [16, '3443-4344-c4ffff'], [16, 'attacker-control'], [16, 'hyf54&%9&jkmcxui'], [16, 'winlogonuserinit'], [15, 'internetreadfil'], [15, 'ccprojectmgr.ex'], [15, 'deviceiocontrol'], [15, 'dbt_devicearriv']]
# 	- shortest words:
# [[2, 'c0'], [2, 'b8'], [2, '3c'], [2, 'e5'], [2, '51'], [2, '64'], [2, '80'], [2, 'io'], [2, 'us'], [2, '10'], [2, 'xp'], [2, 'rc'], [2, 'os'], [2, 'hi'], [2, 'vb'], [2, 'vm'], [2, 'dn'], [2, '14'], [2, 'av'], [2, 'er']]
# 	 TOP:
# NoNetwork
# [('file', 154.0), ('execut', 106.0), ('driver', 71.0), ('dll', 66.0), ('load', 66.0), ('use', 63.0), ('process', 59.0), ('creat', 56.0), ('thi', 55.0), ('hook', 49.0)]
# Network
# [('download', 80.0), ('file', 69.0), ('malwar', 63.0), ('server', 62.0), ('connect', 54.0), ('command', 49.0), ('thi', 44.0), ('upload', 43.0), ('send', 41.0), ('c&c', 33.0)]
#
# Model 'sąsiedzi':
# 	bag-of-words: 1443
# 	- longest words:
# [[20, 'sharedtaskscheduler.'], [19, 'command-and-control'], [18, 'cipher-block-chain'], [18, 'zwterminateprocess'], [18, '‘collectw3perfdata'], [18, 'dllregisterserver.'], [17, 'apptransferwiz.dl'], [17, 'nato_smtp@mail.ru'], [17, 'digitalsignature.'], [17, 'ndismpausecomplet'], [16, 'loadembeddedimag'], [16, 'attacker-control'], [16, 'straightforward.'], [16, 'zwshutdownsystem'], [16, 'inj_snake_x64.dl'], [15, 'internetreadfil'], [15, 'communications.'], [15, 'ccprojectmgr.ex'], [15, 'configurations.'], [15, 'deviceiocontrol']]
# 	- shortest words:
# [[2, '20'], [2, '8.'], [2, 'd.'], [2, 'c:'], [2, 'e.'], [2, '64'], [2, 'ae'], [2, 'vp'], [2, 'ok'], [2, 'gp'], [2, 'er'], [2, '7.'], [2, 'go'], [2, 'os'], [2, 'hi'], [2, 'vb'], [2, '4.'], [2, 'dn'], [2, '14'], [2, 'c#']]
# 	 TOP:
# NoNetwork
# [('file', 130.0), ('execut', 109.0), ('load', 67.0), ('creat', 62.0), ('dll', 62.0), ('use', 61.0), ('driver', 60.0), ('hash-code', 46.0), ('hook', 45.0), ('system-path', 44.0)]
# Network
# [('download', 85.0), ('upload', 53.0), ('connect', 52.0), ('file', 48.0), ('send', 40.0), ('malwar', 39.0), ('command', 34.0), ('execut', 31.0), ('data', 29.0), ('thi', 28.0)]
#
# >>> Network-Test
#
# Model z relacjami:
# 	bag-of-words: 236
# 	- longest words:
# [[19, 'command-and-control'], [13, 'doublefantasi'], [13, 'some-variable'], [11, 'system-path'], [11, 'malware-rel'], [10, 'self-delet'], [10, 'svchost.ex'], [10, 'first-stag'], [10, 'termservic'], [9, 'compromis'], [9, 'side-load'], [9, 'hash-code'], [9, 'blacklist'], [9, 'temporari'], [9, 'adversari'], [9, 'arbitrari'], [9, 'kasperski'], [9, 'administr'], [8, 'tmp-file'], [8, 'jir-file']]
# 	- shortest words:
# [[3, 'ani'], [3, 'run'], [3, 'tcp'], [3, 'vpn'], [3, 'end'], [3, 'use'], [3, 'set'], [3, 'raw'], [3, 'bot'], [3, 'key'], [3, 'mbr'], [3, 'thi'], [3, 'ssh'], [3, 'atm'], [3, 'ftp'], [3, 'new'], [3, 'get'], [3, 'c&c'], [2, 'wa'], [2, 'c2']]
# 	 TOP:
# no-Network
# [('process', 5.0), ('execut', 3.0), ('creat', 3.0), ('log', 3.0), ('event', 3.0), ('eve-file', 3.0), ('ani', 3.0), ('malwar', 3.0), ('registri', 3.0), ('use', 3.0)]
# Network
# [('download', 9.0), ('server', 8.0), ('file', 6.0), ('victim', 5.0), ('page', 4.0), ('login', 4.0), ('c2', 4.0), ('system-path', 3.0), ('dropper', 3.0), ('sent', 3.0)]
# NoNetwork
# [('file', 12.0), ('carbanak', 5.0), ('execut', 5.0), ('copi', 4.0), ('malwar', 4.0), ('system-path', 3.0), ('creat', 3.0), ('run', 3.0), ('thi', 3.0), ('process', 3.0)]
#
# Model 'sąsiedzi':
# 	bag-of-words: 246
# 	- longest words:
# [[14, 'administrator.'], [13, 'doublefantasi'], [13, 'capabilities.'], [13, 'some-variable'], [12, 'self-delete.'], [11, 'system-path'], [11, 'executable.'], [11, 'keystrokes;'], [10, 'reconnaiss'], [10, 'screenshot'], [10, 'first-stag'], [10, 'termservic'], [9, 'explorer.'], [9, 'similarli'], [9, 'microsoft'], [9, 'software.'], [9, 'side-load'], [9, 'defenses.'], [9, 'payloads.'], [9, 'temporari']]
# 	- shortest words:
# [[3, 'run'], [3, 'bot'], [3, 'doe'], [3, 'tcp'], [3, 'set'], [3, 'see'], [3, 'raw'], [3, 'thi'], [3, 'key'], [3, 'mbr'], [3, 'ssh'], [3, 'c&c'], [3, 'ftp'], [3, 'new'], [3, 'rdp'], [3, 'get'], [2, 'wa'], [2, 'os'], [2, 'c2'], [2, '22']]
# 	 TOP:
# no-Network
# [('log', 6.0), ('dump', 5.0), ('event', 5.0), ('use', 4.0), ('file', 4.0), ('process', 4.0), ('wa', 3.0), ('creat', 3.0), ('password', 3.0), ('delet', 3.0)]
# Network
# [('download', 9.0), ('file', 6.0), ('victim', 5.0), ('login', 4.0), ('use', 3.0), ('execut', 3.0), ('addit', 3.0), ('sent', 3.0), ('drop', 3.0), ('server', 3.0)]
# NoNetwork
# [('file', 11.0), ('carbanak', 6.0), ('execut', 5.0), ('log', 5.0), ('copi', 4.0), ('user', 4.0), ('creat', 3.0), ('thi', 3.0), ('server', 3.0), ('process', 3.0)]
#
# >>> Other-Test
#
# Model z relacjami:
# 	bag-of-words: 236
# 	- longest words:
# [[19, 'command-and-control'], [13, 'doublefantasi'], [13, 'some-variable'], [11, 'system-path'], [11, 'malware-rel'], [10, 'self-delet'], [10, 'svchost.ex'], [10, 'first-stag'], [10, 'termservic'], [9, 'compromis'], [9, 'side-load'], [9, 'hash-code'], [9, 'blacklist'], [9, 'temporari'], [9, 'adversari'], [9, 'arbitrari'], [9, 'kasperski'], [9, 'administr'], [8, 'tmp-file'], [8, 'jir-file']]
# 	- shortest words:
# [[3, 'ani'], [3, 'run'], [3, 'tcp'], [3, 'vpn'], [3, 'end'], [3, 'use'], [3, 'set'], [3, 'raw'], [3, 'bot'], [3, 'key'], [3, 'mbr'], [3, 'thi'], [3, 'ssh'], [3, 'atm'], [3, 'ftp'], [3, 'new'], [3, 'get'], [3, 'c&c'], [2, 'wa'], [2, 'c2']]
# 	 TOP:
# no-Other
# [('page', 4.0), ('login', 4.0), ('victim', 4.0), ('log', 3.0), ('event', 3.0), ('eve-file', 3.0), ('dropper', 3.0), ('execut', 2.0), ('dump', 2.0), ('file', 2.0)]
# Other
# [('process', 8.0), ('registri', 5.0), ('malwar', 5.0), ('creat', 4.0), ('run', 3.0), ('use', 3.0), ('execut', 3.0), ('server', 3.0), ('name', 2.0), ('valu', 2.0)]
# NoOther
# [('file', 17.0), ('server', 8.0), ('download', 8.0), ('carbanak', 5.0), ('copi', 5.0), ('drop', 4.0), ('data', 4.0), ('c2', 4.0), ('system-path', 3.0), ('malwar', 3.0)]
#
# Model 'sąsiedzi':
# 	bag-of-words: 246
# 	- longest words:
# [[14, 'administrator.'], [13, 'doublefantasi'], [13, 'capabilities.'], [13, 'some-variable'], [12, 'self-delete.'], [11, 'system-path'], [11, 'executable.'], [11, 'keystrokes;'], [10, 'reconnaiss'], [10, 'screenshot'], [10, 'first-stag'], [10, 'termservic'], [9, 'explorer.'], [9, 'similarli'], [9, 'microsoft'], [9, 'software.'], [9, 'side-load'], [9, 'defenses.'], [9, 'payloads.'], [9, 'temporari']]
# 	- shortest words:
# [[3, 'run'], [3, 'bot'], [3, 'doe'], [3, 'tcp'], [3, 'set'], [3, 'see'], [3, 'raw'], [3, 'thi'], [3, 'key'], [3, 'mbr'], [3, 'ssh'], [3, 'c&c'], [3, 'ftp'], [3, 'new'], [3, 'rdp'], [3, 'get'], [2, 'wa'], [2, 'os'], [2, 'c2'], [2, '22']]
# 	 TOP:
# no-Other
# [('log', 6.0), ('dump', 5.0), ('event', 5.0), ('file', 4.0), ('login', 4.0), ('victim', 4.0), ('execut', 3.0), ('password', 3.0), ('delet', 3.0), ('secur', 3.0)]
# Other
# [('process', 6.0), ('creat', 4.0), ('user', 4.0), ('perform', 3.0), ('registri', 3.0), ('use', 3.0), ('set', 3.0), ('thi', 3.0), ('execut', 3.0), ('also', 2.0)]
# NoOther
# [('file', 16.0), ('download', 10.0), ('carbanak', 7.0), ('server', 5.0), ('copi', 4.0), ('drop', 4.0), ('execut', 4.0), ('compon', 3.0), ('payloads.', 3.0), ('data', 3.0)]
#
# >>> File-Train
#
# Model z relacjami:
# 	bag-of-words: 1327
# 	- longest words:
# [[20, 'shared$=%systemroot%'], [19, 'command-and-control'], [19, 'name>&&mux=<encrypt'], [18, 'zwterminateprocess'], [18, '‘collectw3perfdata'], [18, 'savadminservice.ex'], [17, 'apptransferwiz.dl'], [17, 'nato_smtp@mail.ru'], [17, 'sharedtaskschedul'], [16, 'loadembeddedimag'], [16, 'nato_pop@mail.ru'], [16, 'internetopenurla'], [16, '3443-4344-c4ffff'], [16, 'attacker-control'], [16, 'hyf54&%9&jkmcxui'], [16, 'winlogonuserinit'], [15, 'internetreadfil'], [15, 'ccprojectmgr.ex'], [15, 'deviceiocontrol'], [15, 'dbt_devicearriv']]
# 	- shortest words:
# [[2, 'c0'], [2, 'b8'], [2, '3c'], [2, 'e5'], [2, '51'], [2, '64'], [2, '80'], [2, 'io'], [2, 'us'], [2, '10'], [2, 'xp'], [2, 'rc'], [2, 'os'], [2, 'hi'], [2, 'vb'], [2, 'vm'], [2, 'dn'], [2, '14'], [2, 'av'], [2, 'er']]
# 	 TOP:
# File
# [('file', 129.0), ('execut', 87.0), ('creat', 32.0), ('write', 29.0), ('dropper', 28.0), ('malwar', 28.0), ('thi', 27.0), ('copi', 26.0), ('disk', 26.0), ('delet', 25.0)]
# NoFile
# [('file', 94.0), ('server', 94.0), ('use', 83.0), ('download', 83.0), ('malwar', 81.0), ('thi', 72.0), ('driver', 68.0), ('command', 64.0), ('connect', 61.0), ('dll', 61.0)]
#
# Model 'sąsiedzi':
# 	bag-of-words: 1443
# 	- longest words:
# [[20, 'sharedtaskscheduler.'], [19, 'command-and-control'], [18, 'cipher-block-chain'], [18, 'zwterminateprocess'], [18, '‘collectw3perfdata'], [18, 'dllregisterserver.'], [17, 'apptransferwiz.dl'], [17, 'nato_smtp@mail.ru'], [17, 'digitalsignature.'], [17, 'ndismpausecomplet'], [16, 'loadembeddedimag'], [16, 'attacker-control'], [16, 'straightforward.'], [16, 'zwshutdownsystem'], [16, 'inj_snake_x64.dl'], [15, 'internetreadfil'], [15, 'communications.'], [15, 'ccprojectmgr.ex'], [15, 'configurations.'], [15, 'deviceiocontrol']]
# 	- shortest words:
# [[2, '20'], [2, '8.'], [2, 'd.'], [2, 'c:'], [2, 'e.'], [2, '64'], [2, 'ae'], [2, 'vp'], [2, 'ok'], [2, 'gp'], [2, 'er'], [2, '7.'], [2, 'go'], [2, 'os'], [2, 'hi'], [2, 'vb'], [2, '4.'], [2, 'dn'], [2, '14'], [2, 'c#']]
# 	 TOP:
# File
# [('file', 102.0), ('execut', 91.0), ('creat', 36.0), ('write', 34.0), ('delet', 29.0), ('disk', 28.0), ('copi', 27.0), ('hash-code', 22.0), ('dropper', 18.0), ('written', 18.0)]
# NoFile
# [('download', 88.0), ('file', 76.0), ('use', 70.0), ('upload', 61.0), ('load', 58.0), ('connect', 57.0), ('driver', 56.0), ('dll', 56.0), ('thi', 54.0), ('malwar', 54.0)]
#
# >>> command_and_control-Test
#
# Model z relacjami:
# 	bag-of-words: 505
# 	- longest words:
# [[19, 'command-and-control'], [16, 'man-in-the-middl'], [16, 'attacker-control'], [15, 'privilege-escal'], [13, 'liveupdate.ex'], [13, 'self-destruct'], [13, 'cve-2012-0158'], [13, 'cve-2014-1761'], [12, 'intermediari'], [12, 'equationdrug'], [12, 'mediasoft.ex'], [11, 'system-path'], [11, 'malware-rel'], [11, 'shellexecut'], [11, 'vietnamese-'], [11, 'windows-bas'], [11, 'architectur'], [10, 'self-delet'], [10, 'reconnaiss'], [10, 'screenshot']]
# 	- shortest words:
# [[3, 'tmg'], [3, 'etc'], [3, 'atm'], [3, 'add'], [3, 'rat'], [3, 'ssl'], [3, 'ftp'], [3, 'new'], [3, 'rar'], [2, 'ha'], [2, 'ip'], [2, 'wa'], [2, 'dn'], [2, 'os'], [2, 'vf'], [2, 'go'], [2, 'pc'], [2, 'c2'], [2, '20'], [2, 'ic']]
# 	 TOP:
# command_and_control
# [('server', 21.0), ('c&c', 15.0), ('c2', 9.0), ('report', 7.0), ('malwar', 5.0), ('configur', 5.0), ('use', 4.0), ('command', 4.0), ('send', 4.0), ('attack', 3.0)]
# no-command_and_control
# [('file', 19.0), ('system', 18.0), ('thi', 17.0), ('malwar', 17.0), ('server', 16.0), ('infect', 16.0), ('data', 16.0), ('attack', 14.0), ('access', 11.0), ('use', 11.0)]
#
# Model 'sąsiedzi':
# 	bag-of-words: 500
# 	- longest words:
# [[19, 'command-and-control'], [16, 'man-in-the-middl'], [15, 'infrastructure.'], [15, 'communications.'], [15, 'privilege-escal'], [14, 'automatically.'], [13, 'self-destruct'], [13, 'doublefantasi'], [13, 'certificates.'], [13, 'cve-2014-1761'], [12, 'self-delete.'], [12, 'intermediari'], [12, 'equationdrug'], [12, 'mediasoft.ex'], [12, 'compromised.'], [12, 'particularli'], [11, 'system-path'], [11, 'infections.'], [11, 'shellexecut'], [11, 'appendixes.']]
# 	- shortest words:
# [[3, 'ssh'], [3, 'rat'], [3, 'via'], [3, 'get'], [3, 'mbr'], [3, 'got'], [3, 'at-'], [3, 'add'], [3, 'act'], [3, 'ftp'], [3, 'new'], [3, 'rdp'], [2, 'ip'], [2, '};'], [2, 'wa'], [2, 'dn'], [2, 'os'], [2, 'go'], [2, 'c2'], [2, '20']]
# 	 TOP:
# command_and_control
# [('server', 11.0), ('c&c', 10.0), ('configur', 6.0), ('use', 4.0), ('report', 4.0), ('send', 4.0), ('c2', 4.0), ('command', 3.0), ('sent', 3.0), ('carbanak', 3.0)]
# no-command_and_control
# [('use', 25.0), ('file', 17.0), ('system', 13.0), ('infect', 12.0), ('malwar', 12.0), ('attack', 11.0), ('thi', 11.0), ('data', 11.0), ('wa', 10.0), ('exfiltr', 10.0)]
#
# >>> infection_propagation-Train
#
# Model z relacjami:
# 	bag-of-words: 2755
# 	- longest words:
# [[19, 'command-and-control'], [19, 'name>&&mux=<encrypt'], [18, 'opposition-control'], [18, 'cipher-block-chain'], [18, 'dexclassloaderload'], [18, 'savadminservice.ex'], [17, 'mrconstrucciones.'], [17, 'obopenobjectbynam'], [17, 'nato_smtp@mail.ru'], [17, 'apptransferwiz.dl'], [17, 'intelligence-gath'], [16, 'nato_pop@mail.ru'], [16, '3443-4344-c4ffff'], [16, 'attacker-control'], [16, 'name>&&date=<fil'], [16, 'defaultwsdotasmx'], [16, 'content-disposit'], [16, 'hyf54&%9&jkmcxui'], [16, 'password-protect'], [16, 'internetopenurla']]
# 	- shortest words:
# [[2, 'mz'], [2, 'v1'], [2, '10'], [2, 'go'], [2, 'en'], [2, '20'], [2, 'iv'], [2, 'ae'], [2, '16'], [2, 'vb'], [2, 'ga'], [2, 'ii'], [2, 'vm'], [2, 'ra'], [2, 'kd'], [2, '免查'], [2, 'c#'], [2, '23'], [2, 'sm'], [2, '4h']]
# 	 TOP:
# no-infection/propagation
# [('use', 272.0), ('server', 257.0), ('thi', 253.0), ('attack', 246.0), ('malwar', 229.0), ('file', 228.0), ('command', 208.0), ('data', 173.0), ('system', 158.0), ('c&c', 141.0)]
# infection/propagation
# [('attack', 131.0), ('target', 93.0), ('use', 81.0), ('exploit', 61.0), ('infect', 59.0), ('file', 55.0), ('thi', 50.0), ('malwar', 49.0), ('phish', 40.0), ('email', 40.0)]
#
# Model 'sąsiedzi':
# 	bag-of-words: 2798
# 	- longest words:
# [[20, 'sharedtaskscheduler.'], [19, 'command-and-control'], [19, 'zwquerysysteminform'], [18, 'zwterminateprocess'], [18, 'cipher-block-chain'], [17, 'nato_smtp@mail.ru'], [17, 'digitalsignature.'], [17, 'defaultwsdotasmx.'], [17, 'baden-wurttemberg'], [17, 'politically-motiv'], [17, 'apptransferwiz.dl'], [17, 'intelligence-gath'], [16, 'inj_snake_x64.dl'], [16, 'attacker-control'], [16, 'content-disposit'], [16, 'password-protect'], [16, '................'], [16, 'usbdrv3_32bit.si'], [16, 'straightforward.'], [16, 'vulnerabilities.']]
# 	- shortest words:
# [[2, '13'], [2, 'e:'], [2, 'go'], [2, 'xp'], [2, 'iv'], [2, '16'], [2, 'ae'], [2, '02'], [2, '06'], [2, 'ii'], [2, 'pc'], [2, 'vm'], [2, 'a.'], [2, '25'], [2, '20'], [2, 'a:'], [2, 'ic'], [2, 'sm'], [2, 'gp'], [2, '4h']]
# 	 TOP:
# no-infection/propagation
# [('use', 254.0), ('thi', 191.0), ('file', 191.0), ('attack', 157.0), ('command', 147.0), ('malwar', 144.0), ('data', 143.0), ('server', 127.0), ('execut', 118.0), ('c&c', 111.0)]
# infection/propagation
# [('attack', 98.0), ('use', 79.0), ('target', 61.0), ('infect', 56.0), ('exploit', 48.0), ('thi', 47.0), ('malwar', 36.0), ('file', 33.0), ('email', 30.0), ('wa', 28.0)]
#
# >>> infection_propagation-Test
#
# Model z relacjami:
# 	bag-of-words: 505
# 	- longest words:
# [[19, 'command-and-control'], [16, 'man-in-the-middl'], [16, 'attacker-control'], [15, 'privilege-escal'], [13, 'liveupdate.ex'], [13, 'self-destruct'], [13, 'cve-2012-0158'], [13, 'cve-2014-1761'], [12, 'intermediari'], [12, 'equationdrug'], [12, 'mediasoft.ex'], [11, 'system-path'], [11, 'malware-rel'], [11, 'shellexecut'], [11, 'vietnamese-'], [11, 'windows-bas'], [11, 'architectur'], [10, 'self-delet'], [10, 'reconnaiss'], [10, 'screenshot']]
# 	- shortest words:
# [[3, 'tmg'], [3, 'etc'], [3, 'atm'], [3, 'add'], [3, 'rat'], [3, 'ssl'], [3, 'ftp'], [3, 'new'], [3, 'rar'], [2, 'ha'], [2, 'ip'], [2, 'wa'], [2, 'dn'], [2, 'os'], [2, 'vf'], [2, 'go'], [2, 'pc'], [2, 'c2'], [2, '20'], [2, 'ic']]
# 	 TOP:
# no-infection/propagation
# [('server', 33.0), ('file', 22.0), ('malwar', 20.0), ('data', 18.0), ('c&c', 17.0), ('system', 17.0), ('thi', 15.0), ('attack', 14.0), ('use', 13.0), ('infect', 13.0)]
# infection/propagation
# [('exploit', 4.0), ('server', 4.0), ('infect', 4.0), ('network', 3.0), ('attack', 3.0), ('target', 3.0), ('phish', 3.0), ('legitim', 3.0), ('malici', 3.0), ('document', 3.0)]
#
# Model 'sąsiedzi':
# 	bag-of-words: 500
# 	- longest words:
# [[19, 'command-and-control'], [16, 'man-in-the-middl'], [15, 'infrastructure.'], [15, 'communications.'], [15, 'privilege-escal'], [14, 'automatically.'], [13, 'self-destruct'], [13, 'doublefantasi'], [13, 'certificates.'], [13, 'cve-2014-1761'], [12, 'self-delete.'], [12, 'intermediari'], [12, 'equationdrug'], [12, 'mediasoft.ex'], [12, 'compromised.'], [12, 'particularli'], [11, 'system-path'], [11, 'infections.'], [11, 'shellexecut'], [11, 'appendixes.']]
# 	- shortest words:
# [[3, 'ssh'], [3, 'rat'], [3, 'via'], [3, 'get'], [3, 'mbr'], [3, 'got'], [3, 'at-'], [3, 'add'], [3, 'act'], [3, 'ftp'], [3, 'new'], [3, 'rdp'], [2, 'ip'], [2, '};'], [2, 'wa'], [2, 'dn'], [2, 'os'], [2, 'go'], [2, 'c2'], [2, '20']]
# 	 TOP:
# no-infection/propagation
# [('use', 27.0), ('file', 18.0), ('server', 16.0), ('data', 13.0), ('malwar', 13.0), ('attack', 12.0), ('system', 12.0), ('download', 12.0), ('infect', 11.0), ('c&c', 10.0)]
# infection/propagation
# [('target', 3.0), ('infect', 3.0), ('spread', 2.0), ('network', 2.0), ('exploit', 2.0), ('onli', 2.0), ('specif', 2.0), ('devic', 2.0), ('find', 2.0), ('attempt', 2.0)]
#
# >>> other-Train
#
# Model z relacjami:
# 	bag-of-words: 2755
# 	- longest words:
# [[19, 'command-and-control'], [19, 'name>&&mux=<encrypt'], [18, 'opposition-control'], [18, 'cipher-block-chain'], [18, 'dexclassloaderload'], [18, 'savadminservice.ex'], [17, 'mrconstrucciones.'], [17, 'obopenobjectbynam'], [17, 'nato_smtp@mail.ru'], [17, 'apptransferwiz.dl'], [17, 'intelligence-gath'], [16, 'nato_pop@mail.ru'], [16, '3443-4344-c4ffff'], [16, 'attacker-control'], [16, 'name>&&date=<fil'], [16, 'defaultwsdotasmx'], [16, 'content-disposit'], [16, 'hyf54&%9&jkmcxui'], [16, 'password-protect'], [16, 'internetopenurla']]
# 	- shortest words:
# [[2, 'mz'], [2, 'v1'], [2, '10'], [2, 'go'], [2, 'en'], [2, '20'], [2, 'iv'], [2, 'ae'], [2, '16'], [2, 'vb'], [2, 'ga'], [2, 'ii'], [2, 'vm'], [2, 'ra'], [2, 'kd'], [2, '免查'], [2, 'c#'], [2, '23'], [2, 'sm'], [2, '4h']]
# 	 TOP:
# no-other
# [('use', 186.0), ('server', 185.0), ('attack', 172.0), ('command', 129.0), ('c&c', 127.0), ('malwar', 122.0), ('thi', 114.0), ('target', 96.0), ('file', 92.0), ('c2', 91.0)]
# other
# [('attack', 205.0), ('file', 191.0), ('thi', 189.0), ('use', 167.0), ('malwar', 156.0), ('system', 145.0), ('data', 142.0), ('inform', 116.0), ('tool', 102.0), ('backdoor', 99.0)]
#
# Model 'sąsiedzi':
# 	bag-of-words: 2798
# 	- longest words:
# [[20, 'sharedtaskscheduler.'], [19, 'command-and-control'], [19, 'zwquerysysteminform'], [18, 'zwterminateprocess'], [18, 'cipher-block-chain'], [17, 'nato_smtp@mail.ru'], [17, 'digitalsignature.'], [17, 'defaultwsdotasmx.'], [17, 'baden-wurttemberg'], [17, 'politically-motiv'], [17, 'apptransferwiz.dl'], [17, 'intelligence-gath'], [16, 'inj_snake_x64.dl'], [16, 'attacker-control'], [16, 'content-disposit'], [16, 'password-protect'], [16, '................'], [16, 'usbdrv3_32bit.si'], [16, 'straightforward.'], [16, 'vulnerabilities.']]
# 	- shortest words:
# [[2, '13'], [2, 'e:'], [2, 'go'], [2, 'xp'], [2, 'iv'], [2, '16'], [2, 'ae'], [2, '02'], [2, '06'], [2, 'ii'], [2, 'pc'], [2, 'vm'], [2, 'a.'], [2, '25'], [2, '20'], [2, 'a:'], [2, 'ic'], [2, 'sm'], [2, 'gp'], [2, '4h']]
# 	 TOP:
# no-other
# [('use', 173.0), ('attack', 117.0), ('server', 96.0), ('thi', 88.0), ('c&c', 84.0), ('command', 82.0), ('malwar', 79.0), ('commun', 76.0), ('connect', 72.0), ('target', 66.0)]
# other
# [('file', 164.0), ('use', 160.0), ('thi', 150.0), ('attack', 138.0), ('data', 115.0), ('malwar', 101.0), ('execut', 96.0), ('system', 93.0), ('encrypt', 93.0), ('download', 92.0)]
#
# >>> command_and_control-Train
#
# Model z relacjami:
# 	bag-of-words: 2755
# 	- longest words:
# [[19, 'command-and-control'], [19, 'name>&&mux=<encrypt'], [18, 'opposition-control'], [18, 'cipher-block-chain'], [18, 'dexclassloaderload'], [18, 'savadminservice.ex'], [17, 'mrconstrucciones.'], [17, 'obopenobjectbynam'], [17, 'nato_smtp@mail.ru'], [17, 'apptransferwiz.dl'], [17, 'intelligence-gath'], [16, 'nato_pop@mail.ru'], [16, '3443-4344-c4ffff'], [16, 'attacker-control'], [16, 'name>&&date=<fil'], [16, 'defaultwsdotasmx'], [16, 'content-disposit'], [16, 'hyf54&%9&jkmcxui'], [16, 'password-protect'], [16, 'internetopenurla']]
# 	- shortest words:
# [[2, 'mz'], [2, 'v1'], [2, '10'], [2, 'go'], [2, 'en'], [2, '20'], [2, 'iv'], [2, 'ae'], [2, '16'], [2, 'vb'], [2, 'ga'], [2, 'ii'], [2, 'vm'], [2, 'ra'], [2, 'kd'], [2, '免查'], [2, 'c#'], [2, '23'], [2, 'sm'], [2, '4h']]
# 	 TOP:
# command_and_control
# [('server', 172.0), ('command', 128.0), ('c&c', 124.0), ('use', 105.0), ('commun', 91.0), ('c2', 90.0), ('connect', 83.0), ('malwar', 73.0), ('control', 70.0), ('thi', 64.0)]
# no-command_and_control
# [('attack', 336.0), ('use', 248.0), ('file', 246.0), ('thi', 239.0), ('malwar', 205.0), ('system', 169.0), ('data', 146.0), ('target', 143.0), ('inform', 126.0), ('network', 123.0)]
#
# Model 'sąsiedzi':
# 	bag-of-words: 2798
# 	- longest words:
# [[20, 'sharedtaskscheduler.'], [19, 'command-and-control'], [19, 'zwquerysysteminform'], [18, 'zwterminateprocess'], [18, 'cipher-block-chain'], [17, 'nato_smtp@mail.ru'], [17, 'digitalsignature.'], [17, 'defaultwsdotasmx.'], [17, 'baden-wurttemberg'], [17, 'politically-motiv'], [17, 'apptransferwiz.dl'], [17, 'intelligence-gath'], [16, 'inj_snake_x64.dl'], [16, 'attacker-control'], [16, 'content-disposit'], [16, 'password-protect'], [16, '................'], [16, 'usbdrv3_32bit.si'], [16, 'straightforward.'], [16, 'vulnerabilities.']]
# 	- shortest words:
# [[2, '13'], [2, 'e:'], [2, 'go'], [2, 'xp'], [2, 'iv'], [2, '16'], [2, 'ae'], [2, '02'], [2, '06'], [2, 'ii'], [2, 'pc'], [2, 'vm'], [2, 'a.'], [2, '25'], [2, '20'], [2, 'a:'], [2, 'ic'], [2, 'sm'], [2, 'gp'], [2, '4h']]
# 	 TOP:
# command_and_control
# [('use', 94.0), ('server', 84.0), ('c&c', 83.0), ('command', 81.0), ('commun', 75.0), ('connect', 71.0), ('c2', 46.0), ('send', 44.0), ('malwar', 43.0), ('thi', 41.0)]
# no-command_and_control
# [('use', 239.0), ('attack', 236.0), ('file', 197.0), ('thi', 197.0), ('malwar', 137.0), ('data', 119.0), ('execut', 110.0), ('instal', 109.0), ('system', 107.0), ('download', 103.0)]
#
# >>> other-Test
#
# Model z relacjami:
# 	bag-of-words: 505
# 	- longest words:
# [[19, 'command-and-control'], [16, 'man-in-the-middl'], [16, 'attacker-control'], [15, 'privilege-escal'], [13, 'liveupdate.ex'], [13, 'self-destruct'], [13, 'cve-2012-0158'], [13, 'cve-2014-1761'], [12, 'intermediari'], [12, 'equationdrug'], [12, 'mediasoft.ex'], [11, 'system-path'], [11, 'malware-rel'], [11, 'shellexecut'], [11, 'vietnamese-'], [11, 'windows-bas'], [11, 'architectur'], [10, 'self-delet'], [10, 'reconnaiss'], [10, 'screenshot']]
# 	- shortest words:
# [[3, 'tmg'], [3, 'etc'], [3, 'atm'], [3, 'add'], [3, 'rat'], [3, 'ssl'], [3, 'ftp'], [3, 'new'], [3, 'rar'], [2, 'ha'], [2, 'ip'], [2, 'wa'], [2, 'dn'], [2, 'os'], [2, 'vf'], [2, 'go'], [2, 'pc'], [2, 'c2'], [2, '20'], [2, 'ic']]
# 	 TOP:
# no-other
# [('server', 25.0), ('c&c', 15.0), ('c2', 9.0), ('malwar', 7.0), ('report', 7.0), ('attack', 6.0), ('use', 6.0), ('configur', 5.0), ('infect', 5.0), ('command', 4.0)]
# other
# [('file', 19.0), ('system', 17.0), ('data', 16.0), ('malwar', 15.0), ('thi', 15.0), ('infect', 12.0), ('server', 12.0), ('attack', 11.0), ('tool', 11.0), ('access', 10.0)]
#
# Model 'sąsiedzi':
# 	bag-of-words: 500
# 	- longest words:
# [[19, 'command-and-control'], [16, 'man-in-the-middl'], [15, 'infrastructure.'], [15, 'communications.'], [15, 'privilege-escal'], [14, 'automatically.'], [13, 'self-destruct'], [13, 'doublefantasi'], [13, 'certificates.'], [13, 'cve-2014-1761'], [12, 'self-delete.'], [12, 'intermediari'], [12, 'equationdrug'], [12, 'mediasoft.ex'], [12, 'compromised.'], [12, 'particularli'], [11, 'system-path'], [11, 'infections.'], [11, 'shellexecut'], [11, 'appendixes.']]
# 	- shortest words:
# [[3, 'ssh'], [3, 'rat'], [3, 'via'], [3, 'get'], [3, 'mbr'], [3, 'got'], [3, 'at-'], [3, 'add'], [3, 'act'], [3, 'ftp'], [3, 'new'], [3, 'rdp'], [2, 'ip'], [2, '};'], [2, 'wa'], [2, 'dn'], [2, 'os'], [2, 'go'], [2, 'c2'], [2, '20']]
# 	 TOP:
# no-other
# [('server', 13.0), ('c&c', 10.0), ('use', 6.0), ('configur', 6.0), ('infect', 5.0), ('report', 4.0), ('send', 4.0), ('c2', 4.0), ('attack', 3.0), ('command', 3.0)]
# other
# [('use', 23.0), ('file', 17.0), ('system', 12.0), ('malwar', 12.0), ('data', 11.0), ('attack', 10.0), ('exfiltr', 10.0), ('access', 9.0), ('log', 9.0), ('infect', 9.0)]

# %%
from sklearn.decomposition import PCA, TruncatedSVD
import matplotlib
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt

'''
Display PCA analysis results for the vectorizer above.
'''

def plot_LSA(test_data, test_labels, ax, savepath="PCA_demo.csv", plot=True):
        lsa = TruncatedSVD(n_components=2)
        lsa.fit(test_data)
        lsa_scores = lsa.transform(test_data)
        color_mapper = {label:idx for idx,label in enumerate(set(test_labels))}
        color_column = [color_mapper[label] for label in test_labels]
        colors = ['orange','blue']
        
        if plot:
            ax.scatter(lsa_scores[:,0], lsa_scores[:,1], s=1.5, alpha=.8, c=test_labels, cmap=matplotlib.colors.ListedColormap(colors))
            red_patch = mpatches.Patch(color='orange', label='No')
            green_patch = mpatches.Patch(color='blue', label='Yes')
            ax.legend(handles=[red_patch, green_patch], prop={'size': 10})

for cat in dataframes.keys():

    df = dataframes[cat]
    labels = df['label_num'].tolist()
    f, (ax1, ax2) = plt.subplots(1, 2, sharey=True, figsize=(12, 6))
    
    X_counts = vectorizer.fit_transform(df['text-neigh-tokens'])
    plot_LSA(X_counts, labels, ax1)
    ax1.set_title("{} - neighbours".format(cat))
    
    X_counts = vectorizer.fit_transform(df['text-rel-tokens'])
    plot_LSA(X_counts, labels, ax2)
    ax2.set_title("{} - relations".format(cat))

# %%
'''
Take another try with TF IDF vectorizer
for min_df = 0.1 we get only words common for both classes, such as 'file', 'data', 'malwar' ...
- min_df = 0.05 is quite better, but doesn't show differences neither

'''

from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(
    tokenizer=dummy,
    preprocessor=dummy,
    max_df=0.05
)

# %%
for cat in dataframes.keys():
    print("\n>>> {}".format(cat))
    df = dataframes[cat]
    
    print("\nModel z relacjami:")
    X_counts = vectorizer.fit_transform(df['text-rel-tokens']) # stwórz macierz liczbową z danych. W wierszach mamy kolejne dokumenty, w kolumnach kolejne pola wektora cech odpowiadające unikalnym słowom (bag of words)
    print("bag-of-words: {x}".format(x=X_counts.shape[1]))
    result = get_top_occuring_words(X_counts, 10, vectorizer, df)
    for entry in result:
        print(entry[0])
        print(entry[1])
    
    print("\nModel 'sąsiedzi':")
    X_counts = vectorizer.fit_transform(df['text-neigh-tokens']) # stwórz macierz liczbową z danych. W wierszach mamy kolejne dokumenty, w kolumnach kolejne pola wektora cech odpowiadające unikalnym słowom (bag of words)
    print("bag-of-words: {x}".format(x=X_counts.shape[1]))
    result = get_top_occuring_words(X_counts, 10, vectorizer, df)
    for entry in result:
        print(entry[0])
        print(entry[1])
# Out:
# >>> Other-Train
#
# Model z relacjami:
# bag-of-words: 1313
# NoOther
# [('upload', 20.814932639369335), ('attack', 18.212039414347345), ('c&c', 14.717019431150202), ('dropper', 14.379594096445043), ('send', 14.301057592430176), ('com-file', 13.929241698029863), ('delet', 13.628948364140154), ('copi', 13.06421153946895), ('write', 12.75084867445688), ('creat', 12.051504881411287)]
# Other
# [('hook', 15.499770018081316), ('servic', 15.264658629721888), ('request', 13.838331680205723), ('registri', 12.985759177432064), ('pipe', 11.990890875814962), ('post', 11.75549943365872), ('call', 11.347531461828078), ('api', 10.471466857127378), ('name', 10.19079754982894), ('key', 10.145719211856091)]
#
# Model 'sąsiedzi':
# bag-of-words: 1429
# NoOther
# [('command', 16.746925697212617), ('send', 13.94044575993644), ('copi', 13.026739648144588), ('write', 12.962088363055736), ('delet', 12.44589842381992), ('disk', 12.40964784473976), ('drop', 11.75969160412953), ('c&c', 10.375922811493854), ('sent', 10.168566888162193), ('system-path', 10.12532340744642)]
# Other
# [('hook', 14.708149659198197), ('servic', 12.360380675514161), ('process', 10.85306757433728), ('registri', 10.17482821095504), ('call', 10.041420904843983), ('post', 9.139004178414563), ('request', 8.792599109441134), ('inject', 8.579624272156522), ('instal', 8.417366639096858), ('system-path', 8.229993488219472)]
#
# >>> File-Test
#
# Model z relacjami:
# bag-of-words: 219
# File
# [('delet', 2.544268590159723), ('log', 1.8442343673604467), ('eve-file', 1.5025959133012061), ('save', 1.4228399937248053), ('event', 1.3689742149162862), ('modifi', 1.355496718084142), ('dump', 1.1828481488259341), ('tmp-file', 1.0), ('some-variable', 1.0), ('payload', 1.0)]
# no-File
# [('login', 1.4897668847911305), ('page', 1.4897668847911305), ('tcp', 1.2509765699079671), ('use', 1.0208397869588826), ('dropper', 0.9584809057992432), ('port', 0.907784371857365), ('10073', 0.907784371857365), ('connect', 0.907784371857365), ('legitim', 0.772301139990123), ('librari', 0.7503084400302059)]
# NoFile
# [('compon', 1.7726245450629299), ('sent', 1.6487798780792726), ('addit', 1.4957894641638376), ('administr', 1.3212032573170025), ('servic', 1.081370451509235), ('new', 1.0728176139466463), ('perform', 1.0653266731940532), ('plu-file', 1.0), ('payload', 1.0), ('termin', 1.0)]
#
# Model 'sąsiedzi':
# bag-of-words: 228
# File
# [('password', 1.5704086798290173), ('secur', 1.5375073410276916), ('system-path', 1.455547588612787), ('modifi', 1.2363898942839857), ('pars', 1.1573553148629663), ('interest', 1.1061597967861323), ('edit', 1.0997904656719317), ('one', 0.9729526114622051), ('save', 0.9642303113561419), ('deploy', 0.9127588958060215)]
# no-File
# [('login', 1.636467464425785), ('tcp', 1.186395070593146), ('port', 1.186395070593146), ('kill', 1.026862516736434), ('page', 0.9643407418022233), ('set', 0.9084299345299679), ('also', 0.8877510893531185), ('direct', 0.8577130238273962), ('persist', 0.8541136695244488), ('look', 0.8506599064928889)]
# NoFile
# [('user', 1.6931540534029836), ('c&c', 1.5703497475883872), ('payloads.', 1.2706592588570922), ('reach', 1.1466976110320533), ('compon', 1.1409027468601705), ('data', 1.0971277967159194), ('addit', 1.0936413983280127), ('new', 1.081264266954888), ('c2', 0.9987147300548802), ('transfer', 0.9742543428816524)]
#
# >>> Network-Train
#
# Model z relacjami:
# bag-of-words: 1313
# NoNetwork
# [('creat', 20.330993555714265), ('dropper', 18.698387533507145), ('servic', 15.898686343569873), ('write', 15.799873820772492), ('hook', 15.75927867416481), ('run', 15.438087403507456), ('delet', 15.269449243144196), ('request', 14.19009125189315), ('name', 14.04989059902547), ('registri', 13.95774026945761)]
# Network
# [('upload', 20.814932639369335), ('c&c', 14.717019431150202), ('send', 14.301057592430176), ('com-file', 13.929241698029863), ('attack', 11.658645208253441), ('sent', 11.218180983092761), ('c2', 9.478304642877688), ('control', 8.759686458824007), ('receiv', 8.726051598393653), ('port', 8.104908709068548)]
#
# Model 'sąsiedzi':
# bag-of-words: 1429
# NoNetwork
# [('write', 15.629486728499904), ('hook', 14.708149659198197), ('system-path', 14.657405689202479), ('servic', 13.540136484785423), ('disk', 13.43806038145389), ('copi', 13.304041204090613), ('delet', 13.272529795032263), ('dropper', 12.58164031665741), ('modul', 12.24457628375654), ('process', 11.785152220787676)]
# Network
# [('send', 13.625665202472083), ('command', 11.845321429924896), ('c&c', 9.976105311422756), ('sent', 9.791831061180782), ('receiv', 8.365312093785972), ('server', 7.341771175971443), ('com-file', 7.158861991701873), ('back', 6.543453387917152), ('c2', 6.394710774099197), ('exploit', 6.1864862376832574)]
#
# >>> Network-Test
#
# Model z relacjami:
# bag-of-words: 219
# no-Network
# [('delet', 1.544268590159723), ('eve-file', 1.5025959133012061), ('event', 1.3689742149162862), ('log', 1.2927601504132413), ('dump', 1.1828481488259341), ('tool', 1.1703451220611585), ('use', 1.0208397869588826), ('tmp-file', 1.0), ('ani', 0.968024161631577), ('tcp', 0.8782377189051724)]
# Network
# [('sent', 1.9657806739935433), ('addit', 1.4957894641638376), ('login', 1.4897668847911305), ('page', 1.4897668847911305), ('compon', 1.4625876119987498), ('plu-file', 1.0), ('payload', 1.0), ('dropper', 0.9584809057992432), ('transfer', 0.9452267802022345), ('legitim', 0.772301139990123)]
# NoNetwork
# [('administr', 1.3212032573170025), ('thi', 1.2362750085718701), ('servic', 1.081370451509235), ('new', 1.0728176139466463), ('perform', 1.0653266731940532), ('some-variable', 1.0), ('save', 1.0), ('payload', 1.0), ('delet', 1.0), ('modifi', 1.0)]
#
# Model 'sąsiedzi':
# bag-of-words: 228
# no-Network
# [('password', 1.5704086798290173), ('secur', 1.5375073410276916), ('also', 1.3174373625505427), ('pars', 1.1573553148629663), ('interest', 1.1061597967861323), ('edit', 1.0997904656719317), ('tool', 1.0945436111697577), ('kill', 1.026862516736434), ('end', 0.9841754522312681), ('one', 0.9630812591385247)]
# Network
# [('login', 1.636467464425785), ('addit', 1.5175479985173026), ('sent', 1.4076876723492895), ('payloads.', 1.2706592588570922), ('reach', 1.1466976110320533), ('compon', 1.1409027468601705), ('c2', 0.9987147300548802), ('transfer', 0.9742543428816524), ('page', 0.9643407418022233), ('direct', 0.8577130238273962)]
# NoNetwork
# [('user', 1.6931540534029836), ('registri', 1.1380292377418242), ('system', 1.1061597967861323), ('new', 1.081264266954888), ('system-path', 1.0489544657354135), ('credit', 0.9660390523862028), ('card', 0.9660390523862028), ('deploy', 0.9127588958060215), ('keystrokes;', 0.8973108674013992), ('files;', 0.8973108674013992)]
#
# >>> Other-Test
#
# Model z relacjami:
# bag-of-words: 219
# no-Other
# [('delet', 1.544268590159723), ('eve-file', 1.5025959133012061), ('librari', 1.5006168800604118), ('login', 1.4897668847911305), ('page', 1.4897668847911305), ('event', 1.3689742149162862), ('command', 1.3221758503609702), ('log', 1.2927601504132413), ('dump', 1.1828481488259341), ('tmp-file', 1.0)]
# Other
# [('administr', 1.3212032573170025), ('servic', 1.081370451509235), ('new', 1.0728176139466463), ('perform', 1.0653266731940532), ('reboot', 1.038083021826736), ('use', 1.0208397869588826), ('termin', 1.0), ('set', 0.9870396763434839), ('request', 0.9864548227156624), ('command', 0.9621139915742334)]
# NoOther
# [('payload', 2.0), ('sent', 1.6487798780792726), ('addit', 1.4957894641638376), ('compon', 1.4625876119987498), ('thi', 1.2863792406399674), ('kaptoxa', 1.0284314217434358), ('some-variable', 1.0), ('save', 1.0), ('delet', 1.0), ('modifi', 1.0)]
#
# Model 'sąsiedzi':
# bag-of-words: 228
# no-Other
# [('login', 1.636467464425785), ('password', 1.5704086798290173), ('secur', 1.5375073410276916), ('infect', 1.1804496962365725), ('bot', 1.1804496962365725), ('pars', 1.1573553148629663), ('interest', 1.1061597967861323), ('command', 1.101397761623823), ('edit', 1.0997904656719317), ('page', 0.9643407418022233)]
# Other
# [('user', 1.6931540534029836), ('registri', 1.2762511640668712), ('perform', 1.2494502271490184), ('set', 1.2412538176182655), ('new', 1.081264266954888), ('kill', 1.026862516736434), ('key', 0.9700940625451531), ('send', 0.8933684356419032), ('also', 0.8877510893531185), ('c&c', 0.8632429664018396)]
# NoOther
# [('payloads.', 1.9777660400436399), ('compon', 1.8480095280467181), ('machin', 1.2454504751841173), ('data', 1.1700681842148228), ('reach', 1.1466976110320533), ('addit', 1.0936413983280127), ('system-path', 1.0489544657354135), ('c2', 0.9987147300548802), ('typic', 0.9777141060975991), ('transfer', 0.9742543428816524)]
#
# >>> File-Train
#
# Model z relacjami:
# bag-of-words: 1313
# File
# [('delet', 13.628948364140154), ('write', 12.75084867445688), ('creat', 12.051504881411287), ('disk', 11.949885307812826), ('copi', 11.735682189635384), ('dropper', 11.600444318120797), ('written', 7.820670799821106), ('log', 7.48824083094832), ('attack', 6.553394206093898), ('hash-code', 6.120843078367121)]
# NoFile
# [('upload', 22.597857839953473), ('send', 18.551332358274166), ('request', 18.448408624044756), ('c&c', 16.847766447810116), ('hook', 15.80671230674047), ('servic', 15.50456363303949), ('com-file', 14.465215832640485), ('sent', 13.594115615129493), ('post', 13.299095348515914), ('call', 13.163009162271054)]
#
# Model 'sąsiedzi':
# bag-of-words: 1429
# File
# [('write', 12.962088363055736), ('disk', 12.40964784473976), ('copi', 11.245026611069106), ('delet', 10.801346771778897), ('written', 8.988234563422562), ('dropper', 7.647222993529837), ('system-path', 6.427412200983005), ('drop', 6.18474274327129), ('log', 5.535199238609956), ('store', 5.135021045433091)]
# NoFile
# [('send', 17.70743157290739), ('command', 15.624295846348826), ('hook', 15.016531107979626), ('server', 14.302166644280856), ('call', 13.070254196306264), ('servic', 13.01095447526573), ('request', 12.911232054875974), ('system-path', 11.927904694682894), ('sent', 11.818048579393725), ('system', 11.726180652773614)]
#
# >>> command_and_control-Test
#
# Model z relacjami:
# bag-of-words: 489
# command_and_control
# [('report', 2.918939090926017), ('sent', 2.2476039495606726), ('reach', 2.0), ('configur', 1.9886320007546654), ('command-and-control', 1.7115958119124737), ('send', 1.688491367508737), ('download', 1.2962059213748), ('ip', 1.1265979906707317), ('address', 1.0828794075540733), ('receiv', 1.0)]
# no-command_and_control
# [('exfiltr', 4.9708759227131685), ('log', 4.6421526058388585), ('instal', 4.044083824564128), ('network', 3.1686507699597324), ('user', 3.1206443044861474), ('execut', 3.101738356507978), ('devic', 2.968453854981549), ('sent', 2.8714205275174094), ('comput', 2.8319934537025815), ('provid', 2.8280121889526906)]
#
# Model 'sąsiedzi':
# bag-of-words: 487
# command_and_control
# [('configur', 2.3764888058489646), ('report', 1.9869597229821045), ('c2', 1.7181203641500318), ('send', 1.7030504029931575), ('sent', 1.3386625614654815), ('reach', 1.2735510795430303), ('compon', 1.2224114781529436), ('command', 1.1617437774515116), ('command-and-control', 1.0), ('carbanak', 0.9822196173686355)]
# no-command_and_control
# [('execut', 3.6835244769652467), ('access', 3.5588987595266506), ('instal', 3.4940702627211038), ('log', 3.430057976214135), ('design', 3.3958123678131913), ('victim', 3.044678158922861), ('inform', 2.7600413046556507), ('provid', 2.715756583824524), ('screenshot', 2.6245763291660698), ('tool', 2.588967218366656)]
#
# >>> infection_propagation-Train
#
# Model z relacjami:
# bag-of-words: 2744
# no-infection/propagation
# [('inform', 42.06453956774742), ('control', 40.630976717739784), ('commun', 40.028133432640914), ('backdoor', 38.56038128604443), ('encrypt', 38.35828532010504), ('execut', 36.54833263335941), ('connect', 36.382171465152354), ('download', 36.27264797128694), ('tool', 34.08826872172397), ('driver', 33.77179368817306)]
# infection/propagation
# [('infect', 20.775429074931925), ('exploit', 18.273344021142556), ('phish', 15.242654784247096), ('email', 13.683878824190165), ('document', 12.390708517483096), ('victim', 11.506457063540923), ('malici', 10.601109749017994), ('network', 10.034861283000332), ('deliv', 9.994659007430581), ('compromis', 8.76668612901445)]
#
# Model 'sąsiedzi':
# bag-of-words: 2792
# no-infection/propagation
# [('command', 44.647018883780966), ('server', 39.56303499865637), ('c&c', 37.514255877118245), ('execut', 36.43119844531002), ('download', 35.72757449785438), ('inform', 34.33248743183191), ('commun', 32.53750581624413), ('encrypt', 32.01714407155902), ('connect', 30.933040756980972), ('system', 30.51413138843038)]
# infection/propagation
# [('target', 18.938656888447007), ('infect', 18.291906886517108), ('exploit', 15.486157613534738), ('email', 10.664861598874927), ('phish', 10.2767885127532), ('deliv', 9.61050140922374), ('victim', 8.647287465298678), ('wa', 8.382814221910763), ('contain', 8.129167977214463), ('spread', 8.034336771936372)]
#
# >>> infection_propagation-Test
#
# Model z relacjami:
# bag-of-words: 489
# no-infection/propagation
# [('sent', 5.119024477078082), ('exfiltr', 4.9708759227131685), ('log', 4.6421526058388585), ('instal', 4.044083824564128), ('download', 3.8366509268978346), ('execut', 3.2867126361851984), ('provid', 3.14797630458643), ('remot', 3.1184197559823064), ('ssh', 3.045403225781941), ('configur', 3.031122321107872)]
# infection/propagation
# [('devic', 1.654428327051472), ('exploit', 1.0815885840680628), ('spread', 1.037658075351768), ('network', 1.0145555030978932), ('target', 0.8674842855432804), ('legitim', 0.8644115309284923), ('onli', 0.8350107917888032), ('phish', 0.8095969929493777), ('find', 0.7561240405863389), ('specif', 0.7522453757028155)]
#
# Model 'sąsiedzi':
# bag-of-words: 487
# no-infection/propagation
# [('execut', 4.291815183725593), ('command', 3.7067289575959403), ('access', 3.5588987595266506), ('sent', 3.5313828729247376), ('instal', 3.4940702627211038), ('log', 3.430057976214135), ('design', 3.3958123678131913), ('inform', 3.151937008153619), ('configur', 3.1508896391497867), ('provid', 3.1076522873224923)]
# infection/propagation
# [('target', 1.130700812037337), ('find', 1.0845089289342509), ('devic', 1.0845089289342509), ('attempt', 0.9941405726247526), ('exploit', 0.9190255074939754), ('spread', 0.8891427936630849), ('discuss', 0.7675261760569771), ('network', 0.7429615127688037), ('phish', 0.7351997164754751), ('legitim', 0.7169915343195148)]
#
# >>> other-Train
#
# Model z relacjami:
# bag-of-words: 2744
# no-other
# [('commun', 30.99285533931765), ('c2', 28.832385853472555), ('connect', 28.44529772379115), ('infect', 23.49478132231705), ('control', 23.288232909261254), ('request', 22.358357746522383), ('send', 20.219314381338584), ('exploit', 19.499127910271888), ('http', 18.643325952725625), ('domain', 18.11178063984301)]
# other
# [('inform', 37.43241261267968), ('encrypt', 35.95152336919619), ('backdoor', 33.980826510113765), ('tool', 31.15940712016254), ('download', 30.775602796573253), ('instal', 30.534055358538616), ('driver', 29.95116086855253), ('execut', 28.752085502931013), ('drop', 28.253080906983215), ('collect', 23.84103714040385)]
#
# Model 'sąsiedzi':
# bag-of-words: 2792
# no-other
# [('server', 30.471408242158475), ('c&c', 28.381405107724476), ('command', 26.096420425016994), ('commun', 25.926315751501836), ('connect', 24.48749250905156), ('infect', 21.770460845289), ('target', 20.3963406326083), ('send', 17.612810396231193), ('c2', 17.533019936049232), ('exploit', 16.781583524186562)]
# other
# [('download', 30.09587524839544), ('encrypt', 29.897344002973153), ('execut', 29.304114221082205), ('inform', 29.2441113397124), ('system', 28.5628267919857), ('instal', 26.57688781272042), ('drop', 23.875336901521816), ('includ', 23.74969550083231), ('backdoor', 23.370911283550935), ('driver', 22.93800732913674)]
#
# >>> command_and_control-Train
#
# Model z relacjami:
# bag-of-words: 2744
# command_and_control
# [('commun', 30.99285533931765), ('c2', 28.592100383017723), ('connect', 26.94759544045593), ('control', 22.210058600594127), ('request', 21.671596708668257), ('http', 18.643325952725625), ('send', 17.128400020221537), ('sampl', 15.627189744819127), ('com-file', 15.50754408418181), ('receiv', 13.261477744826564)]
# no-command_and_control
# [('inform', 39.667180899192), ('instal', 37.87231067463245), ('backdoor', 36.70497449895504), ('encrypt', 36.613751301715794), ('tool', 35.29682099713669), ('download', 34.34762096305351), ('execut', 34.039278871959176), ('infect', 33.7707638282297), ('network', 32.59532514400751), ('driver', 32.30414141799248)]
#
# Model 'sąsiedzi':
# bag-of-words: 2792
# command_and_control
# [('c&c', 28.107636002375692), ('server', 26.862864815246446), ('command', 25.829501432181395), ('commun', 25.602775861695207), ('connect', 24.139337389245757), ('c2', 17.146091388091946), ('send', 14.936406570348465), ('request', 14.585222248118166), ('http', 12.58648387000872), ('receiv', 11.606259109521126)]
# no-command_and_control
# [('download', 33.50859083986572), ('execut', 33.147072070605), ('instal', 32.98353494330293), ('system', 32.847254688219884), ('inform', 31.3024738498686), ('encrypt', 30.877489627607982), ('target', 30.510518082380948), ('infect', 30.31767664352543), ('drop', 28.001209443985008), ('exploit', 27.310758214044476)]
#
# >>> other-Test
#
# Model z relacjami:
# bag-of-words: 489
# no-other
# [('report', 2.918939090926017), ('sent', 2.2476039495606726), ('reach', 2.0), ('configur', 1.9886320007546654), ('command-and-control', 1.7115958119124737), ('send', 1.688491367508737), ('devic', 1.654428327051472), ('address', 1.3007833689816828), ('download', 1.2962059213748), ('receiv', 1.2767995918410284)]
# other
# [('exfiltr', 4.9708759227131685), ('log', 4.6421526058388585), ('instal', 4.044083824564128), ('execut', 2.8770616565047624), ('sent', 2.8714205275174094), ('provid', 2.8280121889526906), ('machin', 2.769763516387751), ('user', 2.676448306400869), ('grayfish', 2.6408080377047374), ('ssh', 2.6366709907813255)]
#
# Model 'sąsiedzi':
# bag-of-words: 487
# no-other
# [('configur', 2.3764888058489646), ('report', 1.9869597229821045), ('c2', 1.7181203641500318), ('send', 1.7030504029931575), ('sent', 1.3386625614654815), ('reach', 1.2735510795430303), ('onli', 1.2555747005666742), ('plugx', 1.2424011446284395), ('compon', 1.2224114781529436), ('network', 1.200138263178842)]
# other
# [('execut', 3.6835244769652467), ('access', 3.5588987595266506), ('instal', 3.4940702627211038), ('log', 3.430057976214135), ('design', 3.3958123678131913), ('victim', 3.044678158922861), ('inform', 2.7600413046556507), ('provid', 2.715756583824524), ('screenshot', 2.6245763291660698), ('tool', 2.588967218366656)]

# %%
for cat in dataframes.keys():

    df = dataframes[cat]
    labels = df['label_num'].tolist()
    f, (ax1, ax2) = plt.subplots(1, 2, sharey=True, figsize=(12, 6))
    
    X_counts = vectorizer.fit_transform(df['text-neigh-tokens'])
    plot_LSA(X_counts, labels, ax1)
    ax1.set_title("{} - neighbours".format(cat))
    
    X_counts = vectorizer.fit_transform(df['text-rel-tokens'])
    plot_LSA(X_counts, labels, ax2)
    ax2.set_title("{} - relations".format(cat))

# %%
'''
Now for the n-grams! 
Are there bigrams more interesting for the classifier than unigrams?
'''

from sklearn.feature_extraction.text import CountVectorizer
vectorizer = CountVectorizer(
    tokenizer=dummy,
    preprocessor=dummy,
    ngram_range=(1, 3)
)

'''
Let's search for bigrams, which position are they,
if we also take unigrams into consideration?

(COUNT VECTORIZER)
'''

for cat in dataframes.keys():
    print("\n>>> {}".format(cat))
    df = dataframes[cat]
    
    feature_count = 10 if 'Test' in cat else 100
    # because we expect nothing special from test dataset
    
    print("\nModel z relacjami:")
    X_counts = vectorizer.fit_transform(df['text-rel-tokens']) # stwórz macierz liczbową z danych. W wierszach mamy kolejne dokumenty, w kolumnach kolejne pola wektora cech odpowiadające unikalnym słowom (bag of words)
    print("bag-of-words: {x}".format(x=X_counts.shape[1]))
    result = get_top_occuring_words(X_counts, feature_count, vectorizer, df)
    for entry in result:
        category = entry[0]
        print("-", category)
        words = entry[1]
        for idx, word in enumerate(words):
            len_check = len(word[0].split())
            if len_check > 1:
                print("{}. : {}, {}".format(idx, word[0], word[1]))
            
    
    print("\nModel 'sąsiedzi':")
    X_counts = vectorizer.fit_transform(df['text-neigh-tokens']) # stwórz macierz liczbową z danych. W wierszach mamy kolejne dokumenty, w kolumnach kolejne pola wektora cech odpowiadające unikalnym słowom (bag of words)
    print("bag-of-words: {x}".format(x=X_counts.shape[1]))
    result = get_top_occuring_words(X_counts, feature_count, vectorizer, df)
    for entry in result:
        category = entry[0]
        print("-", category)
        words = entry[1]
        for idx, word in enumerate(words):
            len_check = len(word[0].split())
            if len_check > 1:
                print("{}. : {}, {}".format(idx, word[0], word[1]))
# Out:
# >>> Other-Train
#
# Model z relacjami:
# bag-of-words: 10238
# - NoOther
# 45. : command control, 19.0
# 57. : execut file, 16.0
# 60. : c&c server, 16.0
# 73. : download file, 13.0
# 76. : ip address, 13.0
# 82. : control server, 12.0
# 98. : command control server, 10.0
# - Other
# 26. : post request, 22.0
# 43. : registri key, 16.0
# 49. : get request, 14.0
# 53. : http post, 13.0
# 62. : system-path system-path, 11.0
# 70. : http post request, 10.0
# 74. : pipe server, 9.0
# 78. : name pipe, 9.0
# 80. : dll modul, 8.0
# 97. : network share, 7.0
# 98. : http get request, 7.0
# 99. : http get, 7.0
#
# Model 'sąsiedzi':
# bag-of-words: 9447
# - NoOther
# 26. : download execut, 22.0
# 58. : execut file, 13.0
# 64. : upload download, 12.0
# 87. : disk execut, 9.0
# 97. : download file, 9.0
# - Other
# 49. : post request, 11.0
# 55. : registri key, 10.0
# 61. : get request, 9.0
# 68. : driver hook, 8.0
# 71. : http post, 8.0
# 81. : dll modul, 7.0
# 96. : usermod dll, 6.0
# 97. : load dll, 6.0
#
# >>> File-Test
#
# Model z relacjami:
# bag-of-words: 844
# - File
# 4. : event log, 3.0
# - no-File
# 1. : login page, 4.0
# 6. : victim login page, 3.0
# 7. : victim login, 3.0
# - NoFile
# 3. : c2 server, 5.0
#
# Model 'sąsiedzi':
# bag-of-words: 850
# - File
# 3. : log dump, 5.0
# 4. : event log, 5.0
# 8. : event log dump, 4.0
# - no-File
# 6. : tcp port, 2.0
# 8. : login page, 2.0
# 9. : victim login, 2.0
# - NoFile
#
# >>> Network-Train
#
# Model z relacjami:
# bag-of-words: 10238
# - NoNetwork
# 47. : post request, 22.0
# 61. : registri key, 17.0
# 73. : execut file, 14.0
# 74. : get request, 14.0
# 78. : system-path system-path, 13.0
# 80. : http post, 13.0
# 81. : pipe server, 12.0
# - Network
# 25. : command control, 17.0
# 28. : c&c server, 16.0
# 39. : ip address, 13.0
# 42. : download file, 12.0
# 45. : control server, 12.0
# 53. : command control server, 10.0
# 55. : upload file, 9.0
# 68. : tcp port, 8.0
# 76. : second stage, 7.0
# 77. : c2 server, 7.0
# 78. : malwar send, 7.0
# 87. : email address, 6.0
#
# Model 'sąsiedzi':
# bag-of-words: 9447
# - NoNetwork
# 87. : registri key, 11.0
# 88. : post request, 11.0
# 93. : execut file, 10.0
# - Network
# 25. : download execut, 14.0
# 36. : upload download, 10.0
# 45. : download file, 9.0
# 78. : attempt connect, 6.0
# 85. : command receiv, 5.0
# 86. : file upload, 5.0
# 88. : send receiv, 5.0
# 99. : variant connect, 5.0
#
# >>> Network-Test
#
# Model z relacjami:
# bag-of-words: 844
# - no-Network
# 3. : event log, 3.0
# - Network
# 4. : login page, 4.0
# 7. : c2 server, 4.0
# - NoNetwork
#
# Model 'sąsiedzi':
# bag-of-words: 850
# - no-Network
# 1. : log dump, 5.0
# 2. : event log, 5.0
# 6. : event log dump, 4.0
# - Network
# - NoNetwork
#
# >>> Other-Test
#
# Model z relacjami:
# bag-of-words: 844
# - no-Other
# 0. : login page, 4.0
# 4. : event log, 3.0
# 8. : victim login page, 3.0
# 9. : victim login, 3.0
# - Other
# 9. : hash valu, 2.0
# - NoOther
# 7. : c2 server, 4.0
#
# Model 'sąsiedzi':
# bag-of-words: 850
# - no-Other
# 1. : log dump, 5.0
# 2. : event log, 5.0
# 5. : event log dump, 4.0
# - Other
# - NoOther
# 7. : execut payloads., 3.0
#
# >>> File-Train
#
# Model z relacjami:
# bag-of-words: 10238
# - File
# 19. : execut file, 14.0
# 37. : delet file, 8.0
# 57. : write file, 6.0
# 59. : log file, 6.0
# 80. : configur file, 5.0
# 85. : dropper write, 5.0
# 91. : command line, 5.0
# 95. : log data, 4.0
# 98. : dropper creat, 4.0
# - NoFile
# 57. : post request, 22.0
# 65. : command control, 20.0
# 67. : c&c server, 19.0
# 79. : registri key, 16.0
# 82. : control server, 15.0
# 91. : get request, 14.0
# 94. : ip address, 13.0
# 97. : c2 server, 13.0
# 99. : command control server, 13.0
#
# Model 'sąsiedzi':
# bag-of-words: 9447
# - File
# 29. : execut file, 10.0
# 34. : disk execut, 9.0
# 44. : download execut, 8.0
# 49. : written disk, 7.0
# 55. : delet file, 6.0
# 60. : file written, 6.0
# 66. : write disk, 6.0
# 73. : file copi, 5.0
# 74. : file creat, 5.0
# 76. : write file, 5.0
# 84. : drop execut, 5.0
# 89. : temporari file, 4.0
# 95. : configur file, 4.0
# - NoFile
# 68. : download execut, 14.0
# 88. : upload download, 11.0
# 95. : post request, 11.0
#
# >>> command_and_control-Test
#
# Model z relacjami:
# bag-of-words: 2289
# - command_and_control
# 2. : c&c server, 12.0
# 5. : c2 server, 7.0
# 8. : report c&c server, 5.0
# 9. : report c&c, 5.0
# - no-command_and_control
#
# Model 'sąsiedzi':
# bag-of-words: 1932
# - command_and_control
# 2. : c&c server, 9.0
# 9. : configur c&c server, 3.0
# - no-command_and_control
#
# >>> infection_propagation-Train
#
# Model z relacjami:
# bag-of-words: 27233
# - no-infection/propagation
# 26. : command control, 74.0
# 36. : c&c server, 66.0
# 73. : ip address, 41.0
# 74. : c2 server, 40.0
# 89. : control server, 33.0
# 98. : command control server, 30.0
# - infection/propagation
# 27. : spear phish, 21.0
# 51. : phish email, 14.0
# 58. : attack use, 14.0
# 76. : water hole, 12.0
# 80. : social engin, 11.0
# 90. : decoy document, 9.0
# 94. : ip address, 9.0
# 96. : java exploit, 9.0
#
# Model 'sąsiedzi':
# bag-of-words: 22593
# - no-infection/propagation
# 76. : c&c server, 34.0
# - infection/propagation
# 26. : spear phish, 16.0
# 40. : phish email, 12.0
# 52. : social engin, 11.0
# 70. : water hole, 9.0
# 74. : spear phish email, 8.0
# 96. : microsoft offic, 7.0
#
# >>> infection_propagation-Test
#
# Model z relacjami:
# bag-of-words: 2289
# - no-infection/propagation
# 8. : c&c server, 13.0
# - infection/propagation
#
# Model 'sąsiedzi':
# bag-of-words: 1932
# - no-infection/propagation
# - infection/propagation
# 7. : find infect devic, 2.0
# 8. : attempt find infect, 2.0
# 9. : infect devic, 2.0
#
# >>> other-Train
#
# Model z relacjami:
# bag-of-words: 27233
# - no-other
# 15. : command control, 61.0
# 17. : c&c server, 57.0
# 39. : ip address, 34.0
# 46. : c2 server, 29.0
# 51. : control server, 27.0
# 57. : command control server, 25.0
# 76. : spear phish, 21.0
# 83. : attack use, 20.0
# - other
#
# Model 'sąsiedzi':
# bag-of-words: 22593
# - no-other
# 49. : c&c server, 21.0
# 76. : spear phish, 16.0
# 96. : command control, 13.0
# - other
#
# >>> command_and_control-Train
#
# Model z relacjami:
# bag-of-words: 27233
# - command_and_control
# 10. : command control, 61.0
# 13. : c&c server, 55.0
# 22. : c2 server, 29.0
# 25. : control server, 27.0
# 26. : command control server, 25.0
# 27. : ip address, 25.0
# 53. : post request, 13.0
# 69. : get request, 11.0
# 78. : http request, 10.0
# 81. : use command, 10.0
# 87. : commun c&c, 9.0
# 93. : c&c domain, 9.0
# 94. : sampl connect, 9.0
# - no-command_and_control
#
# Model 'sąsiedzi':
# bag-of-words: 22593
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-33-e6888c0cba74> in <module>
#      42     X_counts = vectorizer.fit_transform(df['text-neigh-tokens']) # stwórz macierz liczbową z danych. W wierszach mamy kolejne dokumenty, w kolumnach kolejne pola wektora cech odpowiadające unikalnym słowom (bag of words)
#      43     print("bag-of-words: {x}".format(x=X_counts.shape[1]))
# ---> 44     result = get_top_occuring_words(X_counts, feature_count, vectorizer, df)
#      45     for entry in result:
#      46         category = entry[0]
#
# ~/Documents/ENGINEER/my-notebooks/data_helpers.py in get_top_occuring_words(X_train_counts, how_many_words, vectorizer, train)
#      90
#      91     for doc_id, word_id, count in zip(cx.row, cx.col, cx.data):
# ---> 92         category = train.iloc[doc_id]['label']  # w category znajduje się idetyfikator kategorii dla aktualnego dokumentu, zapisujemy go
#      93         word = id_to_word[word_id]              # w word - aktualne słowo z dokumentu
#      94                                                 # mamy też liczność wystąpienia danego słowa w dokumencie (gdzie? :) )
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1476
#    1477             maybe_callable = com._apply_if_callable(key, self.obj)
# -> 1478             return self._getitem_axis(maybe_callable, axis=axis)
#    1479
#    1480     def _is_scalar_access(self, key):
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    2102             self._validate_integer(key, axis)
#    2103
# -> 2104             return self._get_loc(key, axis=axis)
#    2105
#    2106     def _convert_to_indexer(self, obj, axis=None, is_setter=False):
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/indexing.py in _get_loc(self, key, axis)
#     143         if axis is None:
#     144             axis = self.axis
# --> 145         return self.obj._ixs(key, axis=axis)
#     146
#     147     def _slice(self, obj, axis=None, kind=None):
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/frame.py in _ixs(self, i, axis)
#    2624                                                       index=self.columns,
#    2625                                                       name=self.index[i],
# -> 2626                                                       dtype=new_values.dtype)
#    2627                 result._set_is_copy(self, copy=copy)
#    2628                 return result
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     279         generic.NDFrame.__init__(self, data, fastpath=True)
#     280
# --> 281         self.name = name
#     282         self._set_axis(0, index, fastpath=True)
#     283
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    4396             object.__setattr__(self, name, value)
#    4397         elif name in self._metadata:
# -> 4398             object.__setattr__(self, name, value)
#    4399         else:
#    4400             try:
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/series.py in name(self, value)
#     405     @name.setter
#     406     def name(self, value):
# --> 407         if value is not None and not is_hashable(value):
#     408             raise TypeError('Series.name must be a hashable type')
#     409         object.__setattr__(self, '_name', value)
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/dtypes/inference.py in is_hashable(obj)
#     438
#     439     try:
# --> 440         hash(obj)
#     441     except TypeError:
#     442         return False
#
# KeyboardInterrupt:

# %%
'''
Check scores considering n-grams for TDIDF Vectorizer!
'''

vectorizer = TfidfVectorizer(
    tokenizer=dummy,
    preprocessor=dummy,
    ngram_range=(1,3)
)

for cat in dataframes.keys():
    print("\n>>> {}".format(cat))
    df = dataframes[cat]
    
    feature_count = 10 if 'Test' in cat else 100
    # because we expect nothing special from test dataset
    
    print("\nModel z relacjami:")
    X_counts = vectorizer.fit_transform(df['text-rel-tokens']) # stwórz macierz liczbową z danych. W wierszach mamy kolejne dokumenty, w kolumnach kolejne pola wektora cech odpowiadające unikalnym słowom (bag of words)
    print("bag-of-words: {x}".format(x=X_counts.shape[1]))
    result = get_top_occuring_words(X_counts, feature_count, vectorizer, df)
    for entry in result:
        category = entry[0]
        print("-", category)
        words = entry[1]
        for idx, word in enumerate(words):
            len_check = len(word[0].split())
            if len_check > 1:
                print("{}. : {}, {}".format(idx, word[0], word[1]))
            
    
    print("\nModel 'sąsiedzi':")
    X_counts = vectorizer.fit_transform(df['text-neigh-tokens']) # stwórz macierz liczbową z danych. W wierszach mamy kolejne dokumenty, w kolumnach kolejne pola wektora cech odpowiadające unikalnym słowom (bag of words)
    print("bag-of-words: {x}".format(x=X_counts.shape[1]))
    result = get_top_occuring_words(X_counts, feature_count, vectorizer, df)
    for entry in result:
        category = entry[0]
        print("-", category)
        words = entry[1]
        for idx, word in enumerate(words):
            len_check = len(word[0].split())
            if len_check > 1:
                print("{}. : {}, {}".format(idx, word[0], word[1]))
# Out:
# >>> ActionName-Train
#
# Model z relacjami:
# bag-of-words: 30775
# - ActionName
# 47. : download file, 5.839672193343967
# 56. : execut file, 5.001764667127984
# 64. : post request, 4.601443536432968
# 69. : upload file, 4.3525977951713415
# 83. : command control, 3.727395518858263
# 92. : c&c server, 3.4038398288696743
# - NoActionName
# 35. : c&c server, 9.282584717553169
# 41. : command control, 8.92652424556101
# 82. : attack use, 5.516364230587741
# 85. : ip address, 5.450388832132534
#
# Model 'sąsiedzi':
# bag-of-words: 25913
# - ActionName
# 40. : download execut, 5.3181342086504815
# 88. : execut file, 3.164302576102987
# 92. : upload download, 3.049998721769038
# - NoActionName
# 54. : c&c server, 6.728795838029409
#
# >>> ActionName-Test
#
# Model z relacjami:
# bag-of-words: 2604
# - ActionName
# - NoActionName
# 4. : c&c server, 2.673775449766095
#
# Model 'sąsiedzi':
# bag-of-words: 2265
# - ActionName
# 9. : download execut, 1.1457942846834346
# - NoActionName
# 6. : c&c server, 1.9204115043608707
#
# >>> Capability-Train
#
# Model z relacjami:
# bag-of-words: 30775
# - Capability
# 34. : c&c server, 12.686424546422844
# 40. : command control, 12.012640857455793
# 89. : ip address, 7.107134498139995
# 95. : c2 server, 6.706046995513969
# 97. : control server, 6.441578186028483
# - NoCapability
# 19. : download file, 4.643020761377613
# 28. : execut file, 4.003457729815709
# 38. : upload file, 3.018305012795002
# 61. : instal servic, 2.1787007119298414
# 74. : name pipe, 1.842844425322112
# 76. : loader load, 1.8098682693900907
# 80. : system-path system-path, 1.7050367782989488
# 81. : load memori, 1.6817414497770957
# 84. : driver hook, 1.5873328253154964
# 88. : creat copi, 1.5457435108971644
# 90. : regist servic, 1.5189021774567653
# 91. : loader execut, 1.5059933289470508
# 93. : registri key, 1.4486614174603294
# 95. : creat follow, 1.4253466610625094
# 96. : malwar creat, 1.4200601668999984
#
# Model 'sąsiedzi':
# bag-of-words: 25913
# - Capability
# 80. : c&c server, 7.4114177655006594
# - NoCapability
# 45. : disk execut, 2.500925937161754
# 50. : upload download, 2.297229354821939
# 54. : written disk, 2.1621140072330554
# 62. : execut file, 2.0581184249532254
# 69. : regist servic, 1.8413095765030074
# 72. : file written, 1.795208233835376
# 74. : driver hook, 1.783243282339753
# 76. : download execut, 1.7662045800711723
# 81. : execut it., 1.6996583796254519
# 87. : instal servic, 1.6383736950760348
# 90. : write disk, 1.5854212436013593
#
# >>> Capability-Test
#
# Model z relacjami:
# bag-of-words: 2604
# - Capability
# 7. : c&c server, 2.6574309591166774
# - NoCapability
# 5. : delet file, 1.3756945464741137
#
# Model 'sąsiedzi':
# bag-of-words: 2265
# - Capability
# - NoCapability
# 4. : log dump, 1.1053524971777882
# 9. : event log dump, 0.9383924495360833

# %%
'''
Saving processed data to file
'''

main_cats = ['ActionName', 'Capability']
subfolder = 'Processed'
for ccat in dataframes.keys():
    cat = 'ActionName' if ccat[0].isupper() else 'Capability'
    sub_path = os.getcwd() + "/" + cat + "/" + subfolder
    new_filename = '{}-P.csv'.format(ccat)
    dataframes[ccat].to_csv(sub_path + "/" + new_filename)
