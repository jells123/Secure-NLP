# %%
import numpy as np

def load_embeddings(path):
    mapping = dict()
    
    with open(path, 'r', encoding='utf8') as f:
        for line in f:
            line = line.strip()
            if len(line) == 0:
                continue
            splitted = line.split(" ")
            if len(splitted) <= 2:
                continue
            mapping[splitted[0]] = np.array(splitted[1:], dtype=float) # stwórz słownik słowo -> wektor 
    return mapping

vec_size = 300
glove_mapping = load_embeddings('glove/glove.6B.{}d.txt'.format(vec_size)) 
my_mapping = load_embeddings('Embedding-Models/size{}-window10.txt'.format(vec_size)) 
my_mapping = load_embeddings('Embedding-Models/super_model.txt'.format(vec_size))

# %%
def join_embeddings(glove_mapping, my_mapping):
    glove_keys = np.array(list(glove_mapping.keys()))
    glove_vals = np.array(list(glove_mapping.values()))
    print(glove_keys.shape, glove_vals.shape)

    glove_avg, glove_std = np.average(glove_vals), np.std(glove_vals)

    my_keys = np.array(list(my_mapping.keys()))
    my_vals = np.array(list(my_mapping.values()))
    print(my_keys.shape, my_vals.shape)
    
    my_avg, my_std = np.average(my_vals), np.std(my_vals)

    glove_keys_count = glove_keys.shape[0]
    my_keys_count = my_keys.shape[0]
    all_words_count = np.unique(np.concatenate((glove_keys, my_keys))).shape[0]

    overhead = all_words_count - glove_keys_count

    new_mapping_values = np.zeros(shape = (all_words_count, glove_vals.shape[1] + my_vals.shape[1]), dtype=np.float64)
    new_mapping_keys = np.empty(all_words_count, dtype="<U30")

    # put glove mapping at the beginning of new super-mapping
    # indices 0 : 4 000 000, 0 : 300
    new_mapping_values[:glove_vals.shape[0], :glove_vals.shape[1]] = glove_vals
    new_mapping_keys[:glove_keys.shape[0]] = glove_keys

    vec_size = glove_vals.shape[1]

    # join glove mapping with own mapping 
    # or if it's missing, fill with random normal
    for idx, key in enumerate(glove_keys):
        if key in my_mapping.keys():
            new_mapping_values[idx, glove_vals.shape[1]:] = my_mapping[key]
        else:
            new_mapping_values[idx, glove_vals.shape[1]:] = np.random.normal(loc=glove_avg, scale=glove_std, size=vec_size)

    counter = 0
    for idx, key in enumerate(my_keys):
        if key not in glove_mapping.keys():
            new_mapping_values[glove_vals.shape[0] + counter, :glove_vals.shape[1]] = np.random.normal(loc=my_avg, scale=my_std, size=vec_size)
            new_mapping_values[glove_vals.shape[0] + counter, glove_vals.shape[1]:] = my_mapping[key]
            new_mapping_keys[glove_vals.shape[0] + counter] = key
            counter += 1            

    super_mapping = dict(zip(new_mapping_keys, new_mapping_values))
    return super_mapping

super_mapping = join_embeddings(glove_mapping, my_mapping)
print("\n", len(super_mapping.keys()), len(super_mapping['the']))
# Out:
# (400000,) (400000, 300)
# (21055,) (21055, 300)
# 406548 600

# %%
str(super_mapping['the'][0])
# Out:
# '0.04656'

# %%
with open("Embedding-Models/super-model.txt", "w") as file:
    for key, value in super_mapping.items():
        file.write(key)
        file.write(" ")
        for v in value:
            file.write(str(v) + " ")
        file.write("\n")

# %%
dataframes = {}

# %%
'''
Data loader.
'''

import data_helpers
import os
import pandas as pd

load_main = False

main_cats = ['ActionName', 'Capability']
# dataframes = {cat : {} for cat in main_cats} if load_main else {}

for cat in main_cats:
    path = os.getcwd() + "/Dataframes/" + cat + "/Processed/"
    ls = os.listdir(path)
    for file in ls:
        if (load_main and cat in file) or (not load_main and cat not in file):
            print(file)
            df = pd.read_csv(path + file, encoding='utf-8')

            df.rename({"Unnamed: 0":"a"}, axis="columns", inplace=True)
            df.drop(["a"], axis=1, inplace=True)

            df.rename({"Unnamed: 0.1":"a"}, axis="columns", inplace=True)
            df.drop(["a"], axis=1, inplace=True)

            df_type = file.split('-')[1]
            if load_main:
                try:
                    dataframes[cat][df_type] = df
                except KeyError:
                    print("\t? KeyError exception, did you mean it ?")
                    dataframes[cat] = {}
                    dataframes[cat][df_type] = df
            else:
                sub_cat = file.split('-')[0]
                if sub_cat not in dataframes.keys():
                    dataframes[sub_cat] = {}
                dataframes[sub_cat][df_type] = df

if not load_main:
    main_cats = list(dataframes.keys())
main_cats
# Out:
# File-Train-P.csv
# Other-Test-P.csv
# Network-Test-P.csv
# Other-Train-P.csv
# Network-Train-P.csv
# File-Test-P.csv
# other-Test-P.csv
# infection_propagation-Train-P.csv
# command_and_control-Train-P.csv
# command_and_control-Test-P.csv
# infection_propagation-Test-P.csv
# other-Train-P.csv
# ['File',
#  'Other',
#  'Network',
#  'other',
#  'infection_propagation',
#  'command_and_control']

# %%
'''
Calculate simple average embeddings for given sentences,
based on file loaded (for example vectors of length 50).

Skips words, that don't exist in mapping!
Therefore some possibly meaningful words (in security context) are skipped.
'''

from sklearn.svm import SVC
from nltk import word_tokenize

from data_helpers import clean_sentence

import re
word_pattern = re.compile(r'[^a-zA-Z0-9-]')

from nltk.corpus import stopwords
stopwords = set(stopwords.words('english'))

def documents_to_ave_embeddings(docs, embeddings, slice_size=None, bin_features=False):
    result = []
    for idx, doc in enumerate(docs):
        vectors = []
        
        if bin_features:
            new_doc, features = clean_sentence(doc, get_features=True)   
            f_to_bin = np.array(list(map(int, features.values())), dtype=np.float64)
        else:
            new_doc = clean_sentence(doc, get_features=False)   
                    
        new_doc = re.sub(word_pattern, " ", new_doc)
        
        words = word_tokenize(new_doc)
        words = [word.lower() for word in words if len(word) > 1 and len(word) <= 25]
        
        for word in words:
#         for word in (doc.lower()).split():
            
            global tokens_count
            tokens_count += 1
            if word in embeddings.keys():
                vec = embeddings[word]
                
                if slice_size is not None:
                    first_slice = vec[:slice_size]
                    second_slice = vec[vec_size : vec_size+slice_size]
                    vec = np.concatenate((first_slice, second_slice))
                    
                vectors.append(vec)
            else:
                global missing_tokens
                missing_tokens += 1
          
        if vectors:
            avg_vec = np.average(vectors, axis=0)
        else:
            avg_vec = np.zeros(shape=result[0].shape)

        if bin_features:
            avg_vec = np.concatenate((avg_vec, f_to_bin))
            
        result.append(avg_vec)
    
    print(result)
    return result

# %%
new_doc, features = clean_sentence('zhCat TCP port 443 XORed communication connect back to with using on srv01.microsoftwindowsupdate(dot)net (a deceptive domain owned by this group with falsified Whois data attributing to Microsoft Investor Relations) the HTTP protocol', get_features=True)        
np.array(list(map(int, features.values())), dtype=np.float64)
# Out:
# array([0., 0., 1., 0., 0., 0., 0., 1., 0.])

# %%
from sklearn.metrics import confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, classification_report

# %%
models = {}

# %%
tokens_count = 0
missing_tokens = 0

cat = 'ActionName'
column = 'text-rel'
mapping = super_mapping

print(">>> {}\n".format(cat))

train = dataframes[cat]['Train']
test = dataframes[cat]['Test']

train[column] = train[column].apply(lambda x : re.sub(r'[^\x00-\x7F]+',' ', x))
test[column] = test[column].apply(lambda x : re.sub(r'[^\x00-\x7F]+',' ', x))

ss = 200
bf = True # bin features

train_transformed = documents_to_ave_embeddings(train[column], mapping, slice_size=ss, bin_features=bf)
test_transformed = documents_to_ave_embeddings(test[column], mapping, slice_size=ss, bin_features=bf)

print("There are {} tokens.".format(tokens_count))
print(" - {:2g} are missing :(".format(missing_tokens/tokens_count))
print()

clf = LogisticRegression(
    solver='newton-cg',
    class_weight='balanced',
    C=1.0
)
clf.fit(train_transformed, train['label_num']) # zwektoryzujmy dane i wytrenujmy klasyfikator na zbiorze treningowym

train_acc = clf.score(train_transformed, train['label_num'])
models[cat] = clf

accuracy = clf.score(test_transformed, test['label_num'])
y_pred = clf.predict(test_transformed)

print("Train Acc: {}".format(train_acc))
print("Test Acc: {}".format(accuracy))
print(classification_report(test['label_num'], y_pred))
c_m = confusion_matrix(test['label_num'], y_pred)
tn, fp, fn, tp = c_m.ravel()
print("TN: {}, FP: {}, FN: {}, TP: {}".format(tn, fp, fn, tp))

train_transformed
# Out:
# >>> ActionName
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-7f60a0fe447b> in <module>
#       8 print(">>> {}\n".format(cat))
#       9
# ---> 10 train = dataframes[cat]['Train']
#      11 test = dataframes[cat]['Test']
#      12
#
# KeyError: 'ActionName'

# %%
dataframes['ActionName']['Test']
# Out:
#             label  label_num  \
# 0      ActionName          1
# 1      ActionName          1
# 2      ActionName          1
# 3      ActionName          1
# 4      ActionName          1
# 5      ActionName          1
# 6      ActionName          1
# 7      ActionName          1
# 8      ActionName          1
# 9      ActionName          1
# 10     ActionName          1
# 11     ActionName          1
# 12     ActionName          1
# 13     ActionName          1
# 14     ActionName          1
# 15     ActionName          1
# 16     ActionName          1
# 17     ActionName          1
# 18     ActionName          1
# 19     ActionName          1
# 20     ActionName          1
# 21     ActionName          1
# 22     ActionName          1
# 23     ActionName          1
# 24     ActionName          1
# 25     ActionName          1
# 26     ActionName          1
# 27     ActionName          1
# 28     ActionName          1
# 29     ActionName          1
# ..            ...        ...
# 207  NoActionName          0
# 208  NoActionName          0
# 209  NoActionName          0
# 210  NoActionName          0
# 211  NoActionName          0
# 212  NoActionName          0
# 213  NoActionName          0
# 214  NoActionName          0
# 215  NoActionName          0
# 216  NoActionName          0
# 217  NoActionName          0
# 218  NoActionName          0
# 219  NoActionName          0
# 220  NoActionName          0
# 221  NoActionName          0
# 222  NoActionName          0
# 223  NoActionName          0
# 224  NoActionName          0
# 225  NoActionName          0
# 226  NoActionName          0
# 227  NoActionName          0
# 228  NoActionName          0
# 229  NoActionName          0
# 230  NoActionName          0
# 231  NoActionName          0
# 232  NoActionName          0
# 233  NoActionName          0
# 234  NoActionName          0
# 235  NoActionName          0
# 236  NoActionName          0
#
#                                             text-neigh  \
# 0    Explorer. Bda9.tmp was then executed and went ...
# 1    application was used to create copies of Backd...
# 2    It hides activity by editing events logs, dump...
# 3    by editing events logs, dumping passwords, sec...
# 4    logs, dumping passwords, securely deleting fil...
# 5    also end processes and perform a secure self-d...
# 6    to parse event logs, dumping out ones of inter...
# 7    primary functionality is to parse event logs, ...
# 8    of interest, and to delete entries. The tool will
# 9    Similarly, event logs are modified to remove a...
# 10   OS loading mechanisms by injecting its code in...
# 11   basic system information and save it onto the ...
# 12   Next, it attempted to run the group’s DOUBLEFA...
# 13   upon launch, the malware checks whether the fi...
# 14   infected bot, download and execute a command or a
# 15        does is to start listening on TCP port 10073
# 16   using the infected bot, download and execute a...
# 17   addition, the droppers all directed victims to...
# 18   except one, the victims were directed to legit...
# 19   It is unclear whether redirecting victims to t...
# 20     case in which victims were sent to a login page
# 21   Microsoft ActiveX software. It dropped the sid...
# 22      The tool will also end processes and perform a
# 23   was created. It also looks for certain process...
# 24     is looking for. It checks that the hashed value
# 25   in GRAYFISH, which exclusively uses the regist...
# 26   hijacking capabilities and will kill the proce...
# 27     sets of threads are created that are related to
# 28            see if it can connect on TCP port 10073.
# 29       10073 port, it will result in a TCP handshake
# ..                                                 ...
# 207  command set capable of conducting reconnaissan...
# 208  files, downloading files, and exfiltrating dat...
# 209  including the ability to log keystrokes; modif...
# 210  modify and copy files; capture screenshots or ...
# 211  Activity as terminating processes, logging off...
# 212  command shell is also provided through access ...
# 213  PlugX is most frequently delivered to targets ...
# 214     RAT called ZxShell, which connected to a C2 at
# 215  that was used to invoke other programs with el...
# 216  previously unknown vulnerability to elevate it...
# 217  operations, and it was deleted immediately aft...
# 218  to the executable was executed with elevated p...
# 219  malicious executable to be combined with a mal...
# 220  Notable Activity dropped malware connecting to...
# 221  this adversary seeks to gain legitimate creden...
# 222  to move laterally and establish RDP sessions t...
# 223  of Chopper webshell; this provides the equival...
# 224  from which they can deploy privilege-escalatio...
# 225  following IP addresses are used as PlugX C2 se...
# 226  victim’s network, they then seek legitimate cr...
# 227  HURRICANE PANDA will often rely on RDP. First,...
# 228  keys mechanism and be presented with an admini...
# 229  files of interest are compressed and password ...
# 230  interest are compressed and password protected...
# 231         using RAR. Next, they stage the files at a
# 232  convenient location. Finally, they exfiltrate ...
# 233  use since 2009. Pirpi provides the adversary w...
# 234  allow the adversary to exfiltrate and deploy f...
# 235  Windows-based rootkit that can leverage an enc...
# 236  main implant, called X-Agent, is a sophisticat...
#
#                                               text-rel               token  \
# 0                                    Bda9.tmp executed           obtaining
# 1    create copies of Backdoor.Jiripbot on the comp...        eavesdropped
# 2                               It editing events logs              insert
# 3                                 It dumping passwords                used
# 4                                    It deleting files            executed
# 5                The tool perform a secure self-delete              create
# 6       Hacktool.Eventlog dumping out ones of interest              spread
# 7                   Hacktool.Eventlog parse event logs              create
# 8                     Hacktool.Eventlog delete entries              create
# 9    modified event logs to remove any evidence of ...              remove
# 10    GrayFish injecting its code into the boot record               hides
# 11           save it onto the hidden area of the stick             editing
# 12            it run the group’s DOUBLEFANTASY implant             dumping
# 13   the malware checks whether the file /home/hik/...            deleting
# 14                         execute a command a library                 end
# 15   Linux/Moose TCP port 10073 listening on for in...             perform
# 16                        download a command a library         dumping out
# 17   the droppers directed victims to login pages f...               parse
# 18   the droppers were directed victims to legitima...              delete
# 19            redirecting victims to these login pages               route
# 20   the droppers were sent victims to a login page...            modified
# 21           It dropped the side-loaded Sakula malware              remove
# 22                              The tool end processes           looks for
# 23   It looks for certain process names of running ...              checks
# 24   It checks that the hashed value of the registr...             provide
# 25   GRAYFISH uses the registry to store all malwar...             hijacks
# 26   Moose kill the processes of other malware fami...           injecting
# 27                       created three sets of threads      self-destructs
# 28                        it TCP port 10073 connect on          implements
# 29   it result in without a TCP handshake a data pa...                make
# ..                                                 ...                 ...
# 207       conducting reconnaissance of victim machines         logging off
# 208                                  exfiltrating data            provided
# 209                                  It log keystrokes               sends
# 210         capture screenshots video of user activity           delivered
# 211                                  logging off users             dropped
# 212                      A full command shell provided           connected
# 213  PlugX delivered to via targets a spear phishin...              invoke
# 214      ZxShell connected to a C2 at newss.effers.com             elevate
# 215  Win64.exe invoke other programs with elevated ...              create
# 216  Win64.exe elevate its privileges to those of t...             deleted
# 217                                         deleted it            executed
# 218  executed any command passed to the executable ...            combined
# 219  combined malicious executable a decoy document...          connecting
# 220  malware connecting to a known TEMPER PANDA C2 ...                gain
# 221  this adversary gain legitimate credentials to ...           establish
# 222  this adversary RDP sessions establish to achie...            provides
# 223  this provides the equivalent functionality of ...              deploy
# 224             they deploy privilege-escalation tools                used
# 225  PlugX C2 servers used the following IP address...                seek
# 226  they seek legitimate credentials via tools suc...             rely on
# 227                        HURRICANE PANDA RDP rely on           presented
# 228     presented with an administrative command shell          compressed
# 229             RAR compressed using files of interest  password protected
# 230     RAR password protected using files of interest               stage
# 231      they stage the files at a convenient location          exfiltrate
# 232  they FTP exfiltrate the files from via the net...            provides
# 233  Pirpi provides the adversary with a traditiona...          exfiltrate
# 234                     the adversary exfiltrate files              deploy
# 235  sophisticated Windows-based rootkit leverage a...            leverage
# 236  Their main implant is a sophisticated RAT that...                  is
#
#                                   text-neigh-processed  \
# 0                   explorer.  tmp-file wa execut went
# 1                   applic wa use creat copi  jir-file
# 2              hide activ edit event log dump password
# 3        edit event log dump password secur delet file
# 4      log dump password secur delet file encrypt file
# 5          also end process perform secur self-delete.
# 6                     pars event log dump one interest
# 7                 primari function pars event log dump
# 8                         interest delet entries. tool
# 9            similarli event log modifi remov ani evid
# 10                          os load mechan inject code
# 11                basic system inform save onto hidden
# 12        next attempt run group doublefantasi implant
# 13   upon launch malwar check whether file system-p...
# 14                  infect bot download execut command
# 15                     doe start listen tcp port 10073
# 16              use infect bot download execut command
# 17              addit dropper direct victim login page
# 18       except one victim direct legitim login pages.
# 19               unclear whether redirect victim login
# 20                         case victim sent login page
# 21   microsoft activex software. drop side-load sak...
# 22                       tool also end process perform
# 23          wa created. also look certain process name
# 24                           look for. check hash valu
# 25                  grayfish exclus use registri store
# 26                          hijack capabl kill process
# 27                              set thread creat relat
# 28                         see connect tcp port 10073.
# 29                      10073 port result tcp handshak
# ..                                                 ...
# 207  command set capabl conduct reconnaiss victim m...
# 208            file download file exfiltr data. number
# 209            includ abil log keystrokes; modifi copi
# 210         modifi copi files; captur screenshot video
# 211        activ termin process log user reboot victim
# 212                   command shell also provid access
# 213                    plugx frequent deliv target via
# 214                        rat call zxshell connect c2
# 215                          wa use invok program elev
# 216              previous unknown vulner elev privileg
# 217                          oper wa delet immedi use.
# 218                  execut wa execut elev privileges.
# 219          malici execut combin malici cve-2014-1761
# 220      notabl activ drop malwar connect known temper
# 221      thi adversari seek gain legitim credenti move
# 222            move later establish rdp session achiev
# 223      chopper webshell; thi provid equival function
# 224             deploy privilege-escal tool move later
# 225            follow ip address use plugx c2 servers:
# 226      victim network seek legitim credenti via tool
# 227               hurrican panda often reli rdp. first
# 228               key mechan present administr command
# 229        file interest compress password protect use
# 230   interest compress password protect use rar. next
# 231                           use rar. next stage file
# 232               conveni location. final exfiltr file
# 233              use sinc 2009. pirpi provid adversari
# 234          allow adversari exfiltr deploy file along
# 235   windows-bas rootkit leverag encrypt virtual file
# 236              main implant call x-agent sophist rat
#
#                                     text-rel-processed  \
# 0                                      tmp-file execut
# 1                creat copi  jir-file compromis comput
# 2                                       edit event log
# 3                                        dump password
# 4                                           delet file
# 5                        tool perform secur self-delet
# 6                           eve-file dump one interest
# 7                              eve-file pars event log
# 8                                 eve-file delet entri
# 9         modifi event log remov ani evid attack activ
# 10                    grayfish inject code boot record
# 11                         save onto hidden area stick
# 12                     run group doublefantasi implant
# 13   malwar check whether file system-path  exist disk
# 14                              execut command librari
# 15    system-path  tcp port 10073 listen incom connect
# 16                            download command librari
# 17   dropper direct victim login page servic specif...
# 18            dropper direct victim legitim login page
# 19                          redirect victim login page
# 20   dropper sent victim login page host domain spo...
# 21                        drop side-load sakula malwar
# 22                                    tool end process
# 23               look certain process name run process
# 24   check hash valu registri subkey hash-code equa...
# 25   grayfish use registri store malware-rel modul ...
# 26   moos kill process malwar famili compet limit r...
# 27                              creat three set thread
# 28                              tcp port 10073 connect
# 29            result without tcp handshak data payload
# ..                                                 ...
# 207                   conduct reconnaiss victim machin
# 208                                       exfiltr data
# 209                                       log keystrok
# 210                 captur screenshot video user activ
# 211                                           log user
# 212                          full command shell provid
# 213  plugx deliv via target spear phish attack cont...
# 214                       zxshell connect c2  com-file
# 215               win64.ex invok program elev privileg
# 216                 win64.ex elev privileg system user
# 217                                              delet
# 218       execut ani command pass execut elev privileg
# 219  combin malici execut decoy document malici cve...
# 220  malwar connect known temper panda c2 address w...
# 221     thi adversari gain legitim credenti move later
# 222  thi adversari rdp session establish achiev object
# 223  thi provid equival function rat adversari cont...
# 224                        deploy privilege-escal tool
# 225              plugx c2 server use follow ip address
# 226  seek legitim credenti via tool window credenti...
# 227                            hurrican panda rdp reli
# 228                    present administr command shell
# 229                     rar compress use file interest
# 230             rar password protect use file interest
# 231                           stage file conveni locat
# 232                       ftp exfiltr file via network
# 233       pirpi provid adversari tradit set rat featur
# 234                             adversari exfiltr file
# 235  sophist windows-bas rootkit leverag encrypt vi...
# 236  main implant sophist rat exhibit modular archi...
#
#                                      text-neigh-tokens  \
# 0    ['explorer.', 'tmp-file', 'wa', 'execut', 'went']
# 1    ['applic', 'wa', 'use', 'creat', 'copi', 'jir-...
# 2    ['hide', 'activ', 'edit', 'event', 'log', 'dum...
# 3    ['edit', 'event', 'log', 'dump', 'password', '...
# 4    ['log', 'dump', 'password', 'secur', 'delet', ...
# 5    ['also', 'end', 'process', 'perform', 'secur',...
# 6    ['pars', 'event', 'log', 'dump', 'one', 'inter...
# 7    ['primari', 'function', 'pars', 'event', 'log'...
# 8            ['interest', 'delet', 'entries.', 'tool']
# 9    ['similarli', 'event', 'log', 'modifi', 'remov...
# 10          ['os', 'load', 'mechan', 'inject', 'code']
# 11   ['basic', 'system', 'inform', 'save', 'onto', ...
# 12   ['next', 'attempt', 'run', 'group', 'doublefan...
# 13   ['upon', 'launch', 'malwar', 'check', 'whether...
# 14   ['infect', 'bot', 'download', 'execut', 'comma...
# 15   ['doe', 'start', 'listen', 'tcp', 'port', '100...
# 16   ['use', 'infect', 'bot', 'download', 'execut',...
# 17   ['addit', 'dropper', 'direct', 'victim', 'logi...
# 18   ['except', 'one', 'victim', 'direct', 'legitim...
# 19   ['unclear', 'whether', 'redirect', 'victim', '...
# 20         ['case', 'victim', 'sent', 'login', 'page']
# 21   ['microsoft', 'activex', 'software.', 'drop', ...
# 22       ['tool', 'also', 'end', 'process', 'perform']
# 23   ['wa', 'created.', 'also', 'look', 'certain', ...
# 24           ['look', 'for.', 'check', 'hash', 'valu']
# 25   ['grayfish', 'exclus', 'use', 'registri', 'sto...
# 26             ['hijack', 'capabl', 'kill', 'process']
# 27                 ['set', 'thread', 'creat', 'relat']
# 28         ['see', 'connect', 'tcp', 'port', '10073.']
# 29      ['10073', 'port', 'result', 'tcp', 'handshak']
# ..                                                 ...
# 207  ['command', 'set', 'capabl', 'conduct', 'recon...
# 208  ['file', 'download', 'file', 'exfiltr', 'data....
# 209  ['includ', 'abil', 'log', 'keystrokes;', 'modi...
# 210  ['modifi', 'copi', 'files;', 'captur', 'screen...
# 211  ['activ', 'termin', 'process', 'log', 'user', ...
# 212   ['command', 'shell', 'also', 'provid', 'access']
# 213    ['plugx', 'frequent', 'deliv', 'target', 'via']
# 214        ['rat', 'call', 'zxshell', 'connect', 'c2']
# 215          ['wa', 'use', 'invok', 'program', 'elev']
# 216  ['previous', 'unknown', 'vulner', 'elev', 'pri...
# 217          ['oper', 'wa', 'delet', 'immedi', 'use.']
# 218  ['execut', 'wa', 'execut', 'elev', 'privileges.']
# 219  ['malici', 'execut', 'combin', 'malici', 'cve-...
# 220  ['notabl', 'activ', 'drop', 'malwar', 'connect...
# 221  ['thi', 'adversari', 'seek', 'gain', 'legitim'...
# 222  ['move', 'later', 'establish', 'rdp', 'session...
# 223  ['chopper', 'webshell;', 'thi', 'provid', 'equ...
# 224  ['deploy', 'privilege-escal', 'tool', 'move', ...
# 225  ['follow', 'ip', 'address', 'use', 'plugx', 'c...
# 226  ['victim', 'network', 'seek', 'legitim', 'cred...
# 227  ['hurrican', 'panda', 'often', 'reli', 'rdp.',...
# 228  ['key', 'mechan', 'present', 'administr', 'com...
# 229  ['file', 'interest', 'compress', 'password', '...
# 230  ['interest', 'compress', 'password', 'protect'...
# 231           ['use', 'rar.', 'next', 'stage', 'file']
# 232  ['conveni', 'location.', 'final', 'exfiltr', '...
# 233  ['use', 'sinc', '2009.', 'pirpi', 'provid', 'a...
# 234  ['allow', 'adversari', 'exfiltr', 'deploy', 'f...
# 235  ['windows-bas', 'rootkit', 'leverag', 'encrypt...
# 236  ['main', 'implant', 'call', 'x-agent', 'sophis...
#
#                                        text-rel-tokens
# 0                               ['tmp-file', 'execut']
# 1    ['creat', 'copi', 'jir-file', 'compromis', 'co...
# 2                             ['edit', 'event', 'log']
# 3                                 ['dump', 'password']
# 4                                    ['delet', 'file']
# 5           ['tool', 'perform', 'secur', 'self-delet']
# 6              ['eve-file', 'dump', 'one', 'interest']
# 7                 ['eve-file', 'pars', 'event', 'log']
# 8                       ['eve-file', 'delet', 'entri']
# 9    ['modifi', 'event', 'log', 'remov', 'ani', 'ev...
# 10    ['grayfish', 'inject', 'code', 'boot', 'record']
# 11         ['save', 'onto', 'hidden', 'area', 'stick']
# 12        ['run', 'group', 'doublefantasi', 'implant']
# 13   ['malwar', 'check', 'whether', 'file', 'system...
# 14                    ['execut', 'command', 'librari']
# 15   ['system-path', 'tcp', 'port', '10073', 'liste...
# 16                  ['download', 'command', 'librari']
# 17   ['dropper', 'direct', 'victim', 'login', 'page...
# 18   ['dropper', 'direct', 'victim', 'legitim', 'lo...
# 19             ['redirect', 'victim', 'login', 'page']
# 20   ['dropper', 'sent', 'victim', 'login', 'page',...
# 21           ['drop', 'side-load', 'sakula', 'malwar']
# 22                          ['tool', 'end', 'process']
# 23   ['look', 'certain', 'process', 'name', 'run', ...
# 24   ['check', 'hash', 'valu', 'registri', 'subkey'...
# 25   ['grayfish', 'use', 'registri', 'store', 'malw...
# 26   ['moos', 'kill', 'process', 'malwar', 'famili'...
# 27                 ['creat', 'three', 'set', 'thread']
# 28                 ['tcp', 'port', '10073', 'connect']
# 29   ['result', 'without', 'tcp', 'handshak', 'data...
# ..                                                 ...
# 207      ['conduct', 'reconnaiss', 'victim', 'machin']
# 208                                ['exfiltr', 'data']
# 209                                ['log', 'keystrok']
# 210  ['captur', 'screenshot', 'video', 'user', 'act...
# 211                                    ['log', 'user']
# 212             ['full', 'command', 'shell', 'provid']
# 213  ['plugx', 'deliv', 'via', 'target', 'spear', '...
# 214           ['zxshell', 'connect', 'c2', 'com-file']
# 215  ['win64.ex', 'invok', 'program', 'elev', 'priv...
# 216  ['win64.ex', 'elev', 'privileg', 'system', 'us...
# 217                                          ['delet']
# 218  ['execut', 'ani', 'command', 'pass', 'execut',...
# 219  ['combin', 'malici', 'execut', 'decoy', 'docum...
# 220  ['malwar', 'connect', 'known', 'temper', 'pand...
# 221  ['thi', 'adversari', 'gain', 'legitim', 'crede...
# 222  ['thi', 'adversari', 'rdp', 'session', 'establ...
# 223  ['thi', 'provid', 'equival', 'function', 'rat'...
# 224              ['deploy', 'privilege-escal', 'tool']
# 225  ['plugx', 'c2', 'server', 'use', 'follow', 'ip...
# 226  ['seek', 'legitim', 'credenti', 'via', 'tool',...
# 227               ['hurrican', 'panda', 'rdp', 'reli']
# 228       ['present', 'administr', 'command', 'shell']
# 229     ['rar', 'compress', 'use', 'file', 'interest']
# 230  ['rar', 'password', 'protect', 'use', 'file', ...
# 231              ['stage', 'file', 'conveni', 'locat']
# 232       ['ftp', 'exfiltr', 'file', 'via', 'network']
# 233  ['pirpi', 'provid', 'adversari', 'tradit', 'se...
# 234                   ['adversari', 'exfiltr', 'file']
# 235  ['sophist', 'windows-bas', 'rootkit', 'leverag...
# 236  ['main', 'implant', 'sophist', 'rat', 'exhibit...
#
# [237 rows x 9 columns]

# %%
test_transformed = documents_to_ave_embeddings(dataframes['ActionName']['Test']['text-rel'], mapping)

predictions = {}
for model_name in models.keys():
    predictions[model_name] = models[model_name].predict_proba(test_transformed)

# %%
'''
Gets actual tokens-list from data.
Some tokens annotated as 'Action Token' are not a single word.

Words' pos tags are checked and we add word to a token list 
if it's a VERB, or eventually a NOUN 
(it's usually NNS - noun plural - which was actually a VERB)

Skipping stopwords, because of such phrases as 'were installed' etc.
'''

from nltk.corpus import stopwords
from nltk import word_tokenize, pos_tag       

stopwords = set(stopwords.words('english'))
tokens_lists = {
    0 : [],
    1 : []
}

train = dataframes['ActionName']['Train']
test = dataframes['ActionName']['Test']

import re
pattern = re.compile('\W')

for i in range(train.shape[0]):
    token = train.at[i, 'token']
    label = train.at[i, 'label_num']
    tokens_lists[label] += get_verb_token(token)

print(len(tokens_lists[0]), len(tokens_lists[1]), train.shape)
# Out:
# 2144 1147 (3348, 10)

# %%
def get_verb_token(token):
    result = []
    token = token.lower().split()
    
    token = [t for t in token if t not in stopwords]
    token = [re.sub(pattern, '', t) for t in token]
        
    if len(token) > 1:
        tagged_tokens = [pos_tag([t]) for t in token]
        verb_tokens = [t for t in tagged_tokens if t[0][1].startswith("V")]
        if len(verb_tokens) == 1:
            token = verb_tokens[0][0][0]
            result += [token]
        elif len(verb_tokens) > 1:
            for tt in verb_tokens:
                 result += [tt[0][0]]
        else:
            noun_tokens = [t for t in tagged_tokens if t[0][1].startswith("N")]
            for tt in noun_tokens:
                result += [tt[0][0]]
    else:
        result += token
        
    return result

# %%
map_vectors = {}
for cat in tokens_lists.keys():
    vectors = [mapping[word] for word in tokens_lists[cat] if word in mapping.keys()]
    map_vectors[cat] = np.average(vectors, axis=0)

# %%
def cosine(vec1, vec2):
    vec1, vec2 = np.asarray(vec1), np.asarray(vec2)
    v1_sqrt = np.sqrt(np.sum(vec1 ** 2))
    v2_sqrt = np.sqrt(np.sum(vec2 ** 2))
    return np.sum((np.multiply(vec1, vec2))) / ( v1_sqrt * v2_sqrt )

# %%
all_count = 0
correct_count = 0

ds = train

train_data = []
train_labels = []

for i in range(ds.shape[0]):
    token = get_verb_token(ds.at[i, 'token'])
    label = ds.at[i, 'label_num']
    if token:
        token = token[0]
        
        if token in mapping.keys():
            
            all_count += 1
            vector = mapping[token]
            scores = [cosine(vector, map_vectors[0]), cosine(vector, map_vectors[1])]
#             print("Predicted: {}, real: {}".format(np.argmax(scores), label))
            choice = np.argmax(scores)
        
            if label == choice:
                correct_count += 1
               
            train_data.append(scores)
            train_labels.append(label)

print(correct_count/all_count)
# Out:
# 0.5078922934076138

# %%
clf = SVC()

clf.fit(train_data, train_labels) # zwektoryzujmy dane i wytrenujmy klasyfikator na zbiorze treningowym
accuracy = clf.score(train_data, train_labels)

accuracy
# Out:
# /home/jells123/anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# 0.6511915815536985
